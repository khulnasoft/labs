# %%
#@title 0) setup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
import itertools, random, time
import copy

# Reproducibility
SEED = 42
def resetRandom():
  torch.manual_seed(SEED)
  np.random.seed(SEED)
  random.seed(SEED)
resetRandom()

# training time optimization
torch.set_float32_matmul_precision('high')
torch.backends.cudnn.benchmark = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 1) MLP: A * B % C (A,B between 0..99, C 0..19)

# %% [markdown]
# ## 1.1) Dataset

# %%
def one_hot(n, num_classes=100):
    # One-hot encode a single integer.
    v = np.zeros(num_classes, dtype=np.float32)
    v[n] = 1.0
    return v

# ── Generate all 10,000 input pairs ──
pairs = list(itertools.product(range(100), range(100), range(19)))
random.shuffle(pairs)

X_all, y_all = [], []
for a, b, c in pairs:
    x = np.concatenate([one_hot(a), one_hot(b), one_hot(c, 19)])   # 220-dim
    y = (a * b) % (c+1)
    X_all.append(x)
    y_all.append(y)

X_all = np.array(X_all)
y_all = np.array(y_all)

# 80-20 split
split = int(0.8 * len(X_all))
X_train, X_test = X_all[:split], X_all[split:]
y_train, y_test = y_all[:split], y_all[split:]

# DataLoaders — mini-batch (full-batch would be 8K samples)
BATCH_SIZE = 256
train_ds = TensorDataset(torch.tensor(X_train).to(device), torch.tensor(y_train, dtype=torch.long).to(device))
test_ds  = TensorDataset(torch.tensor(X_test).to(device),  torch.tensor(y_test, dtype=torch.long).to(device))
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE)

print(f"Train: {len(train_ds):,} samples  |  Test: {len(test_ds):,} samples")
print(f"Input dim: {X_train.shape[1]}  |  Output classes: {len(np.unique(y_all))}")
print(f"Label distribution (train): {dict(zip(*np.unique(y_train, return_counts=True)))}")
# Out:
# Train: 152,000 samples  |  Test: 38,000 samples
# Input dim: 219  |  Output classes: 19
# Label distribution (train): {np.int64(0): np.int64(51411), np.int64(1): np.int64(11977), np.int64(2): np.int64(14363), np.int64(3): np.int64(10413), np.int64(4): np.int64(11615), np.int64(5): np.int64(6717), np.int64(6): np.int64(10053), np.int64(7): np.int64(4823), np.int64(8): np.int64(6869), np.int64(9): np.int64(4650), np.int64(10): np.int64(4769), np.int64(11): np.int64(2542), np.int64(12): np.int64(4452), np.int64(13): np.int64(1747), np.int64(14): np.int64(2023), np.int64(15): np.int64(1374), np.int64(16): np.int64(1254), np.int64(17): np.int64(538), np.int64(18): np.int64(410)}

# %% [markdown]
# ## 1.2) DNN: 16x2 growing & shrinking FFN w/ Residuals + Normalization

# %%
class DNN(nn.Module):
    def __init__(self, norm_type=None, is_post_norm=False):
        super().__init__()
        self.is_post_norm = is_post_norm
        hidden_dim = 128
        self.proj_in = nn.Linear(219, hidden_dim)
        self.layers = nn.ModuleList()
        self.norms = nn.ModuleList()
        for _ in range(16):
            self.layers.append(
                nn.Sequential(
                    nn.Linear(hidden_dim, hidden_dim * 2),
                    nn.ReLU(),
                    nn.Linear(hidden_dim * 2, hidden_dim))
                )
            if norm_type is not None:
                self.norms.append(norm_type(hidden_dim))
            else:
                self.norms.append(nn.Identity())
        self.proj_out = nn.Linear(hidden_dim, 19)

    def forward(self, x):
        x = self.proj_in(x)
        for layer, norm in zip(self.layers, self.norms):
            if self.is_post_norm:
                x = norm(x + layer(x))
            else:
                x = x + layer(norm(x))
        return self.proj_out(x)

model = DNN().to(device)
print(model)

print(f"Total parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Per-layer shapes:")
for name, param in model.named_parameters():
    if "weight" in name:
        print(f"  {name:30s}  {str(list(param.shape)):>15s}  ({param.numel():>6,} params)")
# Out:
# DNN(
#   (proj_in): Linear(in_features=219, out_features=128, bias=True)
#   (layers): ModuleList(
#     (0-15): 16 x Sequential(
#       (0): Linear(in_features=128, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=128, bias=True)
#     )
#   )
#   (norms): ModuleList(
#     (0-15): 16 x Identity()
#   )
#   (proj_out): Linear(in_features=128, out_features=20, bias=True)
# )
# Total parameters: 1,085,460
# Per-layer shapes:
#   proj_in.weight                       [128, 219]  (28,032 params)
#   layers.0.0.weight                    [256, 128]  (32,768 params)
#   layers.0.2.weight                    [128, 256]  (32,768 params)
#   layers.1.0.weight                    [256, 128]  (32,768 params)
#   layers.1.2.weight                    [128, 256]  (32,768 params)
#   layers.2.0.weight                    [256, 128]  (32,768 params)
#   layers.2.2.weight                    [128, 256]  (32,768 params)
#   layers.3.0.weight                    [256, 128]  (32,768 params)
#   layers.3.2.weight                    [128, 256]  (32,768 params)
#   layers.4.0.weight                    [256, 128]  (32,768 params)
#   layers.4.2.weight                    [128, 256]  (32,768 params)
#   layers.5.0.weight                    [256, 128]  (32,768 params)
#   layers.5.2.weight                    [128, 256]  (32,768 params)
#   layers.6.0.weight                    [256, 128]  (32,768 params)
#   layers.6.2.weight                    [128, 256]  (32,768 params)
#   layers.7.0.weight                    [256, 128]  (32,768 params)
#   layers.7.2.weight                    [128, 256]  (32,768 params)
#   layers.8.0.weight                    [256, 128]  (32,768 params)
#   layers.8.2.weight                    [128, 256]  (32,768 params)
#   layers.9.0.weight                    [256, 128]  (32,768 params)
#   layers.9.2.weight                    [128, 256]  (32,768 params)
#   layers.10.0.weight                   [256, 128]  (32,768 params)
#   layers.10.2.weight                   [128, 256]  (32,768 params)
#   layers.11.0.weight                   [256, 128]  (32,768 params)
#   layers.11.2.weight                   [128, 256]  (32,768 params)
#   layers.12.0.weight                   [256, 128]  (32,768 params)
#   layers.12.2.weight                   [128, 256]  (32,768 params)
#   layers.13.0.weight                   [256, 128]  (32,768 params)
#   layers.13.2.weight                   [128, 256]  (32,768 params)
#   layers.14.0.weight                   [256, 128]  (32,768 params)
#   layers.14.2.weight                   [128, 256]  (32,768 params)
#   layers.15.0.weight                   [256, 128]  (32,768 params)
#   layers.15.2.weight                   [128, 256]  (32,768 params)
#   proj_out.weight                       [20, 128]  ( 2,560 params)

# %% [markdown]
# ## 1.3) Train

# %%
# ── Hyperparameters ──
LR = 1e-3
WEIGHT_DECAY = 0.001
MAX_EPOCHS = 200

all_runs = []  # global: stores {"name", "converged_epoch", "history"} per run

def evaluate(loader):
    model.eval()
    total_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for xb, yb in loader:
            logits = model(xb)
            total_loss += criterion(logits, yb).item() * len(yb)
            correct += (logits.argmax(dim=1) == yb).sum().item()
            total += len(yb)
    return total_loss / total, correct / total

def train(run_name="", norm_type=None, is_post_norm=False):
    # Reset model and optimizer
    global model, optimizer, criterion, history
    resetRandom()
    model = DNN(norm_type=norm_type, is_post_norm=is_post_norm).to(device)
    model = torch.compile(model)
    def _init_weights(m):
        if hasattr(m, 'weight') and m.weight.dim() >= 2:
            nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
    model.apply(_init_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    criterion = nn.CrossEntropyLoss()

    # Reset logging
    history = {
        "epoch": [], "train_loss": [], "test_loss": [],
        "train_acc": [], "test_acc": []
    }

    print(f"{'='*60}")
    print(f"  🚀 Run: {run_name}")
    print(f"{'='*60}")

    # ── Training loop ──
    reached_100 = False

    for epoch in range(1, MAX_EPOCHS + 1):
        model.train()
        for xb, yb in train_loader:
            logits = model(xb)
            loss = criterion(logits, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_loss, train_acc = evaluate(train_loader)
        test_loss, test_acc   = evaluate(test_loader)

        history["epoch"].append(epoch)
        history["train_loss"].append(train_loss)
        history["test_loss"].append(test_loss)
        history["train_acc"].append(train_acc)
        history["test_acc"].append(test_acc)

        print(f"Epoch {epoch:>6d} | "
              f"Train loss {train_loss:.4f}  acc {train_acc:.1%} | "
              f"Test loss {test_loss:.4f}  acc {test_acc:.1%}")

        if test_acc == 1.00 and train_acc == 1.00:
            print(f"{'='*60}")
            print(f"  ✅ 100% test accuracy reached at epoch {epoch}!")
            print(f"  📊 Final — Train: {train_acc:.2%}  Test: {test_acc:.2%}")
            print(f"{'='*60}")
            reached_100 = True
            break

    if not reached_100:
        print(f"⚠️  Did not reach 100% in {MAX_EPOCHS} epochs.")
        print(f"    Final test acc: {history['test_acc'][-1]:.1%}")

    converged_epoch = epoch if reached_100 else None
    all_runs.append({"name": run_name,
                     "converged_epoch": converged_epoch,
                     "history": dict(history),
                     "model": copy.deepcopy(model)})

# %% [markdown]
# # 2) Baseline: no normalization

# %%
train(run_name="no normalization")
# Out:
# ============================================================
#   🚀 Run: no normalization
# ============================================================
# Epoch      1 | Train loss 2.4955  acc 30.8% | Test loss 2.5556  acc 30.0%
# Epoch      2 | Train loss 2.2187  acc 28.8% | Test loss 2.2666  acc 28.0%
# Epoch      3 | Train loss 2.1026  acc 33.5% | Test loss 2.1670  acc 32.3%
# Epoch      4 | Train loss 1.9265  acc 35.2% | Test loss 1.9882  acc 33.7%
# Epoch      5 | Train loss 1.8471  acc 37.3% | Test loss 1.9187  acc 34.9%
# Epoch      6 | Train loss 1.6706  acc 42.2% | Test loss 1.7563  acc 39.7%
# Epoch      7 | Train loss 1.4884  acc 47.4% | Test loss 1.5761  acc 45.1%
# Epoch      8 | Train loss 1.2619  acc 52.4% | Test loss 1.3350  acc 49.9%
# Epoch      9 | Train loss 1.1502  acc 54.4% | Test loss 1.2114  acc 52.4%
# Epoch     10 | Train loss 1.0995  acc 55.3% | Test loss 1.1520  acc 53.3%
# Epoch     11 | Train loss 1.0704  acc 55.6% | Test loss 1.1171  acc 53.7%
# Epoch     12 | Train loss 1.0747  acc 55.5% | Test loss 1.1142  acc 53.9%
# Epoch     13 | Train loss 1.0609  acc 55.4% | Test loss 1.0962  acc 53.9%
# Epoch     14 | Train loss 1.0486  acc 55.5% | Test loss 1.0820  acc 53.7%
# Epoch     15 | Train loss 1.0457  acc 55.5% | Test loss 1.0733  acc 54.3%
# Epoch     16 | Train loss 1.0348  acc 55.7% | Test loss 1.0624  acc 53.8%
# Epoch     17 | Train loss 1.0437  acc 55.8% | Test loss 1.0716  acc 54.3%
# Epoch     18 | Train loss 0.9743  acc 59.8% | Test loss 0.9956  acc 58.8%
# Epoch     19 | Train loss 0.9245  acc 61.3% | Test loss 0.9475  acc 59.8%
# Epoch     20 | Train loss 0.8745  acc 62.3% | Test loss 0.8900  acc 61.7%
# Epoch     21 | Train loss 0.8664  acc 62.7% | Test loss 0.8834  acc 61.4%
# Epoch     22 | Train loss 0.8606  acc 62.8% | Test loss 0.8808  acc 61.5%
# Epoch     23 | Train loss 0.8472  acc 63.3% | Test loss 0.8699  acc 61.8%
# Epoch     24 | Train loss 0.8117  acc 64.6% | Test loss 0.8310  acc 63.5%
# Epoch     25 | Train loss 0.7054  acc 69.4% | Test loss 0.7245  acc 68.4%
# Epoch     26 | Train loss 0.5185  acc 75.1% | Test loss 0.5389  acc 73.8%
# Epoch     27 | Train loss 0.4259  acc 78.4% | Test loss 0.4372  acc 77.5%
# Epoch     28 | Train loss 0.4136  acc 80.0% | Test loss 0.4265  acc 78.9%
# Epoch     29 | Train loss 0.3915  acc 80.9% | Test loss 0.4078  acc 79.8%
# Epoch     30 | Train loss 0.3113  acc 83.7% | Test loss 0.3231  acc 83.0%
# Epoch     31 | Train loss 0.3081  acc 83.6% | Test loss 0.3201  acc 82.9%
# Epoch     32 | Train loss 0.2852  acc 85.2% | Test loss 0.2957  acc 84.1%
# Epoch     33 | Train loss 0.2679  acc 86.7% | Test loss 0.2804  acc 86.0%
# Epoch     34 | Train loss 0.2224  acc 88.8% | Test loss 0.2305  acc 88.1%
# Epoch     35 | Train loss 0.1794  acc 90.3% | Test loss 0.1851  acc 89.8%
# Epoch     36 | Train loss 0.1809  acc 90.5% | Test loss 0.1899  acc 89.9%
# Epoch     37 | Train loss 0.1754  acc 90.5% | Test loss 0.1819  acc 89.8%
# Epoch     38 | Train loss 0.1843  acc 90.5% | Test loss 0.1929  acc 89.7%
# Epoch     39 | Train loss 0.1424  acc 92.9% | Test loss 0.1514  acc 92.1%
# Epoch     40 | Train loss 0.1369  acc 94.0% | Test loss 0.1484  acc 93.6%
# Epoch     41 | Train loss 0.0948  acc 96.4% | Test loss 0.1009  acc 96.1%
# Epoch     42 | Train loss 0.0772  acc 97.7% | Test loss 0.0777  acc 97.5%
# Epoch     43 | Train loss 0.0388  acc 98.4% | Test loss 0.0423  acc 98.2%
# Epoch     44 | Train loss 0.0410  acc 98.3% | Test loss 0.0450  acc 98.2%
# Epoch     45 | Train loss 0.0867  acc 96.8% | Test loss 0.0943  acc 96.5%
# Epoch     46 | Train loss 0.0433  acc 98.2% | Test loss 0.0475  acc 97.9%
# Epoch     47 | Train loss 0.0436  acc 98.1% | Test loss 0.0468  acc 98.0%
# Epoch     48 | Train loss 0.0429  acc 98.5% | Test loss 0.0485  acc 98.4%
# Epoch     49 | Train loss 0.0558  acc 98.1% | Test loss 0.0594  acc 98.0%
# Epoch     50 | Train loss 0.0757  acc 97.9% | Test loss 0.0805  acc 97.6%
# Epoch     51 | Train loss 0.0571  acc 98.0% | Test loss 0.0627  acc 97.8%
# Epoch     52 | Train loss 0.0329  acc 98.9% | Test loss 0.0361  acc 98.8%
# Epoch     53 | Train loss 0.0297  acc 98.9% | Test loss 0.0304  acc 98.9%
# Epoch     54 | Train loss 0.0540  acc 98.5% | Test loss 0.0543  acc 98.5%
# Epoch     55 | Train loss 0.0452  acc 98.4% | Test loss 0.0496  acc 98.2%
# Epoch     56 | Train loss 0.0170  acc 99.5% | Test loss 0.0209  acc 99.3%
# Epoch     57 | Train loss 0.0186  acc 99.4% | Test loss 0.0229  acc 99.3%
# Epoch     58 | Train loss 0.0236  acc 99.1% | Test loss 0.0239  acc 99.1%
# Epoch     59 | Train loss 0.0262  acc 99.4% | Test loss 0.0291  acc 99.3%
# Epoch     60 | Train loss 0.0153  acc 99.5% | Test loss 0.0176  acc 99.5%
# Epoch     61 | Train loss 0.0459  acc 98.8% | Test loss 0.0502  acc 98.7%
# Epoch     62 | Train loss 0.0137  acc 99.6% | Test loss 0.0138  acc 99.6%
# Epoch     63 | Train loss 0.0140  acc 99.6% | Test loss 0.0149  acc 99.5%
# Epoch     64 | Train loss 0.0422  acc 98.6% | Test loss 0.0439  acc 98.5%
# Epoch     65 | Train loss 0.0239  acc 99.4% | Test loss 0.0265  acc 99.3%
# Epoch     66 | Train loss 0.0159  acc 99.5% | Test loss 0.0186  acc 99.5%
# Epoch     67 | Train loss 0.0213  acc 99.3% | Test loss 0.0213  acc 99.3%
# Epoch     68 | Train loss 0.0181  acc 99.4% | Test loss 0.0183  acc 99.4%
# Epoch     69 | Train loss 0.0602  acc 98.2% | Test loss 0.0630  acc 98.0%
# Epoch     70 | Train loss 0.0180  acc 99.4% | Test loss 0.0197  acc 99.4%
# Epoch     71 | Train loss 0.0276  acc 99.3% | Test loss 0.0302  acc 99.2%
# Epoch     72 | Train loss 0.0116  acc 99.7% | Test loss 0.0132  acc 99.6%
# Epoch     73 | Train loss 0.0178  acc 99.4% | Test loss 0.0201  acc 99.3%
# Epoch     74 | Train loss 0.0088  acc 99.7% | Test loss 0.0103  acc 99.7%
# Epoch     75 | Train loss 0.0399  acc 99.0% | Test loss 0.0391  acc 98.9%
# Epoch     76 | Train loss 0.0111  acc 99.6% | Test loss 0.0123  acc 99.6%
# Epoch     77 | Train loss 0.0174  acc 99.5% | Test loss 0.0172  acc 99.6%
# Epoch     78 | Train loss 0.0418  acc 98.7% | Test loss 0.0452  acc 98.6%
# Epoch     79 | Train loss 0.0213  acc 99.4% | Test loss 0.0239  acc 99.3%
# Epoch     80 | Train loss 0.0091  acc 99.7% | Test loss 0.0101  acc 99.6%
# Epoch     81 | Train loss 0.0451  acc 98.7% | Test loss 0.0471  acc 98.7%
# Epoch     82 | Train loss 0.0124  acc 99.6% | Test loss 0.0139  acc 99.6%
# Epoch     83 | Train loss 0.0103  acc 99.7% | Test loss 0.0113  acc 99.6%
# Epoch     84 | Train loss 0.0099  acc 99.7% | Test loss 0.0101  acc 99.7%
# Epoch     85 | Train loss 0.0092  acc 99.7% | Test loss 0.0091  acc 99.7%
# Epoch     86 | Train loss 0.0139  acc 99.5% | Test loss 0.0129  acc 99.6%
# Epoch     87 | Train loss 0.0320  acc 99.0% | Test loss 0.0354  acc 98.9%
# Epoch     88 | Train loss 0.0053  acc 99.9% | Test loss 0.0062  acc 99.8%
# Epoch     89 | Train loss 0.0079  acc 99.8% | Test loss 0.0082  acc 99.8%
# Epoch     90 | Train loss 0.0088  acc 99.7% | Test loss 0.0091  acc 99.8%
# Epoch     91 | Train loss 0.0211  acc 99.3% | Test loss 0.0255  acc 99.2%
# Epoch     92 | Train loss 0.0196  acc 99.6% | Test loss 0.0220  acc 99.6%
# Epoch     93 | Train loss 0.0171  acc 99.5% | Test loss 0.0183  acc 99.4%
# Epoch     94 | Train loss 0.0171  acc 99.4% | Test loss 0.0195  acc 99.4%
# Epoch     95 | Train loss 0.0311  acc 99.2% | Test loss 0.0311  acc 99.3%
# Epoch     96 | Train loss 0.0188  acc 99.4% | Test loss 0.0222  acc 99.3%
# Epoch     97 | Train loss 0.0018  acc 99.9% | Test loss 0.0024  acc 99.9%
# Epoch     98 | Train loss 0.0101  acc 99.6% | Test loss 0.0104  acc 99.6%
# Epoch     99 | Train loss 0.0270  acc 99.1% | Test loss 0.0271  acc 99.1%
# Epoch    100 | Train loss 0.0138  acc 99.6% | Test loss 0.0159  acc 99.6%
# Epoch    101 | Train loss 0.0184  acc 99.4% | Test loss 0.0197  acc 99.4%
# Epoch    102 | Train loss 0.0119  acc 99.7% | Test loss 0.0137  acc 99.7%
# Epoch    103 | Train loss 0.0141  acc 99.7% | Test loss 0.0161  acc 99.6%
# Epoch    104 | Train loss 0.0160  acc 99.5% | Test loss 0.0177  acc 99.5%
# Epoch    105 | Train loss 0.0033  acc 99.9% | Test loss 0.0030  acc 99.9%
# Epoch    106 | Train loss 0.0462  acc 98.6% | Test loss 0.0461  acc 98.6%
# Epoch    107 | Train loss 0.0127  acc 99.7% | Test loss 0.0116  acc 99.7%
# Epoch    108 | Train loss 0.0136  acc 99.6% | Test loss 0.0146  acc 99.5%
# Epoch    109 | Train loss 0.0168  acc 99.5% | Test loss 0.0196  acc 99.4%
# Epoch    110 | Train loss 0.0400  acc 99.0% | Test loss 0.0452  acc 98.9%
# Epoch    111 | Train loss 0.0065  acc 99.8% | Test loss 0.0071  acc 99.8%
# Epoch    112 | Train loss 0.0043  acc 99.9% | Test loss 0.0041  acc 99.9%
# Epoch    113 | Train loss 0.0043  acc 99.9% | Test loss 0.0056  acc 99.9%
# Epoch    114 | Train loss 0.0269  acc 99.2% | Test loss 0.0266  acc 99.2%
# Epoch    115 | Train loss 0.0194  acc 99.4% | Test loss 0.0214  acc 99.4%
# Epoch    116 | Train loss 0.0084  acc 99.7% | Test loss 0.0091  acc 99.7%
# Epoch    117 | Train loss 0.0155  acc 99.5% | Test loss 0.0149  acc 99.5%
# Epoch    118 | Train loss 0.0139  acc 99.5% | Test loss 0.0142  acc 99.5%
# Epoch    119 | Train loss 0.0040  acc 99.9% | Test loss 0.0048  acc 99.8%
# Epoch    120 | Train loss 0.0196  acc 99.3% | Test loss 0.0214  acc 99.3%
# Epoch    121 | Train loss 0.0139  acc 99.7% | Test loss 0.0138  acc 99.7%
# Epoch    122 | Train loss 0.0040  acc 99.9% | Test loss 0.0035  acc 99.9%
# Epoch    123 | Train loss 0.0849  acc 97.9% | Test loss 0.0869  acc 97.9%
# Epoch    124 | Train loss 0.0073  acc 99.7% | Test loss 0.0085  acc 99.7%
# Epoch    125 | Train loss 0.0075  acc 99.8% | Test loss 0.0076  acc 99.7%
# Epoch    126 | Train loss 0.0026  acc 99.9% | Test loss 0.0032  acc 99.9%
# Epoch    127 | Train loss 0.0461  acc 98.7% | Test loss 0.0494  acc 98.7%
# Epoch    128 | Train loss 0.0014  acc 100.0% | Test loss 0.0027  acc 99.9%
# Epoch    129 | Train loss 0.0122  acc 99.6% | Test loss 0.0121  acc 99.6%
# Epoch    130 | Train loss 0.0007  acc 100.0% | Test loss 0.0009  acc 100.0%
# Epoch    131 | Train loss 0.0004  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    132 | Train loss 0.0000  acc 100.0% | Test loss 0.0003  acc 100.0%
# Epoch    133 | Train loss 0.0000  acc 100.0% | Test loss 0.0003  acc 100.0%
# Epoch    134 | Train loss 0.0000  acc 100.0% | Test loss 0.0002  acc 100.0%
# Epoch    135 | Train loss 0.0000  acc 100.0% | Test loss 0.0002  acc 100.0%
# Epoch    136 | Train loss 0.0007  acc 100.0% | Test loss 0.0010  acc 100.0%
# Epoch    137 | Train loss 0.0078  acc 99.8% | Test loss 0.0094  acc 99.8%
# Epoch    138 | Train loss 0.0190  acc 99.4% | Test loss 0.0201  acc 99.3%
# Epoch    139 | Train loss 0.0100  acc 99.7% | Test loss 0.0105  acc 99.7%
# Epoch    140 | Train loss 0.0096  acc 99.8% | Test loss 0.0139  acc 99.8%
# Epoch    141 | Train loss 0.0167  acc 99.7% | Test loss 0.0163  acc 99.7%
# Epoch    142 | Train loss 0.0038  acc 99.9% | Test loss 0.0045  acc 99.8%
# Epoch    143 | Train loss 0.0007  acc 100.0% | Test loss 0.0014  acc 100.0%
# Epoch    144 | Train loss 0.0130  acc 99.5% | Test loss 0.0145  acc 99.5%
# Epoch    145 | Train loss 0.0024  acc 99.9% | Test loss 0.0036  acc 99.9%
# Epoch    146 | Train loss 0.0002  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    147 | Train loss 0.0117  acc 99.7% | Test loss 0.0138  acc 99.6%
# Epoch    148 | Train loss 0.0091  acc 99.8% | Test loss 0.0083  acc 99.8%
# Epoch    149 | Train loss 0.0009  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    150 | Train loss 0.0146  acc 99.6% | Test loss 0.0160  acc 99.5%
# Epoch    151 | Train loss 0.0061  acc 99.8% | Test loss 0.0072  acc 99.8%
# Epoch    152 | Train loss 0.0040  acc 99.9% | Test loss 0.0046  acc 99.9%
# Epoch    153 | Train loss 0.0149  acc 99.7% | Test loss 0.0177  acc 99.7%
# Epoch    154 | Train loss 0.0211  acc 99.2% | Test loss 0.0213  acc 99.2%
# Epoch    155 | Train loss 0.0116  acc 99.7% | Test loss 0.0176  acc 99.6%
# Epoch    156 | Train loss 0.0015  acc 100.0% | Test loss 0.0021  acc 99.9%
# Epoch    157 | Train loss 0.0007  acc 100.0% | Test loss 0.0018  acc 100.0%
# Epoch    158 | Train loss 0.0120  acc 99.8% | Test loss 0.0126  acc 99.8%
# Epoch    159 | Train loss 0.0017  acc 100.0% | Test loss 0.0014  acc 100.0%
# Epoch    160 | Train loss 0.0186  acc 99.4% | Test loss 0.0195  acc 99.4%
# Epoch    161 | Train loss 0.0018  acc 100.0% | Test loss 0.0030  acc 99.9%
# Epoch    162 | Train loss 0.0057  acc 99.8% | Test loss 0.0065  acc 99.8%
# Epoch    163 | Train loss 0.0186  acc 99.4% | Test loss 0.0227  acc 99.3%
# Epoch    164 | Train loss 0.0010  acc 100.0% | Test loss 0.0020  acc 100.0%
# Epoch    165 | Train loss 0.0182  acc 99.4% | Test loss 0.0191  acc 99.4%
# Epoch    166 | Train loss 0.0009  acc 100.0% | Test loss 0.0011  acc 100.0%
# Epoch    167 | Train loss 0.0072  acc 99.8% | Test loss 0.0068  acc 99.8%
# Epoch    168 | Train loss 0.0030  acc 99.9% | Test loss 0.0034  acc 99.9%
# Epoch    169 | Train loss 0.0345  acc 98.9% | Test loss 0.0355  acc 98.8%
# Epoch    170 | Train loss 0.0050  acc 99.9% | Test loss 0.0050  acc 99.8%
# Epoch    171 | Train loss 0.0051  acc 99.9% | Test loss 0.0056  acc 99.8%
# Epoch    172 | Train loss 0.0548  acc 98.2% | Test loss 0.0578  acc 98.2%
# Epoch    173 | Train loss 0.0055  acc 99.8% | Test loss 0.0064  acc 99.8%
# Epoch    174 | Train loss 0.0004  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    175 | Train loss 0.0009  acc 100.0% | Test loss 0.0014  acc 100.0%
# Epoch    176 | Train loss 0.0132  acc 99.6% | Test loss 0.0144  acc 99.6%
# Epoch    177 | Train loss 0.0088  acc 99.8% | Test loss 0.0104  acc 99.7%
# Epoch    178 | Train loss 0.0211  acc 99.5% | Test loss 0.0217  acc 99.5%
# Epoch    179 | Train loss 0.0005  acc 100.0% | Test loss 0.0010  acc 100.0%
# Epoch    180 | Train loss 0.0134  acc 99.9% | Test loss 0.0111  acc 99.9%
# Epoch    181 | Train loss 0.0274  acc 99.2% | Test loss 0.0294  acc 99.2%
# Epoch    182 | Train loss 0.0019  acc 100.0% | Test loss 0.0033  acc 99.9%
# Epoch    183 | Train loss 0.0010  acc 100.0% | Test loss 0.0014  acc 100.0%
# Epoch    184 | Train loss 0.0001  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    185 | Train loss 0.0000  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    186 | Train loss 0.0000  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    187 | Train loss 0.0000  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    188 | Train loss 0.0000  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    189 | Train loss 0.0000  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch    190 | Train loss 0.0000  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch    191 | Train loss 0.0000  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch    192 | Train loss 0.0000  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    193 | Train loss 0.0000  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch    194 | Train loss 0.0000  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    195 | Train loss 0.0000  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    196 | Train loss 0.0000  acc 100.0% | Test loss 0.0009  acc 100.0%
# Epoch    197 | Train loss 0.0000  acc 100.0% | Test loss 0.0009  acc 100.0%
# Epoch    198 | Train loss 0.0858  acc 97.6% | Test loss 0.0933  acc 97.4%
# Epoch    199 | Train loss 0.0084  acc 99.8% | Test loss 0.0082  acc 99.9%
# Epoch    200 | Train loss 0.0151  acc 99.5% | Test loss 0.0153  acc 99.5%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 99.5%

# %% [markdown]
# # 3) Pre-norm RMSNorm

# %%
train(run_name="pre-norm RMSNorm", norm_type=nn.RMSNorm)
# Out:
# ============================================================
#   🚀 Run: pre-norm RMSNorm
# ============================================================
# Epoch      1 | Train loss 1.3267  acc 52.3% | Test loss 1.3792  acc 50.8%
# Epoch      2 | Train loss 1.1334  acc 55.2% | Test loss 1.1627  acc 53.9%
# Epoch      3 | Train loss 1.1164  acc 54.9% | Test loss 1.1492  acc 53.5%
# Epoch      4 | Train loss 0.9784  acc 60.1% | Test loss 1.0065  acc 58.5%
# Epoch      5 | Train loss 0.9388  acc 61.5% | Test loss 0.9653  acc 60.1%
# Epoch      6 | Train loss 0.9277  acc 61.9% | Test loss 0.9544  acc 60.4%
# Epoch      7 | Train loss 0.8232  acc 68.0% | Test loss 0.8451  acc 66.9%
# Epoch      8 | Train loss 0.7484  acc 71.4% | Test loss 0.7683  acc 70.4%
# Epoch      9 | Train loss 0.7160  acc 72.3% | Test loss 0.7361  acc 71.0%
# Epoch     10 | Train loss 0.6757  acc 73.3% | Test loss 0.6962  acc 72.6%
# Epoch     11 | Train loss 0.6211  acc 77.0% | Test loss 0.6441  acc 75.8%
# Epoch     12 | Train loss 0.5361  acc 81.1% | Test loss 0.5542  acc 80.2%
# Epoch     13 | Train loss 0.4969  acc 82.7% | Test loss 0.5150  acc 82.1%
# Epoch     14 | Train loss 0.4941  acc 82.8% | Test loss 0.5118  acc 82.3%
# Epoch     15 | Train loss 0.4823  acc 83.1% | Test loss 0.4983  acc 82.3%
# Epoch     16 | Train loss 0.4875  acc 82.8% | Test loss 0.5108  acc 82.1%
# Epoch     17 | Train loss 0.4611  acc 83.2% | Test loss 0.4844  acc 82.2%
# Epoch     18 | Train loss 0.4575  acc 83.3% | Test loss 0.4835  acc 82.4%
# Epoch     19 | Train loss 0.4417  acc 84.1% | Test loss 0.4719  acc 82.9%
# Epoch     20 | Train loss 0.3798  acc 86.5% | Test loss 0.4102  acc 85.3%
# Epoch     21 | Train loss 0.3295  acc 88.2% | Test loss 0.3619  acc 86.9%
# Epoch     22 | Train loss 0.2866  acc 89.5% | Test loss 0.3219  acc 88.2%
# Epoch     23 | Train loss 0.2110  acc 91.8% | Test loss 0.2404  acc 90.5%
# Epoch     24 | Train loss 0.1769  acc 93.4% | Test loss 0.2055  acc 92.1%
# Epoch     25 | Train loss 0.1578  acc 94.1% | Test loss 0.1816  acc 93.0%
# Epoch     26 | Train loss 0.1696  acc 94.0% | Test loss 0.1972  acc 93.0%
# Epoch     27 | Train loss 0.1372  acc 95.0% | Test loss 0.1639  acc 94.0%
# Epoch     28 | Train loss 0.1400  acc 95.1% | Test loss 0.1648  acc 94.0%
# Epoch     29 | Train loss 0.1342  acc 95.3% | Test loss 0.1609  acc 94.3%
# Epoch     30 | Train loss 0.1027  acc 96.2% | Test loss 0.1316  acc 95.3%
# Epoch     31 | Train loss 0.0746  acc 96.9% | Test loss 0.1021  acc 95.8%
# Epoch     32 | Train loss 0.0589  acc 97.9% | Test loss 0.0788  acc 97.0%
# Epoch     33 | Train loss 0.0582  acc 98.0% | Test loss 0.0754  acc 97.2%
# Epoch     34 | Train loss 0.0285  acc 99.2% | Test loss 0.0408  acc 98.6%
# Epoch     35 | Train loss 0.0433  acc 98.7% | Test loss 0.0601  acc 98.2%
# Epoch     36 | Train loss 0.0457  acc 98.8% | Test loss 0.0613  acc 98.3%
# Epoch     37 | Train loss 0.0233  acc 99.2% | Test loss 0.0340  acc 98.9%
# Epoch     38 | Train loss 0.0144  acc 99.5% | Test loss 0.0218  acc 99.2%
# Epoch     39 | Train loss 0.0113  acc 99.7% | Test loss 0.0204  acc 99.4%
# Epoch     40 | Train loss 0.0250  acc 99.2% | Test loss 0.0339  acc 98.9%
# Epoch     41 | Train loss 0.0073  acc 99.8% | Test loss 0.0133  acc 99.6%
# Epoch     42 | Train loss 0.0192  acc 99.4% | Test loss 0.0218  acc 99.3%
# Epoch     43 | Train loss 0.0132  acc 99.6% | Test loss 0.0196  acc 99.4%
# Epoch     44 | Train loss 0.0253  acc 99.3% | Test loss 0.0361  acc 98.9%
# Epoch     45 | Train loss 0.0054  acc 99.9% | Test loss 0.0090  acc 99.7%
# Epoch     46 | Train loss 0.0091  acc 99.7% | Test loss 0.0141  acc 99.6%
# Epoch     47 | Train loss 0.0488  acc 98.9% | Test loss 0.0568  acc 98.7%
# Epoch     48 | Train loss 0.0295  acc 99.3% | Test loss 0.0317  acc 99.2%
# Epoch     49 | Train loss 0.0067  acc 99.8% | Test loss 0.0088  acc 99.7%
# Epoch     50 | Train loss 0.0132  acc 99.6% | Test loss 0.0192  acc 99.5%
# Epoch     51 | Train loss 0.0138  acc 99.6% | Test loss 0.0178  acc 99.5%
# Epoch     52 | Train loss 0.0169  acc 99.6% | Test loss 0.0199  acc 99.5%
# Epoch     53 | Train loss 0.0013  acc 100.0% | Test loss 0.0029  acc 99.9%
# Epoch     54 | Train loss 0.0063  acc 99.8% | Test loss 0.0075  acc 99.8%
# Epoch     55 | Train loss 0.0753  acc 99.1% | Test loss 0.0889  acc 98.9%
# Epoch     56 | Train loss 0.0177  acc 99.5% | Test loss 0.0210  acc 99.4%
# Epoch     57 | Train loss 0.0098  acc 99.8% | Test loss 0.0124  acc 99.7%
# Epoch     58 | Train loss 0.0056  acc 99.8% | Test loss 0.0087  acc 99.8%
# Epoch     59 | Train loss 0.0019  acc 99.9% | Test loss 0.0034  acc 99.9%
# Epoch     60 | Train loss 0.0053  acc 99.9% | Test loss 0.0055  acc 99.8%
# Epoch     61 | Train loss 0.0102  acc 99.7% | Test loss 0.0111  acc 99.7%
# Epoch     62 | Train loss 0.0039  acc 99.9% | Test loss 0.0066  acc 99.8%
# Epoch     63 | Train loss 0.0040  acc 99.9% | Test loss 0.0055  acc 99.8%
# Epoch     64 | Train loss 0.0097  acc 99.8% | Test loss 0.0121  acc 99.7%
# Epoch     65 | Train loss 0.0076  acc 99.8% | Test loss 0.0120  acc 99.7%
# Epoch     66 | Train loss 0.0127  acc 99.7% | Test loss 0.0147  acc 99.6%
# Epoch     67 | Train loss 0.0021  acc 99.9% | Test loss 0.0029  acc 99.9%
# Epoch     68 | Train loss 0.0089  acc 99.7% | Test loss 0.0119  acc 99.6%
# Epoch     69 | Train loss 0.0021  acc 99.9% | Test loss 0.0039  acc 99.9%
# Epoch     70 | Train loss 0.0041  acc 99.9% | Test loss 0.0065  acc 99.8%
# Epoch     71 | Train loss 0.0104  acc 99.7% | Test loss 0.0142  acc 99.6%
# Epoch     72 | Train loss 0.0108  acc 99.8% | Test loss 0.0152  acc 99.7%
# Epoch     73 | Train loss 0.0040  acc 99.9% | Test loss 0.0052  acc 99.9%
# Epoch     74 | Train loss 0.0007  acc 100.0% | Test loss 0.0009  acc 100.0%
# Epoch     75 | Train loss 0.0032  acc 99.9% | Test loss 0.0056  acc 99.9%
# Epoch     76 | Train loss 0.0131  acc 99.6% | Test loss 0.0200  acc 99.5%
# Epoch     77 | Train loss 0.0007  acc 100.0% | Test loss 0.0013  acc 100.0%
# Epoch     78 | Train loss 0.0007  acc 100.0% | Test loss 0.0010  acc 100.0%
# Epoch     79 | Train loss 0.0072  acc 99.8% | Test loss 0.0082  acc 99.8%
# Epoch     80 | Train loss 0.0036  acc 99.9% | Test loss 0.0055  acc 99.9%
# Epoch     81 | Train loss 0.0005  acc 100.0% | Test loss 0.0010  acc 100.0%
# Epoch     82 | Train loss 0.0062  acc 99.8% | Test loss 0.0080  acc 99.8%
# Epoch     83 | Train loss 0.0089  acc 99.8% | Test loss 0.0103  acc 99.7%
# Epoch     84 | Train loss 0.0013  acc 100.0% | Test loss 0.0018  acc 99.9%
# Epoch     85 | Train loss 0.0013  acc 100.0% | Test loss 0.0035  acc 99.9%
# Epoch     86 | Train loss 0.0132  acc 99.7% | Test loss 0.0148  acc 99.6%
# Epoch     87 | Train loss 0.0131  acc 99.6% | Test loss 0.0185  acc 99.5%
# Epoch     88 | Train loss 0.0012  acc 100.0% | Test loss 0.0028  acc 99.9%
# Epoch     89 | Train loss 0.0018  acc 100.0% | Test loss 0.0030  acc 99.9%
# Epoch     90 | Train loss 0.0001  acc 100.0% | Test loss 0.0003  acc 100.0%
# Epoch     91 | Train loss 0.0011  acc 100.0% | Test loss 0.0019  acc 99.9%
# Epoch     92 | Train loss 0.0080  acc 99.8% | Test loss 0.0099  acc 99.7%
# Epoch     93 | Train loss 0.0002  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch     94 | Train loss 0.0000  acc 100.0% | Test loss 0.0001  acc 100.0%
# Epoch     95 | Train loss 0.0000  acc 100.0% | Test loss 0.0001  acc 100.0%
# ============================================================
#   ✅ 100% test accuracy reached at epoch 95!
#   📊 Final — Train: 100.00%  Test: 100.00%
# ============================================================

# %% [markdown]
# # 4) Post-norm RMSNorm

# %%
train(run_name="post-norm RMSNorm", norm_type=nn.RMSNorm, is_post_norm=True)
# Out:
# ============================================================
#   🚀 Run: post-norm RMSNorm
# ============================================================
# Epoch      1 | Train loss 1.9102  acc 35.6% | Test loss 1.9218  acc 35.5%
# Epoch      2 | Train loss 1.7565  acc 42.4% | Test loss 1.7624  acc 42.3%
# Epoch      3 | Train loss 1.8282  acc 38.7% | Test loss 1.8343  acc 38.6%
# Epoch      4 | Train loss 1.5656  acc 45.1% | Test loss 1.5741  acc 44.9%
# Epoch      5 | Train loss 2.1197  acc 34.5% | Test loss 2.1229  acc 34.1%
# Epoch      6 | Train loss 2.1693  acc 33.8% | Test loss 2.1732  acc 33.6%
# Epoch      7 | Train loss 2.1661  acc 33.8% | Test loss 2.1717  acc 33.2%
# Epoch      8 | Train loss 2.3028  acc 35.1% | Test loss 2.3090  acc 34.8%
# Epoch      9 | Train loss 2.1946  acc 34.7% | Test loss 2.1996  acc 34.4%
# Epoch     10 | Train loss 2.2021  acc 33.8% | Test loss 2.2034  acc 33.6%
# Epoch     11 | Train loss 2.2009  acc 33.8% | Test loss 2.2022  acc 33.6%
# Epoch     12 | Train loss 2.1985  acc 33.8% | Test loss 2.1985  acc 33.6%
# Epoch     13 | Train loss 2.2013  acc 33.8% | Test loss 2.2019  acc 33.6%
# Epoch     14 | Train loss 2.1998  acc 33.8% | Test loss 2.2016  acc 33.6%
# Epoch     15 | Train loss 2.1958  acc 33.8% | Test loss 2.1977  acc 33.6%
# Epoch     16 | Train loss 2.1989  acc 33.8% | Test loss 2.1983  acc 33.6%
# Epoch     17 | Train loss 2.1963  acc 33.8% | Test loss 2.1966  acc 33.6%
# Epoch     18 | Train loss 2.2003  acc 33.8% | Test loss 2.2029  acc 33.6%
# Epoch     19 | Train loss 2.1915  acc 33.8% | Test loss 2.1936  acc 33.6%
# Epoch     20 | Train loss 2.1902  acc 33.8% | Test loss 2.1927  acc 33.6%
# Epoch     21 | Train loss 2.1878  acc 33.8% | Test loss 2.1894  acc 33.6%
# Epoch     22 | Train loss 2.1883  acc 33.8% | Test loss 2.1897  acc 33.6%
# Epoch     23 | Train loss 2.1843  acc 33.8% | Test loss 2.1857  acc 33.6%
# Epoch     24 | Train loss 2.1683  acc 33.8% | Test loss 2.1714  acc 33.6%
# Epoch     25 | Train loss 2.1675  acc 33.8% | Test loss 2.1710  acc 33.6%
# Epoch     26 | Train loss 2.1665  acc 33.8% | Test loss 2.1706  acc 33.6%
# Epoch     27 | Train loss 2.1659  acc 33.8% | Test loss 2.1699  acc 33.6%
# Epoch     28 | Train loss 2.1649  acc 33.8% | Test loss 2.1688  acc 33.6%
# Epoch     29 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     30 | Train loss 2.3523  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch     31 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     32 | Train loss 2.3515  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     33 | Train loss 2.3517  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     34 | Train loss 2.3540  acc 33.8% | Test loss 2.3589  acc 33.6%
# Epoch     35 | Train loss 2.3530  acc 33.8% | Test loss 2.3578  acc 33.6%
# Epoch     36 | Train loss 2.3526  acc 33.8% | Test loss 2.3580  acc 33.6%
# Epoch     37 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     38 | Train loss 2.3520  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     39 | Train loss 2.3528  acc 33.8% | Test loss 2.3581  acc 33.6%
# Epoch     40 | Train loss 2.3517  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     41 | Train loss 2.3517  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch     42 | Train loss 2.3515  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     43 | Train loss 2.3522  acc 33.8% | Test loss 2.3572  acc 33.6%
# Epoch     44 | Train loss 2.3520  acc 33.8% | Test loss 2.3578  acc 33.6%
# Epoch     45 | Train loss 2.3518  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     46 | Train loss 2.3515  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     47 | Train loss 2.3519  acc 33.8% | Test loss 2.3574  acc 33.6%
# Epoch     48 | Train loss 2.3518  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     49 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     50 | Train loss 2.3519  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     51 | Train loss 2.3516  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     52 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     53 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     54 | Train loss 2.3513  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     55 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     56 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     57 | Train loss 2.3513  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     58 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     59 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     60 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     61 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     62 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     63 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     64 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     65 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     66 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     67 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     68 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     69 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     70 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     71 | Train loss 2.3516  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     72 | Train loss 2.3516  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     73 | Train loss 2.3512  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     74 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     75 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     76 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     77 | Train loss 2.3515  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     78 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     79 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     80 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     81 | Train loss 2.3513  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     82 | Train loss 2.3515  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     83 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     84 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     85 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     86 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     87 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     88 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     89 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     90 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     91 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     92 | Train loss 2.3512  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     93 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     94 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     95 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     96 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     97 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     98 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     99 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    100 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    101 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    102 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    103 | Train loss 2.3515  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    104 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    105 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    106 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    107 | Train loss 2.3509  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    108 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    109 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    110 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    111 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    112 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    113 | Train loss 2.3517  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch    114 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    115 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    116 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    117 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    118 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    119 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    120 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    121 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    122 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    123 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    124 | Train loss 2.3511  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    125 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    126 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    127 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    128 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    129 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    130 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    131 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    132 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    133 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    134 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    135 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    136 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    137 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    138 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    139 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    140 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    141 | Train loss 2.3509  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    142 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    143 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    144 | Train loss 2.3516  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    145 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    146 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    147 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    148 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    149 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    150 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    151 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    152 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    153 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    154 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    155 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    156 | Train loss 2.3510  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    157 | Train loss 2.3513  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    158 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    159 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    160 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    161 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    162 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    163 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    164 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    165 | Train loss 2.3518  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch    166 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    167 | Train loss 2.3512  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    168 | Train loss 2.3514  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch    169 | Train loss 2.3510  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    170 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    171 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    172 | Train loss 2.3515  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch    173 | Train loss 2.3512  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    174 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    175 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    176 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    177 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    178 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    179 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    180 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    181 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    182 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    183 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    184 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    185 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    186 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    187 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    188 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    189 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    190 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    191 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    192 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    193 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    194 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    195 | Train loss 2.3512  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    196 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    197 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    198 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    199 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    200 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 33.6%

# %% [markdown]
# # 5) Pre-norm LayerNorm

# %%
train(run_name="pre-norm LayerNorm", norm_type=nn.LayerNorm)
# Out:
# ============================================================
#   🚀 Run: pre-norm LayerNorm
# ============================================================
# W0401 02:11:17.694000 1428 torch/_dynamo/convert_frame.py:1676] [0/8] torch._dynamo hit config.recompile_limit (8)
# W0401 02:11:17.694000 1428 torch/_dynamo/convert_frame.py:1676] [0/8]    function: 'forward' (/tmp/ipykernel_1428/756787679.py:22)
# W0401 02:11:17.694000 1428 torch/_dynamo/convert_frame.py:1676] [0/8]    last reason: 0/7: GLOBAL_STATE changed: grad_mode
# W0401 02:11:17.694000 1428 torch/_dynamo/convert_frame.py:1676] [0/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0401 02:11:17.694000 1428 torch/_dynamo/convert_frame.py:1676] [0/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/compile/programming_model.recompilation.html
# Epoch      1 | Train loss 1.3583  acc 51.9% | Test loss 1.4216  acc 50.3%
# Epoch      2 | Train loss 1.1250  acc 55.4% | Test loss 1.1654  acc 53.9%
# Epoch      3 | Train loss 1.0746  acc 55.8% | Test loss 1.1165  acc 54.2%
# Epoch      4 | Train loss 0.9482  acc 61.5% | Test loss 0.9882  acc 59.6%
# Epoch      5 | Train loss 0.9484  acc 61.9% | Test loss 0.9844  acc 59.9%
# Epoch      6 | Train loss 0.8913  acc 64.6% | Test loss 0.9286  acc 62.7%
# Epoch      7 | Train loss 0.7548  acc 71.1% | Test loss 0.7811  acc 69.9%
# Epoch      8 | Train loss 0.6886  acc 73.8% | Test loss 0.7131  acc 72.8%
# Epoch      9 | Train loss 0.5933  acc 77.7% | Test loss 0.6151  acc 76.5%
# Epoch     10 | Train loss 0.5861  acc 77.8% | Test loss 0.6057  acc 76.9%
# Epoch     11 | Train loss 0.6035  acc 77.1% | Test loss 0.6273  acc 76.2%
# Epoch     12 | Train loss 0.5858  acc 77.9% | Test loss 0.6101  acc 76.8%
# Epoch     13 | Train loss 0.5725  acc 78.8% | Test loss 0.6032  acc 77.5%
# Epoch     14 | Train loss 0.4973  acc 82.7% | Test loss 0.5253  acc 81.9%
# Epoch     15 | Train loss 0.4748  acc 83.5% | Test loss 0.5049  acc 82.2%
# Epoch     16 | Train loss 0.4164  acc 84.2% | Test loss 0.4437  acc 83.1%
# Epoch     17 | Train loss 0.3617  acc 85.2% | Test loss 0.3882  acc 84.1%
# Epoch     18 | Train loss 0.3443  acc 85.8% | Test loss 0.3759  acc 84.4%
# Epoch     19 | Train loss 0.3137  acc 87.5% | Test loss 0.3476  acc 86.3%
# Epoch     20 | Train loss 0.2898  acc 88.4% | Test loss 0.3206  acc 86.9%
# Epoch     21 | Train loss 0.2823  acc 88.8% | Test loss 0.3176  acc 87.3%
# Epoch     22 | Train loss 0.2556  acc 90.2% | Test loss 0.2928  acc 88.8%
# Epoch     23 | Train loss 0.1985  acc 91.9% | Test loss 0.2281  acc 90.4%
# Epoch     24 | Train loss 0.1932  acc 92.3% | Test loss 0.2321  acc 90.5%
# Epoch     25 | Train loss 0.1719  acc 93.1% | Test loss 0.2131  acc 91.2%
# Epoch     26 | Train loss 0.1513  acc 94.0% | Test loss 0.1946  acc 92.2%
# Epoch     27 | Train loss 0.1159  acc 95.8% | Test loss 0.1537  acc 94.2%
# Epoch     28 | Train loss 0.0898  acc 96.6% | Test loss 0.1250  acc 95.2%
# Epoch     29 | Train loss 0.0877  acc 97.4% | Test loss 0.1149  acc 96.2%
# Epoch     30 | Train loss 0.0263  acc 99.0% | Test loss 0.0421  acc 98.3%
# Epoch     31 | Train loss 0.0283  acc 99.0% | Test loss 0.0412  acc 98.5%
# Epoch     32 | Train loss 0.0304  acc 99.0% | Test loss 0.0390  acc 98.7%
# Epoch     33 | Train loss 0.0330  acc 99.0% | Test loss 0.0427  acc 98.6%
# Epoch     34 | Train loss 0.0219  acc 99.4% | Test loss 0.0338  acc 99.1%
# Epoch     35 | Train loss 0.0270  acc 99.3% | Test loss 0.0367  acc 98.9%
# Epoch     36 | Train loss 0.0132  acc 99.6% | Test loss 0.0198  acc 99.3%
# Epoch     37 | Train loss 0.0125  acc 99.7% | Test loss 0.0203  acc 99.5%
# Epoch     38 | Train loss 0.0297  acc 99.3% | Test loss 0.0385  acc 99.1%
# Epoch     39 | Train loss 0.0074  acc 99.8% | Test loss 0.0125  acc 99.6%
# Epoch     40 | Train loss 0.0268  acc 99.3% | Test loss 0.0372  acc 99.1%
# Epoch     41 | Train loss 0.0318  acc 99.2% | Test loss 0.0386  acc 99.0%
# Epoch     42 | Train loss 0.0046  acc 99.9% | Test loss 0.0077  acc 99.8%
# Epoch     43 | Train loss 0.0038  acc 99.9% | Test loss 0.0058  acc 99.8%
# Epoch     44 | Train loss 0.0082  acc 99.8% | Test loss 0.0131  acc 99.6%
# Epoch     45 | Train loss 0.0063  acc 99.9% | Test loss 0.0069  acc 99.8%
# Epoch     46 | Train loss 0.0242  acc 99.6% | Test loss 0.0268  acc 99.5%
# Epoch     47 | Train loss 0.0202  acc 99.4% | Test loss 0.0286  acc 99.4%
# Epoch     48 | Train loss 0.0127  acc 99.7% | Test loss 0.0154  acc 99.6%
# Epoch     49 | Train loss 0.0012  acc 100.0% | Test loss 0.0026  acc 99.9%
# Epoch     50 | Train loss 0.0029  acc 99.9% | Test loss 0.0047  acc 99.8%
# Epoch     51 | Train loss 0.0324  acc 99.2% | Test loss 0.0431  acc 99.0%
# Epoch     52 | Train loss 0.0038  acc 99.9% | Test loss 0.0066  acc 99.8%
# Epoch     53 | Train loss 0.0009  acc 100.0% | Test loss 0.0015  acc 100.0%
# Epoch     54 | Train loss 0.0168  acc 99.6% | Test loss 0.0186  acc 99.5%
# Epoch     55 | Train loss 0.0028  acc 99.9% | Test loss 0.0029  acc 99.9%
# Epoch     56 | Train loss 0.0014  acc 100.0% | Test loss 0.0022  acc 99.9%
# Epoch     57 | Train loss 0.0001  acc 100.0% | Test loss 0.0003  acc 100.0%
# Epoch     58 | Train loss 0.0169  acc 99.5% | Test loss 0.0205  acc 99.4%
# Epoch     59 | Train loss 0.0053  acc 99.9% | Test loss 0.0061  acc 99.8%
# Epoch     60 | Train loss 0.0003  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch     61 | Train loss 0.0036  acc 99.9% | Test loss 0.0041  acc 99.9%
# Epoch     62 | Train loss 0.0125  acc 99.8% | Test loss 0.0158  acc 99.7%
# Epoch     63 | Train loss 0.0042  acc 99.9% | Test loss 0.0057  acc 99.8%
# Epoch     64 | Train loss 0.0018  acc 100.0% | Test loss 0.0027  acc 99.9%
# Epoch     65 | Train loss 0.0033  acc 99.9% | Test loss 0.0032  acc 99.9%
# Epoch     66 | Train loss 0.0017  acc 99.9% | Test loss 0.0024  acc 99.9%
# Epoch     67 | Train loss 0.0206  acc 99.6% | Test loss 0.0251  acc 99.5%
# Epoch     68 | Train loss 0.0007  acc 100.0% | Test loss 0.0015  acc 100.0%
# Epoch     69 | Train loss 0.0036  acc 99.9% | Test loss 0.0053  acc 99.9%
# Epoch     70 | Train loss 0.0083  acc 99.7% | Test loss 0.0134  acc 99.6%
# Epoch     71 | Train loss 0.0054  acc 99.8% | Test loss 0.0073  acc 99.8%
# Epoch     72 | Train loss 0.0042  acc 99.9% | Test loss 0.0056  acc 99.9%
# Epoch     73 | Train loss 0.0011  acc 100.0% | Test loss 0.0012  acc 100.0%
# Epoch     74 | Train loss 0.0038  acc 99.9% | Test loss 0.0062  acc 99.8%
# Epoch     75 | Train loss 0.0076  acc 99.9% | Test loss 0.0088  acc 99.8%
# Epoch     76 | Train loss 0.0068  acc 99.8% | Test loss 0.0083  acc 99.8%
# Epoch     77 | Train loss 0.0068  acc 99.8% | Test loss 0.0067  acc 99.8%
# Epoch     78 | Train loss 0.0008  acc 100.0% | Test loss 0.0027  acc 100.0%
# Epoch     79 | Train loss 0.0091  acc 99.8% | Test loss 0.0101  acc 99.8%
# Epoch     80 | Train loss 0.0050  acc 99.9% | Test loss 0.0062  acc 99.8%
# Epoch     81 | Train loss 0.0037  acc 99.9% | Test loss 0.0055  acc 99.9%
# Epoch     82 | Train loss 0.0082  acc 99.9% | Test loss 0.0089  acc 99.9%
# Epoch     83 | Train loss 0.0030  acc 99.9% | Test loss 0.0032  acc 99.9%
# Epoch     84 | Train loss 0.0137  acc 99.6% | Test loss 0.0165  acc 99.6%
# Epoch     85 | Train loss 0.0012  acc 100.0% | Test loss 0.0017  acc 99.9%
# Epoch     86 | Train loss 0.0000  acc 100.0% | Test loss 0.0001  acc 100.0%
# Epoch     87 | Train loss 0.0000  acc 100.0% | Test loss 0.0000  acc 100.0%
# ============================================================
#   ✅ 100% test accuracy reached at epoch 87!
#   📊 Final — Train: 100.00%  Test: 100.00%
# ============================================================

# %% [markdown]
# # 6) Post-norm LayerNorm

# %%
train(run_name="post-norm LayerNorm", norm_type=nn.LayerNorm, is_post_norm=True)
# Out:
# ============================================================
#   🚀 Run: post-norm LayerNorm
# ============================================================
# Epoch      1 | Train loss 1.8853  acc 34.9% | Test loss 1.8997  acc 34.6%
# Epoch      2 | Train loss 2.2011  acc 30.4% | Test loss 2.2009  acc 30.7%
# Epoch      3 | Train loss 2.2987  acc 33.8% | Test loss 2.3050  acc 33.6%
# Epoch      4 | Train loss 2.2935  acc 33.8% | Test loss 2.2998  acc 33.6%
# Epoch      5 | Train loss 2.2921  acc 33.8% | Test loss 2.2981  acc 33.6%
# Epoch      6 | Train loss 2.2961  acc 33.8% | Test loss 2.3027  acc 33.6%
# Epoch      7 | Train loss 2.2998  acc 33.8% | Test loss 2.3063  acc 33.6%
# Epoch      8 | Train loss 2.3064  acc 33.8% | Test loss 2.3122  acc 33.6%
# Epoch      9 | Train loss 2.3027  acc 33.8% | Test loss 2.3082  acc 33.6%
# Epoch     10 | Train loss 2.3022  acc 33.8% | Test loss 2.3091  acc 33.6%
# Epoch     11 | Train loss 2.3019  acc 33.8% | Test loss 2.3082  acc 33.6%
# Epoch     12 | Train loss 2.3007  acc 33.8% | Test loss 2.3062  acc 33.6%
# Epoch     13 | Train loss 2.2471  acc 33.8% | Test loss 2.2527  acc 33.6%
# Epoch     14 | Train loss 2.2469  acc 33.8% | Test loss 2.2533  acc 33.6%
# Epoch     15 | Train loss 2.2461  acc 33.8% | Test loss 2.2523  acc 33.6%
# Epoch     16 | Train loss 2.2463  acc 33.8% | Test loss 2.2511  acc 33.6%
# Epoch     17 | Train loss 2.2458  acc 33.8% | Test loss 2.2506  acc 33.6%
# Epoch     18 | Train loss 2.2442  acc 33.8% | Test loss 2.2493  acc 33.6%
# Epoch     19 | Train loss 2.2447  acc 33.8% | Test loss 2.2500  acc 33.6%
# Epoch     20 | Train loss 2.2446  acc 33.8% | Test loss 2.2498  acc 33.6%
# Epoch     21 | Train loss 2.2365  acc 33.8% | Test loss 2.2428  acc 33.6%
# Epoch     22 | Train loss 2.2377  acc 33.8% | Test loss 2.2444  acc 33.6%
# Epoch     23 | Train loss 2.2373  acc 33.8% | Test loss 2.2438  acc 33.6%
# Epoch     24 | Train loss 2.2365  acc 33.8% | Test loss 2.2430  acc 33.6%
# Epoch     25 | Train loss 2.2360  acc 33.8% | Test loss 2.2429  acc 33.6%
# Epoch     26 | Train loss 2.2348  acc 33.8% | Test loss 2.2414  acc 33.6%
# Epoch     27 | Train loss 2.2353  acc 33.8% | Test loss 2.2427  acc 33.6%
# Epoch     28 | Train loss 2.2260  acc 33.8% | Test loss 2.2315  acc 33.6%
# Epoch     29 | Train loss 2.2254  acc 33.8% | Test loss 2.2315  acc 33.6%
# Epoch     30 | Train loss 2.2263  acc 33.8% | Test loss 2.2320  acc 33.6%
# Epoch     31 | Train loss 2.1984  acc 33.8% | Test loss 2.2044  acc 33.6%
# Epoch     32 | Train loss 2.1972  acc 33.8% | Test loss 2.2032  acc 33.6%
# Epoch     33 | Train loss 2.1978  acc 33.8% | Test loss 2.2039  acc 33.6%
# Epoch     34 | Train loss 2.1989  acc 33.8% | Test loss 2.2041  acc 33.6%
# Epoch     35 | Train loss 2.1989  acc 33.8% | Test loss 2.2041  acc 33.6%
# Epoch     36 | Train loss 2.1982  acc 33.8% | Test loss 2.2041  acc 33.6%
# Epoch     37 | Train loss 2.1976  acc 33.8% | Test loss 2.2038  acc 33.6%
# Epoch     38 | Train loss 2.1987  acc 33.8% | Test loss 2.2035  acc 33.6%
# Epoch     39 | Train loss 2.1977  acc 33.8% | Test loss 2.2032  acc 33.6%
# Epoch     40 | Train loss 2.1962  acc 33.8% | Test loss 2.2015  acc 33.6%
# Epoch     41 | Train loss 2.3408  acc 33.8% | Test loss 2.3469  acc 33.6%
# Epoch     42 | Train loss 2.3388  acc 33.8% | Test loss 2.3445  acc 33.6%
# Epoch     43 | Train loss 2.3394  acc 33.8% | Test loss 2.3445  acc 33.6%
# Epoch     44 | Train loss 2.3401  acc 33.8% | Test loss 2.3461  acc 33.6%
# Epoch     45 | Train loss 2.3394  acc 33.8% | Test loss 2.3445  acc 33.6%
# Epoch     46 | Train loss 2.3354  acc 33.8% | Test loss 2.3406  acc 33.6%
# Epoch     47 | Train loss 2.3379  acc 33.8% | Test loss 2.3432  acc 33.6%
# Epoch     48 | Train loss 2.3369  acc 33.8% | Test loss 2.3412  acc 33.6%
# Epoch     49 | Train loss 2.3367  acc 33.8% | Test loss 2.3418  acc 33.6%
# Epoch     50 | Train loss 2.1985  acc 33.8% | Test loss 2.2034  acc 33.6%
# Epoch     51 | Train loss 2.1978  acc 33.8% | Test loss 2.2029  acc 33.6%
# Epoch     52 | Train loss 2.1974  acc 33.8% | Test loss 2.2017  acc 33.6%
# Epoch     53 | Train loss 2.1965  acc 33.8% | Test loss 2.2014  acc 33.6%
# Epoch     54 | Train loss 2.1969  acc 33.8% | Test loss 2.2018  acc 33.6%
# Epoch     55 | Train loss 2.1964  acc 33.8% | Test loss 2.2015  acc 33.6%
# Epoch     56 | Train loss 2.1975  acc 33.8% | Test loss 2.2022  acc 33.6%
# Epoch     57 | Train loss 2.1978  acc 33.8% | Test loss 2.2022  acc 33.6%
# Epoch     58 | Train loss 2.1974  acc 33.8% | Test loss 2.2025  acc 33.6%
# Epoch     59 | Train loss 2.1977  acc 33.8% | Test loss 2.2027  acc 33.6%
# Epoch     60 | Train loss 2.1977  acc 33.8% | Test loss 2.2026  acc 33.6%
# Epoch     61 | Train loss 2.1974  acc 33.8% | Test loss 2.2024  acc 33.6%
# Epoch     62 | Train loss 2.1973  acc 33.8% | Test loss 2.2025  acc 33.6%
# Epoch     63 | Train loss 2.2182  acc 33.8% | Test loss 2.2259  acc 33.6%
# Epoch     64 | Train loss 2.2178  acc 33.8% | Test loss 2.2251  acc 33.6%
# Epoch     65 | Train loss 2.2166  acc 33.8% | Test loss 2.2239  acc 33.6%
# Epoch     66 | Train loss 2.2132  acc 33.8% | Test loss 2.2200  acc 33.6%
# Epoch     67 | Train loss 2.2135  acc 33.8% | Test loss 2.2199  acc 33.6%
# Epoch     68 | Train loss 2.2117  acc 33.8% | Test loss 2.2174  acc 33.6%
# Epoch     69 | Train loss 2.3519  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     70 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     71 | Train loss 2.3518  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     72 | Train loss 2.3522  acc 33.8% | Test loss 2.3574  acc 33.6%
# Epoch     73 | Train loss 2.3515  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     74 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     75 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     76 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     77 | Train loss 2.3518  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     78 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     79 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     80 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     81 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     82 | Train loss 2.3515  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     83 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     84 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     85 | Train loss 2.3510  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     86 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     87 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     88 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     89 | Train loss 2.3512  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     90 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     91 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     92 | Train loss 2.3511  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch     93 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     94 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     95 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     96 | Train loss 2.3514  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     97 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     98 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     99 | Train loss 2.3515  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch    100 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    101 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    102 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    103 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    104 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    105 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    106 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    107 | Train loss 2.3509  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    108 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    109 | Train loss 2.3517  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch    110 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    111 | Train loss 2.3514  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    112 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    113 | Train loss 2.3521  acc 33.8% | Test loss 2.3576  acc 33.6%
# Epoch    114 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    115 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    116 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    117 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    118 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    119 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    120 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    121 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    122 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    123 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    124 | Train loss 2.3511  acc 33.8% | Test loss 2.3560  acc 33.6%
# Epoch    125 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    126 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    127 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    128 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    129 | Train loss 2.3516  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    130 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    131 | Train loss 2.3516  acc 33.8% | Test loss 2.3572  acc 33.6%
# Epoch    132 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    133 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    134 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    135 | Train loss 2.3514  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch    136 | Train loss 2.3514  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    137 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    138 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    139 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    140 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    141 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    142 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    143 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    144 | Train loss 2.3516  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    145 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    146 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    147 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    148 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    149 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    150 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    151 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    152 | Train loss 2.3510  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    153 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    154 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    155 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    156 | Train loss 2.3510  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    157 | Train loss 2.3513  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    158 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    159 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    160 | Train loss 2.3509  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    161 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    162 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    163 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    164 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    165 | Train loss 2.3518  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch    166 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    167 | Train loss 2.3511  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    168 | Train loss 2.3516  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch    169 | Train loss 2.3509  acc 33.8% | Test loss 2.3560  acc 33.6%
# Epoch    170 | Train loss 2.3510  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    171 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    172 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    173 | Train loss 2.3513  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    174 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    175 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    176 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    177 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    178 | Train loss 2.3510  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    179 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    180 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    181 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    182 | Train loss 2.3516  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    183 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    184 | Train loss 2.3513  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    185 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    186 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    187 | Train loss 2.3516  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    188 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    189 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    190 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    191 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    192 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    193 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    194 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    195 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    196 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    197 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    198 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    199 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    200 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 33.6%

# %% [markdown]
# # 7) Pre-norm BatchNorm

# %%
train(run_name="pre-norm BatchNorm", norm_type=nn.BatchNorm1d)
# Out:
# ============================================================
#   🚀 Run: pre-norm BatchNorm
# ============================================================
# Epoch      1 | Train loss 1.3752  acc 50.1% | Test loss 1.4502  acc 47.7%
# Epoch      2 | Train loss 1.0895  acc 55.8% | Test loss 1.1431  acc 53.2%
# Epoch      3 | Train loss 1.0449  acc 56.6% | Test loss 1.1034  acc 53.7%
# Epoch      4 | Train loss 1.0303  acc 57.5% | Test loss 1.0940  acc 53.6%
# Epoch      5 | Train loss 0.9151  acc 63.1% | Test loss 0.9761  acc 59.3%
# Epoch      6 | Train loss 0.8810  acc 65.3% | Test loss 0.9479  acc 61.4%
# Epoch      7 | Train loss 0.7236  acc 72.9% | Test loss 0.7676  acc 70.7%
# Epoch      8 | Train loss 0.6526  acc 75.2% | Test loss 0.6964  acc 72.8%
# Epoch      9 | Train loss 0.5583  acc 80.5% | Test loss 0.5959  acc 78.9%
# Epoch     10 | Train loss 0.4915  acc 82.9% | Test loss 0.5169  acc 82.1%
# Epoch     11 | Train loss 0.4844  acc 83.2% | Test loss 0.5103  acc 82.2%
# Epoch     12 | Train loss 0.4836  acc 83.3% | Test loss 0.5090  acc 82.2%
# Epoch     13 | Train loss 0.4748  acc 83.5% | Test loss 0.5083  acc 82.2%
# Epoch     14 | Train loss 0.4778  acc 83.4% | Test loss 0.5216  acc 81.7%
# Epoch     15 | Train loss 0.4409  acc 84.3% | Test loss 0.4768  acc 82.5%
# Epoch     16 | Train loss 0.4349  acc 84.3% | Test loss 0.4758  acc 82.8%
# Epoch     17 | Train loss 0.4038  acc 85.3% | Test loss 0.4505  acc 83.3%
# Epoch     18 | Train loss 0.3801  acc 85.9% | Test loss 0.4306  acc 83.7%
# Epoch     19 | Train loss 0.3552  acc 86.7% | Test loss 0.4067  acc 84.6%
# Epoch     20 | Train loss 0.3252  acc 88.3% | Test loss 0.3820  acc 85.7%
# Epoch     21 | Train loss 0.2716  acc 90.4% | Test loss 0.3207  acc 88.5%
# Epoch     22 | Train loss 0.2172  acc 92.0% | Test loss 0.2608  acc 90.2%
# Epoch     23 | Train loss 0.2150  acc 92.1% | Test loss 0.2533  acc 90.7%
# Epoch     24 | Train loss 0.1626  acc 93.7% | Test loss 0.2058  acc 91.8%
# Epoch     25 | Train loss 0.1286  acc 94.8% | Test loss 0.1671  acc 92.8%
# Epoch     26 | Train loss 0.0943  acc 96.2% | Test loss 0.1292  acc 94.5%
# Epoch     27 | Train loss 0.0704  acc 97.2% | Test loss 0.0974  acc 95.8%
# Epoch     28 | Train loss 0.0523  acc 98.0% | Test loss 0.0755  acc 96.8%
# Epoch     29 | Train loss 0.0878  acc 97.6% | Test loss 0.1084  acc 96.5%
# Epoch     30 | Train loss 0.0352  acc 98.8% | Test loss 0.0517  acc 97.9%
# Epoch     31 | Train loss 0.0351  acc 98.7% | Test loss 0.0549  acc 97.8%
# Epoch     32 | Train loss 0.0284  acc 99.1% | Test loss 0.0441  acc 98.3%
# Epoch     33 | Train loss 0.0208  acc 99.3% | Test loss 0.0359  acc 98.7%
# Epoch     34 | Train loss 0.0273  acc 99.3% | Test loss 0.0411  acc 98.9%
# Epoch     35 | Train loss 0.0122  acc 99.7% | Test loss 0.0217  acc 99.3%
# Epoch     36 | Train loss 0.0150  acc 99.6% | Test loss 0.0223  acc 99.3%
# Epoch     37 | Train loss 0.0167  acc 99.5% | Test loss 0.0253  acc 99.2%
# Epoch     38 | Train loss 0.0074  acc 99.8% | Test loss 0.0147  acc 99.5%
# Epoch     39 | Train loss 0.0104  acc 99.7% | Test loss 0.0177  acc 99.4%
# Epoch     40 | Train loss 0.0075  acc 99.8% | Test loss 0.0112  acc 99.6%
# Epoch     41 | Train loss 0.0052  acc 99.9% | Test loss 0.0086  acc 99.7%
# Epoch     42 | Train loss 0.0087  acc 99.8% | Test loss 0.0146  acc 99.6%
# Epoch     43 | Train loss 0.0145  acc 99.7% | Test loss 0.0201  acc 99.6%
# Epoch     44 | Train loss 0.0074  acc 99.8% | Test loss 0.0103  acc 99.6%
# Epoch     45 | Train loss 0.0069  acc 99.8% | Test loss 0.0109  acc 99.7%
# Epoch     46 | Train loss 0.0083  acc 99.8% | Test loss 0.0127  acc 99.7%
# Epoch     47 | Train loss 0.0150  acc 99.6% | Test loss 0.0184  acc 99.5%
# Epoch     48 | Train loss 0.0036  acc 99.9% | Test loss 0.0066  acc 99.8%
# Epoch     49 | Train loss 0.0065  acc 99.8% | Test loss 0.0082  acc 99.8%
# Epoch     50 | Train loss 0.0075  acc 99.7% | Test loss 0.0114  acc 99.6%
# Epoch     51 | Train loss 0.0212  acc 99.5% | Test loss 0.0264  acc 99.4%
# Epoch     52 | Train loss 0.0083  acc 99.7% | Test loss 0.0083  acc 99.7%
# Epoch     53 | Train loss 0.0096  acc 99.7% | Test loss 0.0105  acc 99.7%
# Epoch     54 | Train loss 0.0044  acc 99.9% | Test loss 0.0071  acc 99.8%
# Epoch     55 | Train loss 0.0054  acc 99.9% | Test loss 0.0064  acc 99.8%
# Epoch     56 | Train loss 0.0079  acc 99.8% | Test loss 0.0110  acc 99.7%
# Epoch     57 | Train loss 0.0131  acc 99.7% | Test loss 0.0131  acc 99.7%
# Epoch     58 | Train loss 0.0038  acc 99.9% | Test loss 0.0059  acc 99.8%
# Epoch     59 | Train loss 0.0141  acc 99.8% | Test loss 0.0124  acc 99.8%
# Epoch     60 | Train loss 0.0015  acc 100.0% | Test loss 0.0031  acc 99.9%
# Epoch     61 | Train loss 0.0050  acc 99.8% | Test loss 0.0072  acc 99.8%
# Epoch     62 | Train loss 0.0039  acc 99.9% | Test loss 0.0066  acc 99.8%
# Epoch     63 | Train loss 0.0019  acc 99.9% | Test loss 0.0031  acc 99.9%
# Epoch     64 | Train loss 0.0099  acc 99.8% | Test loss 0.0113  acc 99.7%
# Epoch     65 | Train loss 0.0028  acc 99.9% | Test loss 0.0032  acc 99.9%
# Epoch     66 | Train loss 0.0027  acc 99.9% | Test loss 0.0041  acc 99.9%
# Epoch     67 | Train loss 0.0072  acc 99.8% | Test loss 0.0087  acc 99.8%
# Epoch     68 | Train loss 0.0017  acc 100.0% | Test loss 0.0024  acc 99.9%
# Epoch     69 | Train loss 0.0023  acc 99.9% | Test loss 0.0030  acc 99.9%
# Epoch     70 | Train loss 0.0028  acc 99.9% | Test loss 0.0045  acc 99.9%
# Epoch     71 | Train loss 0.0025  acc 99.9% | Test loss 0.0045  acc 99.9%
# Epoch     72 | Train loss 0.0053  acc 99.8% | Test loss 0.0081  acc 99.8%
# Epoch     73 | Train loss 0.0057  acc 99.9% | Test loss 0.0063  acc 99.8%
# Epoch     74 | Train loss 0.0028  acc 99.9% | Test loss 0.0032  acc 99.9%
# Epoch     75 | Train loss 0.0035  acc 99.9% | Test loss 0.0045  acc 99.9%
# Epoch     76 | Train loss 0.0030  acc 99.9% | Test loss 0.0034  acc 99.9%
# Epoch     77 | Train loss 0.0077  acc 99.8% | Test loss 0.0104  acc 99.8%
# Epoch     78 | Train loss 0.0023  acc 99.9% | Test loss 0.0022  acc 99.9%
# Epoch     79 | Train loss 0.0028  acc 99.9% | Test loss 0.0037  acc 99.9%
# Epoch     80 | Train loss 0.0018  acc 100.0% | Test loss 0.0023  acc 99.9%
# Epoch     81 | Train loss 0.0058  acc 99.8% | Test loss 0.0076  acc 99.8%
# Epoch     82 | Train loss 0.0015  acc 99.9% | Test loss 0.0020  acc 99.9%
# Epoch     83 | Train loss 0.0075  acc 99.8% | Test loss 0.0101  acc 99.7%
# Epoch     84 | Train loss 0.0024  acc 99.9% | Test loss 0.0035  acc 99.9%
# Epoch     85 | Train loss 0.0139  acc 99.7% | Test loss 0.0185  acc 99.6%
# Epoch     86 | Train loss 0.0032  acc 99.9% | Test loss 0.0053  acc 99.9%
# Epoch     87 | Train loss 0.0035  acc 99.9% | Test loss 0.0046  acc 99.9%
# Epoch     88 | Train loss 0.0055  acc 99.9% | Test loss 0.0061  acc 99.8%
# Epoch     89 | Train loss 0.0019  acc 100.0% | Test loss 0.0033  acc 99.9%
# Epoch     90 | Train loss 0.0072  acc 99.9% | Test loss 0.0089  acc 99.8%
# Epoch     91 | Train loss 0.0012  acc 100.0% | Test loss 0.0020  acc 99.9%
# Epoch     92 | Train loss 0.0010  acc 100.0% | Test loss 0.0021  acc 100.0%
# Epoch     93 | Train loss 0.0054  acc 99.8% | Test loss 0.0068  acc 99.8%
# Epoch     94 | Train loss 0.0088  acc 99.8% | Test loss 0.0139  acc 99.8%
# Epoch     95 | Train loss 0.0032  acc 99.9% | Test loss 0.0034  acc 99.9%
# Epoch     96 | Train loss 0.0026  acc 99.9% | Test loss 0.0041  acc 99.9%
# Epoch     97 | Train loss 0.0018  acc 99.9% | Test loss 0.0043  acc 99.9%
# Epoch     98 | Train loss 0.0043  acc 99.9% | Test loss 0.0046  acc 99.9%
# Epoch     99 | Train loss 0.0029  acc 99.9% | Test loss 0.0041  acc 99.9%
# Epoch    100 | Train loss 0.0006  acc 100.0% | Test loss 0.0014  acc 100.0%
# Epoch    101 | Train loss 0.0035  acc 99.9% | Test loss 0.0034  acc 99.9%
# Epoch    102 | Train loss 0.0013  acc 100.0% | Test loss 0.0017  acc 100.0%
# Epoch    103 | Train loss 0.0043  acc 99.9% | Test loss 0.0061  acc 99.8%
# Epoch    104 | Train loss 0.0016  acc 100.0% | Test loss 0.0032  acc 99.9%
# Epoch    105 | Train loss 0.0021  acc 99.9% | Test loss 0.0027  acc 99.9%
# Epoch    106 | Train loss 0.0058  acc 99.9% | Test loss 0.0053  acc 99.8%
# Epoch    107 | Train loss 0.0047  acc 99.9% | Test loss 0.0033  acc 99.9%
# Epoch    108 | Train loss 0.0022  acc 99.9% | Test loss 0.0022  acc 99.9%
# Epoch    109 | Train loss 0.0016  acc 100.0% | Test loss 0.0017  acc 100.0%
# Epoch    110 | Train loss 0.0043  acc 99.9% | Test loss 0.0049  acc 99.9%
# Epoch    111 | Train loss 0.0097  acc 99.7% | Test loss 0.0113  acc 99.7%
# Epoch    112 | Train loss 0.0044  acc 99.9% | Test loss 0.0050  acc 99.9%
# Epoch    113 | Train loss 0.0002  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    114 | Train loss 0.0013  acc 100.0% | Test loss 0.0017  acc 100.0%
# Epoch    115 | Train loss 0.0005  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch    116 | Train loss 0.0008  acc 100.0% | Test loss 0.0013  acc 100.0%
# Epoch    117 | Train loss 0.0011  acc 100.0% | Test loss 0.0016  acc 99.9%
# Epoch    118 | Train loss 0.0011  acc 100.0% | Test loss 0.0015  acc 100.0%
# Epoch    119 | Train loss 0.0001  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    120 | Train loss 0.0030  acc 99.9% | Test loss 0.0029  acc 99.9%
# Epoch    121 | Train loss 0.0005  acc 100.0% | Test loss 0.0011  acc 100.0%
# Epoch    122 | Train loss 0.0036  acc 99.9% | Test loss 0.0041  acc 99.9%
# Epoch    123 | Train loss 0.0008  acc 100.0% | Test loss 0.0017  acc 100.0%
# Epoch    124 | Train loss 0.0022  acc 99.9% | Test loss 0.0027  acc 99.9%
# Epoch    125 | Train loss 0.0030  acc 99.9% | Test loss 0.0034  acc 99.9%
# Epoch    126 | Train loss 0.0015  acc 100.0% | Test loss 0.0011  acc 100.0%
# Epoch    127 | Train loss 0.0018  acc 100.0% | Test loss 0.0020  acc 99.9%
# Epoch    128 | Train loss 0.0015  acc 100.0% | Test loss 0.0012  acc 100.0%
# Epoch    129 | Train loss 0.0132  acc 99.8% | Test loss 0.0134  acc 99.8%
# Epoch    130 | Train loss 0.0018  acc 100.0% | Test loss 0.0024  acc 99.9%
# Epoch    131 | Train loss 0.0029  acc 99.9% | Test loss 0.0032  acc 99.9%
# Epoch    132 | Train loss 0.0025  acc 99.9% | Test loss 0.0028  acc 99.9%
# Epoch    133 | Train loss 0.0027  acc 100.0% | Test loss 0.0045  acc 99.9%
# Epoch    134 | Train loss 0.0020  acc 99.9% | Test loss 0.0029  acc 99.9%
# Epoch    135 | Train loss 0.0016  acc 100.0% | Test loss 0.0023  acc 100.0%
# Epoch    136 | Train loss 0.0019  acc 100.0% | Test loss 0.0030  acc 99.9%
# Epoch    137 | Train loss 0.0024  acc 99.9% | Test loss 0.0034  acc 99.9%
# Epoch    138 | Train loss 0.0012  acc 100.0% | Test loss 0.0018  acc 100.0%
# Epoch    139 | Train loss 0.0010  acc 100.0% | Test loss 0.0013  acc 100.0%
# Epoch    140 | Train loss 0.0069  acc 99.9% | Test loss 0.0088  acc 99.9%
# Epoch    141 | Train loss 0.0014  acc 100.0% | Test loss 0.0021  acc 99.9%
# Epoch    142 | Train loss 0.0012  acc 100.0% | Test loss 0.0020  acc 99.9%
# Epoch    143 | Train loss 0.0011  acc 100.0% | Test loss 0.0012  acc 100.0%
# Epoch    144 | Train loss 0.0038  acc 99.9% | Test loss 0.0055  acc 99.9%
# Epoch    145 | Train loss 0.0028  acc 99.9% | Test loss 0.0033  acc 99.9%
# Epoch    146 | Train loss 0.0003  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch    147 | Train loss 0.0023  acc 99.9% | Test loss 0.0028  acc 99.9%
# Epoch    148 | Train loss 0.0011  acc 100.0% | Test loss 0.0019  acc 99.9%
# Epoch    149 | Train loss 0.0015  acc 100.0% | Test loss 0.0024  acc 99.9%
# Epoch    150 | Train loss 0.0015  acc 100.0% | Test loss 0.0026  acc 99.9%
# Epoch    151 | Train loss 0.0089  acc 99.8% | Test loss 0.0117  acc 99.7%
# Epoch    152 | Train loss 0.0004  acc 100.0% | Test loss 0.0013  acc 100.0%
# Epoch    153 | Train loss 0.0025  acc 99.9% | Test loss 0.0040  acc 99.9%
# Epoch    154 | Train loss 0.0080  acc 100.0% | Test loss 0.0076  acc 99.9%
# Epoch    155 | Train loss 0.0010  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    156 | Train loss 0.0012  acc 100.0% | Test loss 0.0018  acc 100.0%
# Epoch    157 | Train loss 0.0027  acc 99.9% | Test loss 0.0025  acc 99.9%
# Epoch    158 | Train loss 0.0018  acc 100.0% | Test loss 0.0029  acc 99.9%
# Epoch    159 | Train loss 0.0015  acc 100.0% | Test loss 0.0027  acc 99.9%
# Epoch    160 | Train loss 0.0010  acc 100.0% | Test loss 0.0010  acc 100.0%
# Epoch    161 | Train loss 0.0418  acc 98.8% | Test loss 0.0453  acc 98.7%
# Epoch    162 | Train loss 0.0007  acc 100.0% | Test loss 0.0018  acc 100.0%
# Epoch    163 | Train loss 0.0001  acc 100.0% | Test loss 0.0006  acc 100.0%
# Epoch    164 | Train loss 0.0003  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    165 | Train loss 0.0001  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    166 | Train loss 0.0001  acc 100.0% | Test loss 0.0003  acc 100.0%
# Epoch    167 | Train loss 0.0001  acc 100.0% | Test loss 0.0004  acc 100.0%
# Epoch    168 | Train loss 0.0005  acc 100.0% | Test loss 0.0010  acc 100.0%
# Epoch    169 | Train loss 0.0043  acc 99.9% | Test loss 0.0058  acc 99.8%
# Epoch    170 | Train loss 0.0016  acc 100.0% | Test loss 0.0022  acc 99.9%
# Epoch    171 | Train loss 0.0019  acc 100.0% | Test loss 0.0020  acc 99.9%
# Epoch    172 | Train loss 0.0009  acc 100.0% | Test loss 0.0015  acc 100.0%
# Epoch    173 | Train loss 0.0003  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    174 | Train loss 0.0050  acc 99.9% | Test loss 0.0058  acc 99.9%
# Epoch    175 | Train loss 0.0012  acc 100.0% | Test loss 0.0019  acc 99.9%
# Epoch    176 | Train loss 0.0008  acc 100.0% | Test loss 0.0009  acc 100.0%
# Epoch    177 | Train loss 0.0063  acc 99.9% | Test loss 0.0079  acc 99.9%
# Epoch    178 | Train loss 0.0063  acc 99.9% | Test loss 0.0074  acc 99.8%
# Epoch    179 | Train loss 0.0082  acc 99.9% | Test loss 0.0098  acc 99.8%
# Epoch    180 | Train loss 0.0040  acc 99.9% | Test loss 0.0037  acc 99.9%
# Epoch    181 | Train loss 0.0019  acc 99.9% | Test loss 0.0025  acc 99.9%
# Epoch    182 | Train loss 0.0032  acc 99.9% | Test loss 0.0061  acc 99.9%
# Epoch    183 | Train loss 0.0015  acc 100.0% | Test loss 0.0019  acc 100.0%
# Epoch    184 | Train loss 0.0011  acc 100.0% | Test loss 0.0019  acc 99.9%
# Epoch    185 | Train loss 0.0027  acc 99.9% | Test loss 0.0031  acc 99.9%
# Epoch    186 | Train loss 0.0001  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    187 | Train loss 0.0018  acc 99.9% | Test loss 0.0028  acc 99.9%
# Epoch    188 | Train loss 0.0096  acc 99.8% | Test loss 0.0098  acc 99.8%
# Epoch    189 | Train loss 0.0024  acc 99.9% | Test loss 0.0031  acc 99.9%
# Epoch    190 | Train loss 0.0007  acc 100.0% | Test loss 0.0015  acc 100.0%
# Epoch    191 | Train loss 0.0006  acc 100.0% | Test loss 0.0007  acc 100.0%
# Epoch    192 | Train loss 0.0004  acc 100.0% | Test loss 0.0005  acc 100.0%
# Epoch    193 | Train loss 0.0007  acc 100.0% | Test loss 0.0008  acc 100.0%
# Epoch    194 | Train loss 0.0015  acc 100.0% | Test loss 0.0014  acc 100.0%
# Epoch    195 | Train loss 0.0027  acc 99.9% | Test loss 0.0026  acc 99.9%
# Epoch    196 | Train loss 0.0016  acc 100.0% | Test loss 0.0023  acc 100.0%
# Epoch    197 | Train loss 0.0013  acc 100.0% | Test loss 0.0016  acc 100.0%
# Epoch    198 | Train loss 0.0015  acc 100.0% | Test loss 0.0026  acc 99.9%
# Epoch    199 | Train loss 0.0042  acc 99.9% | Test loss 0.0049  acc 99.9%
# Epoch    200 | Train loss 0.0031  acc 99.9% | Test loss 0.0034  acc 99.9%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 99.9%

# %% [markdown]
# # 8) Post-norm BatchNorm

# %%
train(run_name="post-norm BatchNorm", norm_type=nn.BatchNorm1d, is_post_norm=True)
# Out:
# ============================================================
#   🚀 Run: post-norm BatchNorm
# ============================================================
# Epoch      1 | Train loss 1.2363  acc 51.2% | Test loss 1.2520  acc 51.0%
# Epoch      2 | Train loss 1.0516  acc 54.5% | Test loss 1.0548  acc 54.2%
# Epoch      3 | Train loss 1.0453  acc 54.4% | Test loss 1.0485  acc 54.3%
# Epoch      4 | Train loss 1.0379  acc 54.6% | Test loss 1.0403  acc 54.3%
# Epoch      5 | Train loss 1.0368  acc 54.6% | Test loss 1.0392  acc 54.1%
# Epoch      6 | Train loss 1.0615  acc 54.3% | Test loss 1.0629  acc 54.2%
# Epoch      7 | Train loss 1.0356  acc 54.5% | Test loss 1.0357  acc 54.3%
# Epoch      8 | Train loss 1.0298  acc 54.6% | Test loss 1.0296  acc 54.6%
# Epoch      9 | Train loss 1.0326  acc 54.6% | Test loss 1.0332  acc 54.5%
# Epoch     10 | Train loss 1.0303  acc 54.6% | Test loss 1.0318  acc 54.4%
# Epoch     11 | Train loss 1.0451  acc 53.9% | Test loss 1.0458  acc 53.9%
# Epoch     12 | Train loss 1.0254  acc 54.6% | Test loss 1.0265  acc 54.5%
# Epoch     13 | Train loss 1.0401  acc 54.6% | Test loss 1.0413  acc 54.5%
# Epoch     14 | Train loss 1.0272  acc 54.6% | Test loss 1.0282  acc 54.3%
# Epoch     15 | Train loss 1.0961  acc 54.4% | Test loss 1.1029  acc 54.6%
# Epoch     16 | Train loss 1.0266  acc 54.6% | Test loss 1.0271  acc 54.5%
# Epoch     17 | Train loss 1.0253  acc 54.6% | Test loss 1.0263  acc 54.4%
# Epoch     18 | Train loss 1.0218  acc 54.6% | Test loss 1.0223  acc 54.7%
# Epoch     19 | Train loss 1.0301  acc 54.2% | Test loss 1.0309  acc 54.3%
# Epoch     20 | Train loss 1.0240  acc 54.6% | Test loss 1.0261  acc 54.4%
# Epoch     21 | Train loss 1.0698  acc 54.2% | Test loss 1.0684  acc 54.3%
# Epoch     22 | Train loss 1.0286  acc 54.5% | Test loss 1.0298  acc 54.3%
# Epoch     23 | Train loss 1.0477  acc 54.3% | Test loss 1.0489  acc 54.1%
# Epoch     24 | Train loss 1.0213  acc 54.6% | Test loss 1.0212  acc 54.5%
# Epoch     25 | Train loss 1.0653  acc 54.0% | Test loss 1.0637  acc 53.7%
# Epoch     26 | Train loss 1.0210  acc 54.6% | Test loss 1.0219  acc 54.5%
# Epoch     27 | Train loss 1.0677  acc 53.9% | Test loss 1.0717  acc 53.8%
# Epoch     28 | Train loss 1.0203  acc 54.6% | Test loss 1.0205  acc 54.7%
# Epoch     29 | Train loss 1.0190  acc 54.7% | Test loss 1.0200  acc 54.4%
# Epoch     30 | Train loss 1.0245  acc 54.5% | Test loss 1.0258  acc 54.3%
# Epoch     31 | Train loss 1.0204  acc 54.6% | Test loss 1.0211  acc 54.5%
# Epoch     32 | Train loss 1.0238  acc 54.6% | Test loss 1.0243  acc 54.4%
# Epoch     33 | Train loss 1.0188  acc 54.6% | Test loss 1.0197  acc 54.4%
# Epoch     34 | Train loss 1.0198  acc 54.6% | Test loss 1.0203  acc 54.5%
# Epoch     35 | Train loss 1.0348  acc 54.6% | Test loss 1.0364  acc 54.4%
# Epoch     36 | Train loss 1.0191  acc 54.6% | Test loss 1.0203  acc 54.5%
# Epoch     37 | Train loss 1.0179  acc 54.7% | Test loss 1.0191  acc 54.2%
# Epoch     38 | Train loss 1.0182  acc 54.6% | Test loss 1.0183  acc 54.6%
# Epoch     39 | Train loss 1.0289  acc 54.5% | Test loss 1.0322  acc 54.3%
# Epoch     40 | Train loss 1.0203  acc 54.5% | Test loss 1.0204  acc 54.7%
# Epoch     41 | Train loss 1.0192  acc 54.7% | Test loss 1.0204  acc 54.4%
# Epoch     42 | Train loss 1.0196  acc 54.6% | Test loss 1.0198  acc 54.4%
# Epoch     43 | Train loss 1.0226  acc 54.6% | Test loss 1.0242  acc 54.6%
# Epoch     44 | Train loss 1.0235  acc 54.6% | Test loss 1.0241  acc 54.3%
# Epoch     45 | Train loss 1.0189  acc 54.7% | Test loss 1.0204  acc 54.3%
# Epoch     46 | Train loss 1.0189  acc 54.6% | Test loss 1.0197  acc 54.6%
# Epoch     47 | Train loss 1.0206  acc 54.6% | Test loss 1.0200  acc 54.7%
# Epoch     48 | Train loss 1.0204  acc 54.6% | Test loss 1.0202  acc 54.4%
# Epoch     49 | Train loss 1.0215  acc 54.6% | Test loss 1.0225  acc 54.6%
# Epoch     50 | Train loss 1.0181  acc 54.6% | Test loss 1.0174  acc 54.5%
# Epoch     51 | Train loss 1.0228  acc 54.6% | Test loss 1.0224  acc 54.4%
# Epoch     52 | Train loss 1.0229  acc 54.6% | Test loss 1.0240  acc 54.5%
# Epoch     53 | Train loss 1.0220  acc 54.5% | Test loss 1.0225  acc 54.7%
# Epoch     54 | Train loss 1.0209  acc 54.6% | Test loss 1.0215  acc 54.6%
# Epoch     55 | Train loss 1.0176  acc 54.7% | Test loss 1.0188  acc 54.3%
# Epoch     56 | Train loss 1.0285  acc 54.6% | Test loss 1.0314  acc 54.1%
# Epoch     57 | Train loss 1.0240  acc 54.6% | Test loss 1.0259  acc 54.2%
# Epoch     58 | Train loss 1.0188  acc 54.6% | Test loss 1.0190  acc 54.4%
# Epoch     59 | Train loss 1.0187  acc 54.6% | Test loss 1.0193  acc 54.4%
# Epoch     60 | Train loss 1.0497  acc 54.6% | Test loss 1.0508  acc 54.4%
# Epoch     61 | Train loss 1.0202  acc 54.6% | Test loss 1.0215  acc 54.5%
# Epoch     62 | Train loss 1.0206  acc 54.6% | Test loss 1.0206  acc 54.6%
# Epoch     63 | Train loss 1.0189  acc 54.6% | Test loss 1.0199  acc 54.5%
# Epoch     64 | Train loss 1.0391  acc 54.6% | Test loss 1.0406  acc 54.5%
# Epoch     65 | Train loss 1.0178  acc 54.6% | Test loss 1.0180  acc 54.7%
# Epoch     66 | Train loss 1.0208  acc 54.6% | Test loss 1.0223  acc 54.7%
# Epoch     67 | Train loss 1.0197  acc 54.6% | Test loss 1.0202  acc 54.8%
# Epoch     68 | Train loss 1.0186  acc 54.7% | Test loss 1.0202  acc 54.3%
# Epoch     69 | Train loss 1.0172  acc 54.7% | Test loss 1.0188  acc 54.3%
# Epoch     70 | Train loss 1.0174  acc 54.6% | Test loss 1.0189  acc 54.4%
# Epoch     71 | Train loss 1.0345  acc 54.6% | Test loss 1.0367  acc 54.3%
# Epoch     72 | Train loss 1.0209  acc 54.6% | Test loss 1.0198  acc 54.5%
# Epoch     73 | Train loss 1.0245  acc 54.6% | Test loss 1.0249  acc 54.4%
# Epoch     74 | Train loss 1.0190  acc 54.6% | Test loss 1.0201  acc 54.5%
# Epoch     75 | Train loss 1.0182  acc 54.7% | Test loss 1.0188  acc 54.3%
# Epoch     76 | Train loss 1.0188  acc 54.7% | Test loss 1.0207  acc 54.2%
# Epoch     77 | Train loss 1.0186  acc 54.6% | Test loss 1.0198  acc 54.5%
# Epoch     78 | Train loss 1.0198  acc 54.6% | Test loss 1.0197  acc 54.5%
# Epoch     79 | Train loss 1.0176  acc 54.6% | Test loss 1.0184  acc 54.5%
# Epoch     80 | Train loss 1.0173  acc 54.6% | Test loss 1.0178  acc 54.5%
# Epoch     81 | Train loss 1.0189  acc 54.7% | Test loss 1.0206  acc 54.3%
# Epoch     82 | Train loss 1.0269  acc 54.6% | Test loss 1.0277  acc 54.6%
# Epoch     83 | Train loss 1.0179  acc 54.7% | Test loss 1.0187  acc 54.4%
# Epoch     84 | Train loss 1.0177  acc 54.7% | Test loss 1.0187  acc 54.3%
# Epoch     85 | Train loss 1.0238  acc 54.4% | Test loss 1.0263  acc 53.8%
# Epoch     86 | Train loss 1.0169  acc 54.7% | Test loss 1.0187  acc 54.3%
# Epoch     87 | Train loss 1.0166  acc 54.6% | Test loss 1.0172  acc 54.4%
# Epoch     88 | Train loss 1.0179  acc 54.6% | Test loss 1.0175  acc 54.6%
# Epoch     89 | Train loss 1.0185  acc 54.6% | Test loss 1.0194  acc 54.4%
# Epoch     90 | Train loss 1.0199  acc 54.6% | Test loss 1.0206  acc 54.4%
# Epoch     91 | Train loss 1.0186  acc 54.6% | Test loss 1.0191  acc 54.6%
# Epoch     92 | Train loss 1.0292  acc 54.6% | Test loss 1.0292  acc 54.7%
# Epoch     93 | Train loss 1.0184  acc 54.7% | Test loss 1.0194  acc 54.4%
# Epoch     94 | Train loss 1.0178  acc 54.6% | Test loss 1.0187  acc 54.4%
# Epoch     95 | Train loss 1.0197  acc 54.6% | Test loss 1.0212  acc 54.5%
# Epoch     96 | Train loss 1.0193  acc 54.7% | Test loss 1.0205  acc 54.2%
# Epoch     97 | Train loss 1.0168  acc 54.6% | Test loss 1.0176  acc 54.4%
# Epoch     98 | Train loss 1.0181  acc 54.6% | Test loss 1.0191  acc 54.6%
# Epoch     99 | Train loss 1.0167  acc 54.7% | Test loss 1.0182  acc 54.3%
# Epoch    100 | Train loss 1.0176  acc 54.7% | Test loss 1.0194  acc 54.3%
# Epoch    101 | Train loss 1.0195  acc 54.6% | Test loss 1.0210  acc 54.5%
# Epoch    102 | Train loss 1.0208  acc 54.6% | Test loss 1.0219  acc 54.5%
# Epoch    103 | Train loss 1.0205  acc 54.6% | Test loss 1.0211  acc 54.5%
# Epoch    104 | Train loss 1.0184  acc 54.6% | Test loss 1.0185  acc 54.5%
# Epoch    105 | Train loss 1.0170  acc 54.6% | Test loss 1.0177  acc 54.5%
# Epoch    106 | Train loss 1.0166  acc 54.7% | Test loss 1.0175  acc 54.3%
# Epoch    107 | Train loss 1.0197  acc 54.6% | Test loss 1.0206  acc 54.4%
# Epoch    108 | Train loss 1.0191  acc 54.6% | Test loss 1.0202  acc 54.6%
# Epoch    109 | Train loss 1.0169  acc 54.7% | Test loss 1.0187  acc 54.3%
# Epoch    110 | Train loss 1.0164  acc 54.8% | Test loss 1.0179  acc 54.4%
# Epoch    111 | Train loss 1.0164  acc 54.8% | Test loss 1.0180  acc 54.3%
# Epoch    112 | Train loss 1.0219  acc 54.7% | Test loss 1.0230  acc 54.8%
# Epoch    113 | Train loss 1.0165  acc 54.9% | Test loss 1.0178  acc 54.3%
# Epoch    114 | Train loss 1.0133  acc 54.9% | Test loss 1.0150  acc 54.8%
# Epoch    115 | Train loss 1.0335  acc 55.2% | Test loss 1.0396  acc 54.9%
# Epoch    116 | Train loss 0.9916  acc 56.2% | Test loss 0.9920  acc 55.9%
# Epoch    117 | Train loss 0.9838  acc 56.3% | Test loss 0.9843  acc 56.2%
# Epoch    118 | Train loss 0.9822  acc 56.3% | Test loss 0.9827  acc 56.1%
# Epoch    119 | Train loss 0.9913  acc 56.3% | Test loss 0.9910  acc 56.1%
# Epoch    120 | Train loss 0.9837  acc 56.3% | Test loss 0.9845  acc 56.1%
# Epoch    121 | Train loss 0.9814  acc 56.2% | Test loss 0.9807  acc 56.3%
# Epoch    122 | Train loss 0.9807  acc 56.3% | Test loss 0.9808  acc 56.2%
# Epoch    123 | Train loss 0.9814  acc 56.3% | Test loss 0.9818  acc 56.0%
# Epoch    124 | Train loss 0.9807  acc 56.3% | Test loss 0.9813  acc 55.9%
# Epoch    125 | Train loss 0.9813  acc 56.3% | Test loss 0.9808  acc 56.2%
# Epoch    126 | Train loss 0.9811  acc 56.3% | Test loss 0.9814  acc 56.2%
# Epoch    127 | Train loss 0.9675  acc 57.1% | Test loss 0.9679  acc 56.9%
# Epoch    128 | Train loss 0.9641  acc 57.2% | Test loss 0.9648  acc 57.1%
# Epoch    129 | Train loss 0.9635  acc 57.2% | Test loss 0.9639  acc 57.2%
# Epoch    130 | Train loss 0.9636  acc 57.3% | Test loss 0.9651  acc 56.9%
# Epoch    131 | Train loss 0.9661  acc 57.3% | Test loss 0.9657  acc 57.1%
# Epoch    132 | Train loss 0.9608  acc 57.3% | Test loss 0.9605  acc 57.3%
# Epoch    133 | Train loss 0.9621  acc 57.3% | Test loss 0.9620  acc 57.2%
# Epoch    134 | Train loss 0.9629  acc 57.3% | Test loss 0.9633  acc 57.2%
# Epoch    135 | Train loss 0.9624  acc 57.3% | Test loss 0.9632  acc 57.1%
# Epoch    136 | Train loss 0.9642  acc 57.3% | Test loss 0.9639  acc 57.3%
# Epoch    137 | Train loss 0.9609  acc 57.6% | Test loss 0.9612  acc 57.5%
# Epoch    138 | Train loss 0.9577  acc 57.8% | Test loss 0.9606  acc 57.4%
# Epoch    139 | Train loss 0.9548  acc 57.9% | Test loss 0.9570  acc 57.7%
# Epoch    140 | Train loss 0.9584  acc 57.8% | Test loss 0.9641  acc 57.6%
# Epoch    141 | Train loss 0.9539  acc 58.0% | Test loss 0.9571  acc 57.8%
# Epoch    142 | Train loss 0.9523  acc 58.0% | Test loss 0.9553  acc 57.9%
# Epoch    143 | Train loss 0.9540  acc 58.0% | Test loss 0.9576  acc 57.8%
# Epoch    144 | Train loss 0.9507  acc 58.0% | Test loss 0.9537  acc 58.0%
# Epoch    145 | Train loss 0.9515  acc 58.2% | Test loss 0.9564  acc 57.8%
# Epoch    146 | Train loss 0.9486  acc 58.2% | Test loss 0.9543  acc 57.9%
# Epoch    147 | Train loss 0.9467  acc 58.3% | Test loss 0.9533  acc 58.3%
# Epoch    148 | Train loss 0.9392  acc 58.8% | Test loss 0.9453  acc 58.4%
# Epoch    149 | Train loss 0.9295  acc 59.3% | Test loss 0.9407  acc 58.7%
# Epoch    150 | Train loss 0.9005  acc 60.7% | Test loss 0.9086  acc 60.3%
# Epoch    151 | Train loss 0.8826  acc 62.4% | Test loss 0.8945  acc 61.7%
# Epoch    152 | Train loss 0.8391  acc 63.6% | Test loss 0.8462  acc 63.3%
# Epoch    153 | Train loss 0.8472  acc 64.8% | Test loss 0.8611  acc 64.4%
# Epoch    154 | Train loss 0.8022  acc 65.0% | Test loss 0.8108  acc 64.6%
# Epoch    155 | Train loss 0.7865  acc 65.4% | Test loss 0.7937  acc 65.1%
# Epoch    156 | Train loss 0.7747  acc 65.7% | Test loss 0.7827  acc 65.3%
# Epoch    157 | Train loss 0.7759  acc 65.7% | Test loss 0.7830  acc 65.2%
# Epoch    158 | Train loss 0.7639  acc 65.8% | Test loss 0.7735  acc 65.5%
# Epoch    159 | Train loss 0.7498  acc 66.5% | Test loss 0.7616  acc 65.7%
# Epoch    160 | Train loss 0.7409  acc 66.8% | Test loss 0.7491  acc 66.5%
# Epoch    161 | Train loss 0.7358  acc 66.9% | Test loss 0.7437  acc 66.7%
# Epoch    162 | Train loss 0.7362  acc 67.0% | Test loss 0.7433  acc 66.8%
# Epoch    163 | Train loss 0.7442  acc 66.8% | Test loss 0.7509  acc 66.4%
# Epoch    164 | Train loss 0.7191  acc 67.9% | Test loss 0.7252  acc 67.5%
# Epoch    165 | Train loss 0.7266  acc 67.5% | Test loss 0.7323  acc 67.2%
# Epoch    166 | Train loss 0.7218  acc 67.7% | Test loss 0.7299  acc 67.1%
# Epoch    167 | Train loss 0.7249  acc 67.5% | Test loss 0.7319  acc 67.2%
# Epoch    168 | Train loss 0.7169  acc 67.6% | Test loss 0.7250  acc 67.3%
# Epoch    169 | Train loss 0.7217  acc 67.5% | Test loss 0.7275  acc 67.4%
# Epoch    170 | Train loss 0.7089  acc 68.2% | Test loss 0.7167  acc 67.5%
# Epoch    171 | Train loss 0.7138  acc 68.0% | Test loss 0.7192  acc 67.7%
# Epoch    172 | Train loss 0.7156  acc 67.9% | Test loss 0.7230  acc 67.3%
# Epoch    173 | Train loss 0.7138  acc 68.2% | Test loss 0.7195  acc 67.9%
# Epoch    174 | Train loss 0.7068  acc 68.3% | Test loss 0.7148  acc 67.8%
# Epoch    175 | Train loss 0.7378  acc 67.1% | Test loss 0.7404  acc 66.9%
# Epoch    176 | Train loss 0.7081  acc 68.5% | Test loss 0.7167  acc 68.2%
# Epoch    177 | Train loss 0.7109  acc 68.5% | Test loss 0.7196  acc 67.9%
# Epoch    178 | Train loss 0.7223  acc 67.8% | Test loss 0.7304  acc 67.5%
# Epoch    179 | Train loss 0.7065  acc 68.3% | Test loss 0.7114  acc 68.0%
# Epoch    180 | Train loss 0.7129  acc 68.2% | Test loss 0.7202  acc 67.8%
# Epoch    181 | Train loss 0.7334  acc 67.8% | Test loss 0.7420  acc 67.2%
# Epoch    182 | Train loss 0.7071  acc 68.6% | Test loss 0.7124  acc 68.0%
# Epoch    183 | Train loss 0.7238  acc 68.5% | Test loss 0.7366  acc 67.8%
# Epoch    184 | Train loss 0.7060  acc 68.6% | Test loss 0.7129  acc 68.2%
# Epoch    185 | Train loss 0.7065  acc 68.7% | Test loss 0.7163  acc 68.1%
# Epoch    186 | Train loss 0.7176  acc 68.0% | Test loss 0.7222  acc 67.4%
# Epoch    187 | Train loss 0.7196  acc 68.0% | Test loss 0.7264  acc 67.7%
# Epoch    188 | Train loss 0.7147  acc 68.3% | Test loss 0.7234  acc 67.9%
# Epoch    189 | Train loss 0.7139  acc 68.5% | Test loss 0.7218  acc 68.2%
# Epoch    190 | Train loss 0.7123  acc 68.3% | Test loss 0.7182  acc 68.1%
# Epoch    191 | Train loss 0.6984  acc 68.7% | Test loss 0.7030  acc 68.5%
# Epoch    192 | Train loss 0.7088  acc 68.6% | Test loss 0.7130  acc 68.5%
# Epoch    193 | Train loss 0.7179  acc 68.0% | Test loss 0.7226  acc 67.7%
# Epoch    194 | Train loss 0.7033  acc 68.8% | Test loss 0.7106  acc 68.4%
# Epoch    195 | Train loss 0.7051  acc 69.1% | Test loss 0.7126  acc 68.7%
# Epoch    196 | Train loss 0.7354  acc 69.8% | Test loss 0.7521  acc 69.2%
# Epoch    197 | Train loss 0.6769  acc 72.2% | Test loss 0.6865  acc 71.8%
# Epoch    198 | Train loss 0.6698  acc 73.7% | Test loss 0.6836  acc 73.5%
# Epoch    199 | Train loss 0.6242  acc 75.1% | Test loss 0.6334  acc 74.9%
# Epoch    200 | Train loss 0.5894  acc 75.6% | Test loss 0.5990  acc 75.3%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 75.3%

# %% [markdown]
# # 9) Loss + Accuracy across runs

# %%
#@title Visualize
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
import logging
import matplotlib.ticker as ticker

# Suppress missing font warnings
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# Prefer the deployment font when available, otherwise fall back to common sans-serif fonts
font_candidates = ['Inter', 'DejaVu Sans', 'Arial', 'Helvetica', 'sans-serif']
plt.rcParams['font.family'] = font_candidates
font_path = 'fonts/Inter-Regular.ttf'
try:
    prop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = prop.get_name()
except Exception:
    pass

# Set styling for all text and lines
plt.rcParams['text.color'] = '#F1F5F9'
plt.rcParams['axes.labelcolor'] = '#F1F5F9'
plt.rcParams['xtick.color'] = '#F1F5F9'
plt.rcParams['ytick.color'] = '#F1F5F9'
plt.rcParams['axes.edgecolor'] = '#F1F5F9'

# Grid styling
plt.rcParams['grid.color'] = '#5B7268'
plt.rcParams['grid.alpha'] = 0.7

def _coplot_luminance_from_rgba(rgba):
    r, g, b = mcolors.to_rgb(rgba)
    def _linear(c):
        return c / 12.92 if c <= 0.03928 else ((c + 0.055) / 1.055) ** 2.4
    return 0.2126 * _linear(r) + 0.7152 * _linear(g) + 0.0722 * _linear(b)

def _coplot_text_color_for_rgba(rgba, preferred='#F1F5F9'):
    try:
        preferred_l = _coplot_luminance_from_rgba(mcolors.to_rgba(preferred))
        bg_l = _coplot_luminance_from_rgba(rgba)
        lighter = max(preferred_l, bg_l)
        darker = min(preferred_l, bg_l)
        ratio = (lighter + 0.05) / (darker + 0.05)
        if ratio >= 4.5:
            return preferred
    except Exception:
        pass
    bg_l = _coplot_luminance_from_rgba(rgba)
    return '#111111' if bg_l > 0.5 else '#FFFFFF'

# Create figure and axis with publication-quality settings
fig, axes = plt.subplots(1, 2, figsize=(14, 5.5), dpi=300)
fig.patch.set_facecolor('#1A3A2A')

# Distinct bright colors for dark background (modified to keep runs distinguishable)
colors = ["#38BDF8", "#34D399", "#FBBF24", "#F87171", "#A78BFA", "#FB923C", "#E879F9"]
line_styles = ["-","--",":","-."]
marker_styles = ["o","s","^","D"]

for idx, run in enumerate(all_runs):
    h = run["history"]

    line_style = line_styles[idx % len(line_styles)] if False else '-'
    marker_style = marker_styles[idx % len(marker_styles)] if False else ''

    # Plot accuracy
    axes[0].plot(h["epoch"], h["test_acc"], label=run["name"],
                 color=colors[idx % len(colors)], linewidth=2,
                 linestyle=line_style, marker=marker_style, alpha=0.9)

    # Plot loss
    axes[1].plot(h["epoch"], h["test_loss"], label=run["name"],
                 color=colors[idx % len(colors)], linewidth=2,
                 linestyle=line_style, marker=marker_style, alpha=0.9)

# Apply custom styling to both axes
for ax in axes:
    ax.set_facecolor('#1A3A2A')
    ax.set_xlabel('Epoch', fontsize=12, labelpad=10, color='#F1F5F9')

    # Force integer epochs
    ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # Add grid
    ax.grid(axis='both', alpha=0.7, color='#5B7268', linestyle='--', linewidth=0.5, zorder=0)
    ax.set_axisbelow(True)

    # Remove top and right spines for cleaner look
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['left'].set_linewidth(1)
    ax.spines['bottom'].set_color('#F1F5F9')
    ax.spines['left'].set_color('#F1F5F9')

    # Adjust spine positions
    ax.spines['left'].set_position(('outward', 2))
    ax.spines['bottom'].set_position(('outward', 2))

    # Add legend
    ax.legend(frameon=False, fontsize=10)

# Specific titles and labels
axes[0].set_ylabel('Test Accuracy', fontsize=12, color='#F1F5F9', labelpad=10)
axes[0].set_title('Test Accuracy by Normalization', color='#F1F5F9', pad=15)
axes[0].yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

axes[1].set_ylabel('Test Loss', fontsize=12, color='#F1F5F9', labelpad=10)
axes[1].set_title('Test Loss by Normalization', color='#F1F5F9', pad=15)
axes[1].set_yscale('linear')
axes[1].set_ylim(top=3.0)
axes[1].set_ylim(bottom=0.0)
axes[1].yaxis.set_major_formatter(ticker.ScalarFormatter())

# Global title
plt.suptitle("Normalization Method Comparison", fontsize=14, y=1.02, color='#F1F5F9')

# Tight layout
plt.tight_layout()
plt.show()

# Summary table
print(f"\n{'Run':<20s} {'Converged Epoch':<20s}")
print("-" * 40)
for run in sorted(all_runs, key=lambda x: (x['converged_epoch'] is None, x['converged_epoch'])):
    ep = run["converged_epoch"]
    print(f"{run['name']:<20s} {str(ep) if ep else 'Did not converge':<20s}")
# Out:
# Run                  Converged Epoch
# ----------------------------------------
# pre-norm LayerNorm   87
# pre-norm RMSNorm     95
# no normalization     Did not converge
# post-norm RMSNorm    Did not converge
# post-norm LayerNorm  Did not converge
# pre-norm BatchNorm   Did not converge
# post-norm BatchNorm  Did not converge

# %% [markdown]
# # 10) Activation values visualized

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
import torch

# Prefer the deployment font when available, otherwise fall back to common sans-serif fonts
font_candidates = ['Inter', 'DejaVu Sans', 'Arial', 'Helvetica', 'sans-serif']
plt.rcParams['font.family'] = font_candidates
font_path = 'fonts/Inter-Regular.ttf'
try:
    prop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = prop.get_name()
except Exception:
    pass

# Set styling for all text and lines
plt.rcParams['text.color'] = '#F1F5F9'
plt.rcParams['axes.labelcolor'] = '#F1F5F9'
plt.rcParams['xtick.color'] = '#F1F5F9'
plt.rcParams['ytick.color'] = '#F1F5F9'
plt.rcParams['axes.edgecolor'] = '#F1F5F9'

# Grid styling
plt.rcParams['grid.color'] = '#5D6674'
plt.rcParams['grid.alpha'] = 0.7

def _coplot_luminance_from_rgba(rgba):
    r, g, b = mcolors.to_rgb(rgba)
    def _linear(c):
        return c / 12.92 if c <= 0.03928 else ((c + 0.055) / 1.055) ** 2.4
    return 0.2126 * _linear(r) + 0.7152 * _linear(g) + 0.0722 * _linear(b)

def _coplot_text_color_for_rgba(rgba, preferred='#F1F5F9'):
    try:
        preferred_l = _coplot_luminance_from_rgba(mcolors.to_rgba(preferred))
        bg_l = _coplot_luminance_from_rgba(rgba)
        lighter = max(preferred_l, bg_l)
        darker = min(preferred_l, bg_l)
        ratio = (lighter + 0.05) / (darker + 0.05)
        if ratio >= 4.5:
            return preferred
    except Exception:
        pass
    bg_l = _coplot_luminance_from_rgba(rgba)
    return '#111111' if bg_l > 0.5 else '#FFFFFF'

# ── Signal survival per layer (post-hoc) ──
xb, yb = next(iter(test_loader))

# Create figure and axis with publication-quality settings
fig, ax = plt.subplots(figsize=(10, 5.5), dpi=300)
fig.patch.set_facecolor('#1E293B')
ax.set_facecolor('#1E293B')

# Define distinct bright colors instead of the same blue, so lines are distinguishable
colors = ["#38BDF8", "#34D399", "#FBBF24", "#F87171", "#A78BFA", "#FB923C", "#E879F9"]
line_styles = ["-","--",":","-."]
marker_styles = ["o","s","^","D"]

for idx, run in enumerate(all_runs):
    model = run["model"].eval()
    if hasattr(model, "_orig_mod"):
        model = model._orig_mod

    magnitudes = []

    handles = []
    def make_hook(store):
        def hook(module, input, output):
            store.append(output.detach().abs().mean().item())
        return hook

    for block in model.layers:
        m = []
        magnitudes.append(m)
        handles.append(block.register_forward_hook(make_hook(m)))

    with torch.no_grad():
        model(xb)

    for h in handles:
        h.remove()

    layer_means = [m[0] for m in magnitudes]

    line_style = line_styles[idx % len(line_styles)] if False else '-'
    marker_style = marker_styles[idx % len(marker_styles)] if False else 'o'

    ax.plot(range(len(layer_means)), layer_means,
           color=colors[idx % len(colors)],
           linewidth=2,
           linestyle=line_style,
           marker=marker_style, markersize=5,
           label=run["name"],
           alpha=0.9)

ax.set_yscale("log")
ax.axhline(y=1.0, color="#F1F5F9", linestyle="--", alpha=0.3, linewidth=1)

# Customize axis labels
ax.set_xlabel('Layer index', fontsize=15, labelpad=10, color='#F1F5F9')
ax.set_ylabel('Activation value', fontsize=15, color='#F1F5F9', labelpad=10)
ax.set_title("Activation values in each layer", fontsize=16, color='#F1F5F9', pad=25)

# Add grid
ax.grid(axis='both', alpha=0.7, color='#5D6674', linestyle='--', linewidth=0.5, zorder=0)
ax.set_axisbelow(True)

# Add legend
ax.legend(loc='upper center',
         bbox_to_anchor=(0.5, 1.05),
         frameon=False, fontsize=12, ncol=3)

# Remove top and right spines for cleaner look
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)
ax.spines['bottom'].set_color('#F1F5F9')
ax.spines['left'].set_color('#F1F5F9')

# Adjust spine positions
ax.spines['left'].set_position(('outward', 2))
ax.spines['bottom'].set_position(('outward', 2))

# Tight layout
plt.tight_layout()

# Display the plot
plt.show()
