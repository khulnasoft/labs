# %%
#@title 0) setup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
import itertools, random, time
import copy

# Reproducibility
SEED = 42
def resetRandom():
  torch.manual_seed(SEED)
  np.random.seed(SEED)
  random.seed(SEED)
resetRandom()

# training time optimization
torch.set_float32_matmul_precision('high')
torch.backends.cudnn.benchmark = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 1) MLP: A * B % C (A,B between 0..99, C 0..19)

# %% [markdown]
# ## 1.1) Dataset

# %%
def one_hot(n, num_classes=100):
    # One-hot encode a single integer.
    v = np.zeros(num_classes, dtype=np.float32)
    v[n] = 1.0
    return v

# ── Generate all 10,000 input pairs ──
pairs = list(itertools.product(range(100), range(100), range(19)))
random.shuffle(pairs)

X_all, y_all = [], []
for a, b, c in pairs:
    x = np.concatenate([one_hot(a), one_hot(b), one_hot(c, 19)])   # 220-dim
    y = (a * b) % (c+1)
    X_all.append(x)
    y_all.append(y)

X_all = np.array(X_all)
y_all = np.array(y_all)

# 80-20 split
split = int(0.8 * len(X_all))
X_train, X_test = X_all[:split], X_all[split:]
y_train, y_test = y_all[:split], y_all[split:]

# DataLoaders — mini-batch (full-batch would be 8K samples)
BATCH_SIZE = 256
train_ds = TensorDataset(torch.tensor(X_train).to(device), torch.tensor(y_train, dtype=torch.long).to(device))
test_ds  = TensorDataset(torch.tensor(X_test).to(device),  torch.tensor(y_test, dtype=torch.long).to(device))
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE)

print(f"Train: {len(train_ds):,} samples  |  Test: {len(test_ds):,} samples")
print(f"Input dim: {X_train.shape[1]}  |  Output classes: {len(np.unique(y_all))}")
print(f"Label distribution (train): {dict(zip(*np.unique(y_train, return_counts=True)))}")
# Out:
# Train: 152,000 samples  |  Test: 38,000 samples
# Input dim: 219  |  Output classes: 19
# Label distribution (train): {np.int64(0): np.int64(51411), np.int64(1): np.int64(11977), np.int64(2): np.int64(14363), np.int64(3): np.int64(10413), np.int64(4): np.int64(11615), np.int64(5): np.int64(6717), np.int64(6): np.int64(10053), np.int64(7): np.int64(4823), np.int64(8): np.int64(6869), np.int64(9): np.int64(4650), np.int64(10): np.int64(4769), np.int64(11): np.int64(2542), np.int64(12): np.int64(4452), np.int64(13): np.int64(1747), np.int64(14): np.int64(2023), np.int64(15): np.int64(1374), np.int64(16): np.int64(1254), np.int64(17): np.int64(538), np.int64(18): np.int64(410)}

# %% [markdown]
# ## 1.2) DNN: 72x2 growing & shrinking FFN w/ Residuals + Normalization

# %%
class DNN(nn.Module):
    def __init__(self, norm_type=None, is_post_norm=False):
        super().__init__()
        self.is_post_norm = is_post_norm
        hidden_dim = 128
        self.proj_in = nn.Linear(219, hidden_dim)
        self.layers = nn.ModuleList()
        self.norms = nn.ModuleList()
        for _ in range(72):
            self.layers.append(
                nn.Sequential(
                    nn.Linear(hidden_dim, hidden_dim * 2),
                    nn.ReLU(),
                    nn.Linear(hidden_dim * 2, hidden_dim))
                )
            if norm_type is not None:
                self.norms.append(norm_type(hidden_dim))
            else:
                self.norms.append(nn.Identity())
        self.proj_out = nn.Linear(hidden_dim, 20)

    def forward(self, x):
        x = F.relu(self.proj_in(x))
        for layer, norm in zip(self.layers, self.norms):
            if self.is_post_norm:
                x = norm(x + layer(x))
            else:
                x = x + layer(norm(x))
        return self.proj_out(x)

model = DNN().to(device)
print(model)

print(f"Total parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Per-layer shapes:")
for name, param in model.named_parameters():
    if "weight" in name:
        print(f"  {name:30s}  {str(list(param.shape)):>15s}  ({param.numel():>6,} params)")
# Out:
# DNN(
#   (proj_in): Linear(in_features=219, out_features=128, bias=True)
#   (layers): ModuleList(
#     (0-71): 72 x Sequential(
#       (0): Linear(in_features=128, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=128, bias=True)
#     )
#   )
#   (norms): ModuleList(
#     (0-71): 72 x Identity()
#   )
#   (proj_out): Linear(in_features=128, out_features=20, bias=True)
# )
# Total parameters: 4,776,980
# Per-layer shapes:
#   proj_in.weight                       [128, 219]  (28,032 params)
#   layers.0.0.weight                    [256, 128]  (32,768 params)
#   layers.0.2.weight                    [128, 256]  (32,768 params)
#   layers.1.0.weight                    [256, 128]  (32,768 params)
#   layers.1.2.weight                    [128, 256]  (32,768 params)
#   layers.2.0.weight                    [256, 128]  (32,768 params)
#   layers.2.2.weight                    [128, 256]  (32,768 params)
#   layers.3.0.weight                    [256, 128]  (32,768 params)
#   layers.3.2.weight                    [128, 256]  (32,768 params)
#   layers.4.0.weight                    [256, 128]  (32,768 params)
#   layers.4.2.weight                    [128, 256]  (32,768 params)
#   layers.5.0.weight                    [256, 128]  (32,768 params)
#   layers.5.2.weight                    [128, 256]  (32,768 params)
#   layers.6.0.weight                    [256, 128]  (32,768 params)
#   layers.6.2.weight                    [128, 256]  (32,768 params)
#   layers.7.0.weight                    [256, 128]  (32,768 params)
#   layers.7.2.weight                    [128, 256]  (32,768 params)
#   layers.8.0.weight                    [256, 128]  (32,768 params)
#   layers.8.2.weight                    [128, 256]  (32,768 params)
#   layers.9.0.weight                    [256, 128]  (32,768 params)
#   layers.9.2.weight                    [128, 256]  (32,768 params)
#   layers.10.0.weight                   [256, 128]  (32,768 params)
#   layers.10.2.weight                   [128, 256]  (32,768 params)
#   layers.11.0.weight                   [256, 128]  (32,768 params)
#   layers.11.2.weight                   [128, 256]  (32,768 params)
#   layers.12.0.weight                   [256, 128]  (32,768 params)
#   layers.12.2.weight                   [128, 256]  (32,768 params)
#   layers.13.0.weight                   [256, 128]  (32,768 params)
#   layers.13.2.weight                   [128, 256]  (32,768 params)
#   layers.14.0.weight                   [256, 128]  (32,768 params)
#   layers.14.2.weight                   [128, 256]  (32,768 params)
#   layers.15.0.weight                   [256, 128]  (32,768 params)
#   layers.15.2.weight                   [128, 256]  (32,768 params)
#   layers.16.0.weight                   [256, 128]  (32,768 params)
#   layers.16.2.weight                   [128, 256]  (32,768 params)
#   layers.17.0.weight                   [256, 128]  (32,768 params)
#   layers.17.2.weight                   [128, 256]  (32,768 params)
#   layers.18.0.weight                   [256, 128]  (32,768 params)
#   layers.18.2.weight                   [128, 256]  (32,768 params)
#   layers.19.0.weight                   [256, 128]  (32,768 params)
#   layers.19.2.weight                   [128, 256]  (32,768 params)
#   layers.20.0.weight                   [256, 128]  (32,768 params)
#   layers.20.2.weight                   [128, 256]  (32,768 params)
#   layers.21.0.weight                   [256, 128]  (32,768 params)
#   layers.49.0.weight                   [256, 128]  (32,768 params)
#   layers.49.2.weight                   [128, 256]  (32,768 params)
#   layers.50.0.weight                   [256, 128]  (32,768 params)
#   layers.50.2.weight                   [128, 256]  (32,768 params)
#   layers.51.0.weight                   [256, 128]  (32,768 params)
#   layers.51.2.weight                   [128, 256]  (32,768 params)
#   layers.52.0.weight                   [256, 128]  (32,768 params)
#   layers.52.2.weight                   [128, 256]  (32,768 params)
#   layers.53.0.weight                   [256, 128]  (32,768 params)
#   layers.53.2.weight                   [128, 256]  (32,768 params)
#   layers.54.0.weight                   [256, 128]  (32,768 params)
#   layers.54.2.weight                   [128, 256]  (32,768 params)
#   layers.55.0.weight                   [256, 128]  (32,768 params)
#   layers.55.2.weight                   [128, 256]  (32,768 params)
#   layers.56.0.weight                   [256, 128]  (32,768 params)
#   layers.56.2.weight                   [128, 256]  (32,768 params)
#   layers.57.0.weight                   [256, 128]  (32,768 params)
#   layers.57.2.weight                   [128, 256]  (32,768 params)
#   layers.58.0.weight                   [256, 128]  (32,768 params)
#   layers.58.2.weight                   [128, 256]  (32,768 params)
#   layers.59.0.weight                   [256, 128]  (32,768 params)
#   layers.59.2.weight                   [128, 256]  (32,768 params)
#   layers.60.0.weight                   [256, 128]  (32,768 params)
#   layers.60.2.weight                   [128, 256]  (32,768 params)
#   layers.61.0.weight                   [256, 128]  (32,768 params)
#   layers.61.2.weight                   [128, 256]  (32,768 params)
#   layers.62.0.weight                   [256, 128]  (32,768 params)
#   layers.62.2.weight                   [128, 256]  (32,768 params)
#   layers.63.0.weight                   [256, 128]  (32,768 params)
#   layers.63.2.weight                   [128, 256]  (32,768 params)
#   layers.64.0.weight                   [256, 128]  (32,768 params)
#   layers.64.2.weight                   [128, 256]  (32,768 params)
#   layers.65.0.weight                   [256, 128]  (32,768 params)
#   layers.65.2.weight                   [128, 256]  (32,768 params)
#   layers.66.0.weight                   [256, 128]  (32,768 params)
#   layers.66.2.weight                   [128, 256]  (32,768 params)
#   layers.67.0.weight                   [256, 128]  (32,768 params)
#   layers.67.2.weight                   [128, 256]  (32,768 params)
#   layers.68.0.weight                   [256, 128]  (32,768 params)
#   layers.68.2.weight                   [128, 256]  (32,768 params)
#   layers.69.0.weight                   [256, 128]  (32,768 params)
#   layers.69.2.weight                   [128, 256]  (32,768 params)
#   layers.70.0.weight                   [256, 128]  (32,768 params)
#   layers.70.2.weight                   [128, 256]  (32,768 params)
#   layers.71.0.weight                   [256, 128]  (32,768 params)
#   layers.71.2.weight                   [128, 256]  (32,768 params)
#   proj_out.weight                       [20, 128]  ( 2,560 params)

# %% [markdown]
# ## 1.3) Train

# %%
# ── Hyperparameters ──
LR = 1e-3
WEIGHT_DECAY = 0.001
MAX_EPOCHS = 200

all_runs = []  # global: stores {"name", "converged_epoch", "history"} per run

def evaluate(loader):
    model.eval()
    total_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for xb, yb in loader:
            logits = model(xb)
            total_loss += criterion(logits, yb).item() * len(yb)
            correct += (logits.argmax(dim=1) == yb).sum().item()
            total += len(yb)
    return total_loss / total, correct / total

def train(run_name="", norm_type=None, is_post_norm=False):
    # Reset model and optimizer
    global model, optimizer, criterion, history
    resetRandom()
    model = DNN(norm_type=norm_type, is_post_norm=is_post_norm).to(device)
    model = torch.compile(model)
    def _init_weights(m):
        if hasattr(m, 'weight') and m.weight.dim() >= 2:
            nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
    model.apply(_init_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    criterion = nn.CrossEntropyLoss()

    # Reset logging
    history = {
        "epoch": [], "train_loss": [], "test_loss": [],
        "train_acc": [], "test_acc": []
    }

    print(f"{'='*60}")
    print(f"  🚀 Run: {run_name}")
    print(f"{'='*60}")

    # ── Training loop ──
    reached_100 = False

    for epoch in range(1, MAX_EPOCHS + 1):
        model.train()
        for xb, yb in train_loader:
            logits = model(xb)
            loss = criterion(logits, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_loss, train_acc = evaluate(train_loader)
        test_loss, test_acc   = evaluate(test_loader)

        history["epoch"].append(epoch)
        history["train_loss"].append(train_loss)
        history["test_loss"].append(test_loss)
        history["train_acc"].append(train_acc)
        history["test_acc"].append(test_acc)

        print(f"Epoch {epoch:>6d} | "
              f"Train loss {train_loss:.4f}  acc {train_acc:.1%} | "
              f"Test loss {test_loss:.4f}  acc {test_acc:.1%}")

        if test_acc >= 0.999 and train_acc >= 0.999:
            print(f"{'='*60}")
            print(f"  ✅ 100% test accuracy reached at epoch {epoch}!")
            print(f"  📊 Final — Train: {train_acc:.2%}  Test: {test_acc:.2%}")
            print(f"{'='*60}")
            reached_100 = True
            break

    if not reached_100:
        print(f"⚠️  Did not reach 100% in {MAX_EPOCHS} epochs.")
        print(f"    Final test acc: {history['test_acc'][-1]:.1%}")

    converged_epoch = epoch if reached_100 else None
    all_runs.append({"name": run_name,
                     "converged_epoch": converged_epoch,
                     "history": dict(history),
                     "model": copy.deepcopy(model)})

# %% [markdown]
# # 2) Baseline: no normalization

# %%
train(run_name="no normalization")
# Out:
# ============================================================
#   🚀 Run: no normalization
# ============================================================
# Epoch      1 | Train loss 121389073484.3149  acc 21.2% | Test loss 121286115027.9141  acc 21.1%
# Epoch      2 | Train loss 44829836890.3276  acc 23.8% | Test loss 44914322647.1478  acc 23.7%
# Epoch      3 | Train loss 27517539460.3655  acc 16.0% | Test loss 27676745394.2838  acc 16.0%
# Epoch      4 | Train loss 15198087110.2248  acc 20.2% | Test loss 15378863679.5958  acc 19.9%
# Epoch      5 | Train loss 7175144089.7078  acc 12.2% | Test loss 7272891337.0274  acc 12.3%
# Epoch      6 | Train loss 7626646540.2880  acc 23.1% | Test loss 7702767939.3684  acc 23.2%
# Epoch      7 | Train loss 5352961760.4177  acc 8.4% | Test loss 5386584535.9023  acc 8.1%
# Epoch      8 | Train loss 3890083551.4476  acc 15.2% | Test loss 3915227168.6602  acc 15.1%
# Epoch      9 | Train loss 2237510610.9440  acc 19.0% | Test loss 2270416276.4261  acc 18.8%
# Epoch     10 | Train loss 1663668594.5263  acc 11.8% | Test loss 1682163596.6114  acc 11.8%
# Epoch     11 | Train loss 1535595706.4219  acc 28.2% | Test loss 1545917875.9545  acc 27.9%
# Epoch     12 | Train loss 1206408124.1465  acc 6.6% | Test loss 1216607527.6665  acc 6.4%
# Epoch     13 | Train loss 1278648939.7895  acc 10.6% | Test loss 1297344853.7465  acc 10.7%
# Epoch    110 | Train loss 4100.0224  acc 14.6% | Test loss 4131.5086  acc 14.3%
# Epoch    111 | Train loss 4630.4208  acc 27.3% | Test loss 4616.9336  acc 27.4%
# Epoch    112 | Train loss 4537.5246  acc 7.7% | Test loss 4554.5633  acc 7.7%
# Epoch    113 | Train loss 2349.3896  acc 21.1% | Test loss 2367.9793  acc 21.0%
# Epoch    114 | Train loss 3285.3217  acc 23.7% | Test loss 3293.1564  acc 23.5%
# Epoch    115 | Train loss 2678.2049  acc 24.2% | Test loss 2711.7229  acc 24.1%
# Epoch    116 | Train loss 1414.5499  acc 23.2% | Test loss 1417.8944  acc 23.0%
# Epoch    117 | Train loss 1318.2929  acc 13.9% | Test loss 1334.9036  acc 13.9%
# Epoch    118 | Train loss 803.4325  acc 25.7% | Test loss 800.1028  acc 25.7%
# Epoch    119 | Train loss 1408.0985  acc 24.6% | Test loss 1405.1831  acc 24.4%
# Epoch    120 | Train loss 866.9744  acc 9.9% | Test loss 867.7880  acc 9.7%
# Epoch    121 | Train loss 605.8785  acc 10.7% | Test loss 607.2969  acc 10.9%
# Epoch    122 | Train loss 602.5948  acc 8.9% | Test loss 602.4954  acc 8.8%
# Epoch    123 | Train loss 449.2029  acc 25.6% | Test loss 450.0959  acc 25.4%
# Epoch    124 | Train loss 369.4053  acc 10.1% | Test loss 366.9903  acc 9.7%
# Epoch    125 | Train loss 1436.4593  acc 14.2% | Test loss 1431.2581  acc 13.9%
# Epoch    126 | Train loss 874.5535  acc 16.4% | Test loss 878.7366  acc 16.1%
# Epoch    127 | Train loss 627.0806  acc 13.6% | Test loss 634.7871  acc 13.5%
# Epoch    128 | Train loss 349.1700  acc 19.1% | Test loss 354.4553  acc 18.9%
# Epoch    129 | Train loss 298.1101  acc 13.5% | Test loss 302.8079  acc 13.4%
# Epoch    130 | Train loss 522.1180  acc 13.1% | Test loss 524.7885  acc 13.1%
# Epoch    131 | Train loss 195.1297  acc 17.4% | Test loss 198.7069  acc 17.5%
# Epoch    132 | Train loss 196.9780  acc 24.7% | Test loss 200.8182  acc 24.7%
# Epoch    133 | Train loss 151.7006  acc 13.6% | Test loss 152.6662  acc 13.7%
# Epoch    134 | Train loss 183.2835  acc 8.2% | Test loss 184.4019  acc 8.4%
# Epoch    135 | Train loss 231.1202  acc 11.9% | Test loss 232.5982  acc 11.6%
# Epoch    136 | Train loss 103.4433  acc 27.2% | Test loss 104.0407  acc 27.1%
# Epoch    137 | Train loss 77.3312  acc 26.6% | Test loss 78.9287  acc 26.6%
# Epoch    138 | Train loss 344.3385  acc 15.7% | Test loss 339.1624  acc 15.7%
# Epoch    139 | Train loss 231.8772  acc 23.4% | Test loss 229.3645  acc 23.4%
# Epoch    140 | Train loss 133.4742  acc 19.3% | Test loss 132.6358  acc 19.0%
# Epoch    141 | Train loss 82.2105  acc 16.9% | Test loss 82.7738  acc 16.8%
# Epoch    142 | Train loss 97.1540  acc 5.1% | Test loss 98.0823  acc 5.3%
# Epoch    143 | Train loss 70.4467  acc 7.6% | Test loss 71.1298  acc 7.4%
# Epoch    144 | Train loss 42.6152  acc 11.8% | Test loss 43.4992  acc 11.6%
# Epoch    145 | Train loss 47.0999  acc 7.4% | Test loss 47.5143  acc 7.2%
# Epoch    146 | Train loss 20.9359  acc 20.1% | Test loss 21.2429  acc 20.0%
# Epoch    147 | Train loss 35.7514  acc 25.6% | Test loss 36.2234  acc 25.5%
# Epoch    148 | Train loss 31.4211  acc 15.7% | Test loss 31.7695  acc 15.3%
# Epoch    149 | Train loss 16.3453  acc 12.4% | Test loss 16.5157  acc 12.5%
# Epoch    150 | Train loss 26.5397  acc 23.0% | Test loss 26.7389  acc 23.1%
# Epoch    151 | Train loss 15.1979  acc 9.8% | Test loss 15.2903  acc 9.6%
# Epoch    152 | Train loss 13.1172  acc 17.5% | Test loss 13.2696  acc 17.0%
# Epoch    153 | Train loss 9.4247  acc 21.8% | Test loss 9.4479  acc 21.6%
# Epoch    154 | Train loss 7.1935  acc 20.4% | Test loss 7.3487  acc 20.3%
# Epoch    155 | Train loss 5.2950  acc 29.1% | Test loss 5.3528  acc 29.1%
# Epoch    156 | Train loss 217.7866  acc 15.3% | Test loss 219.4908  acc 14.9%
# Epoch    157 | Train loss 42.1332  acc 14.0% | Test loss 42.6822  acc 13.7%
# Epoch    158 | Train loss 35.1532  acc 20.3% | Test loss 35.2811  acc 20.1%
# Epoch    159 | Train loss 22.3727  acc 10.3% | Test loss 22.4862  acc 10.3%
# Epoch    160 | Train loss 13.4380  acc 15.3% | Test loss 13.5701  acc 15.2%
# Epoch    161 | Train loss 10.0604  acc 22.1% | Test loss 10.1587  acc 21.7%
# Epoch    162 | Train loss 10.3811  acc 21.8% | Test loss 10.4360  acc 21.5%
# Epoch    163 | Train loss 7.6902  acc 23.8% | Test loss 7.7831  acc 23.4%
# Epoch    164 | Train loss 6.3610  acc 21.3% | Test loss 6.3882  acc 20.9%
# Epoch    165 | Train loss 6.6728  acc 18.6% | Test loss 6.6737  acc 18.4%
# Epoch    166 | Train loss 6.5509  acc 23.4% | Test loss 6.5951  acc 22.9%
# Epoch    167 | Train loss 4.6077  acc 20.1% | Test loss 4.6618  acc 19.9%
# Epoch    168 | Train loss 4.2953  acc 29.7% | Test loss 4.3213  acc 29.4%
# Epoch    169 | Train loss 3.6029  acc 26.7% | Test loss 3.6407  acc 26.5%
# Epoch    170 | Train loss 9.2424  acc 18.0% | Test loss 9.1850  acc 17.9%
# Epoch    171 | Train loss 5.2097  acc 16.6% | Test loss 5.1840  acc 16.6%
# Epoch    172 | Train loss 5.0056  acc 20.0% | Test loss 5.0161  acc 19.9%
# Epoch    173 | Train loss 3.2131  acc 23.7% | Test loss 3.2252  acc 23.3%
# Epoch    174 | Train loss 3.3301  acc 27.0% | Test loss 3.3405  acc 26.7%
# Epoch    175 | Train loss 3.1537  acc 25.9% | Test loss 3.1781  acc 25.9%
# Epoch    176 | Train loss 2.7476  acc 30.8% | Test loss 2.7762  acc 30.4%
# Epoch    177 | Train loss 2.6148  acc 20.2% | Test loss 2.6476  acc 19.4%
# Epoch    178 | Train loss 2.5113  acc 32.9% | Test loss 2.5389  acc 32.5%
# Epoch    179 | Train loss 2.3855  acc 32.7% | Test loss 2.4125  acc 32.5%
# Epoch    180 | Train loss 2.3800  acc 33.4% | Test loss 2.4043  acc 33.2%
# Epoch    181 | Train loss 2.2945  acc 32.1% | Test loss 2.3148  acc 31.6%
# Epoch    182 | Train loss 2.3154  acc 33.2% | Test loss 2.3423  acc 33.0%
# Epoch    183 | Train loss 2.2205  acc 30.2% | Test loss 2.2396  acc 29.8%
# Epoch    184 | Train loss 2.2338  acc 28.7% | Test loss 2.2510  acc 28.3%
# Epoch    185 | Train loss 1.9498  acc 34.0% | Test loss 1.9665  acc 33.6%
# Epoch    186 | Train loss 2.0055  acc 33.4% | Test loss 2.0205  acc 33.0%
# Epoch    187 | Train loss 1.9158  acc 37.0% | Test loss 1.9366  acc 36.6%
# Epoch    188 | Train loss 1.7864  acc 39.4% | Test loss 1.8026  acc 39.1%
# Epoch    189 | Train loss 1.7601  acc 40.7% | Test loss 1.7775  acc 40.2%
# Epoch    190 | Train loss 1.6478  acc 43.8% | Test loss 1.6753  acc 43.0%
# Epoch    191 | Train loss 1.4972  acc 47.1% | Test loss 1.5263  acc 46.4%
# Epoch    192 | Train loss 1.5144  acc 47.6% | Test loss 1.5419  acc 46.9%
# Epoch    193 | Train loss 1.4584  acc 48.8% | Test loss 1.4762  acc 48.2%
# Epoch    194 | Train loss 35.2835  acc 15.1% | Test loss 34.9954  acc 14.9%
# Epoch    195 | Train loss 2.7726  acc 31.1% | Test loss 2.7859  acc 30.9%
# Epoch    196 | Train loss 2.2990  acc 34.3% | Test loss 2.3098  acc 34.3%
# Epoch    197 | Train loss 2.2748  acc 32.3% | Test loss 2.2862  acc 32.1%
# Epoch    198 | Train loss 2.0903  acc 35.4% | Test loss 2.1096  acc 35.0%
# Epoch    199 | Train loss 2.2100  acc 35.0% | Test loss 2.2321  acc 34.6%
# Epoch    200 | Train loss 2.0189  acc 35.2% | Test loss 2.0418  acc 34.8%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 34.8%

# %% [markdown]
# # 3) Pre-norm RMSNorm

# %%
train(run_name="pre-norm RMSNorm", norm_type=nn.RMSNorm)
# Out:
# ============================================================
#   🚀 Run: pre-norm RMSNorm
# ============================================================
# Epoch      1 | Train loss 1.7750  acc 43.3% | Test loss 1.8200  acc 42.4%
# Epoch      2 | Train loss 1.2848  acc 54.4% | Test loss 1.3194  acc 53.6%
# Epoch      3 | Train loss 1.1626  acc 54.7% | Test loss 1.1861  acc 54.0%
# Epoch      4 | Train loss 1.1609  acc 55.1% | Test loss 1.1858  acc 54.0%
# Epoch      5 | Train loss 1.1930  acc 55.0% | Test loss 1.2174  acc 54.1%
# Epoch      6 | Train loss 1.1160  acc 54.9% | Test loss 1.1430  acc 53.9%
# Epoch      7 | Train loss 1.0549  acc 58.6% | Test loss 1.0765  acc 57.6%
# Epoch      8 | Train loss 0.9583  acc 60.9% | Test loss 0.9749  acc 60.3%
# Epoch     44 | Train loss 0.0521  acc 97.4% | Test loss 0.0578  acc 97.1%
# Epoch     45 | Train loss 0.0575  acc 97.1% | Test loss 0.0621  acc 96.6%
# Epoch     46 | Train loss 0.0457  acc 97.4% | Test loss 0.0515  acc 97.1%
# Epoch     47 | Train loss 0.0672  acc 96.9% | Test loss 0.0800  acc 96.5%
# Epoch     48 | Train loss 0.0477  acc 97.6% | Test loss 0.0521  acc 97.2%
# Epoch     49 | Train loss 0.0428  acc 97.6% | Test loss 0.0490  acc 97.2%
# Epoch     50 | Train loss 0.0491  acc 97.6% | Test loss 0.0547  acc 97.2%
# Epoch     51 | Train loss 0.0617  acc 97.2% | Test loss 0.0666  acc 96.7%
# Epoch     52 | Train loss 0.0359  acc 98.3% | Test loss 0.0411  acc 97.8%
# Epoch     53 | Train loss 0.0339  acc 98.6% | Test loss 0.0432  acc 98.2%
# Epoch     54 | Train loss 0.0240  acc 99.2% | Test loss 0.0329  acc 98.8%
# Epoch     55 | Train loss 0.0461  acc 99.1% | Test loss 0.0483  acc 99.0%
# Epoch     56 | Train loss 0.0105  acc 99.6% | Test loss 0.0135  acc 99.6%
# Epoch     57 | Train loss 0.0210  acc 99.3% | Test loss 0.0255  acc 99.2%
# Epoch     58 | Train loss 0.0338  acc 99.2% | Test loss 0.0354  acc 99.2%
# Epoch     59 | Train loss 0.0131  acc 99.7% | Test loss 0.0171  acc 99.5%
# Epoch     60 | Train loss 0.0071  acc 99.8% | Test loss 0.0090  acc 99.7%
# Epoch     61 | Train loss 0.0110  acc 99.7% | Test loss 0.0127  acc 99.7%
# Epoch     62 | Train loss 0.0263  acc 99.2% | Test loss 0.0295  acc 99.1%
# Epoch     63 | Train loss 0.0071  acc 99.8% | Test loss 0.0097  acc 99.7%
# Epoch     64 | Train loss 0.0086  acc 99.7% | Test loss 0.0117  acc 99.7%
# Epoch     65 | Train loss 0.0145  acc 99.6% | Test loss 0.0166  acc 99.5%
# Epoch     66 | Train loss 0.0143  acc 99.5% | Test loss 0.0164  acc 99.4%
# Epoch     67 | Train loss 0.0308  acc 99.0% | Test loss 0.0328  acc 99.0%
# Epoch     68 | Train loss 0.0048  acc 99.9% | Test loss 0.0057  acc 99.9%
# Epoch     69 | Train loss 0.0147  acc 99.5% | Test loss 0.0166  acc 99.5%
# Epoch     70 | Train loss 0.0059  acc 99.8% | Test loss 0.0087  acc 99.8%
# Epoch     71 | Train loss 0.0029  acc 99.9% | Test loss 0.0034  acc 99.9%
# ============================================================
#   ✅ 100% test accuracy reached at epoch 71!
#   📊 Final — Train: 99.92%  Test: 99.91%
# ============================================================

# %% [markdown]
# # 4) Post-norm RMSNorm

# %%
train(run_name="post-norm RMSNorm", norm_type=nn.RMSNorm, is_post_norm=True)
# Out:
# ============================================================
#   🚀 Run: post-norm RMSNorm
# ============================================================
# Epoch      1 | Train loss 2.3597  acc 33.8% | Test loss 2.3661  acc 33.6%
# Epoch      2 | Train loss 2.3608  acc 33.8% | Test loss 2.3668  acc 33.6%
# Epoch      3 | Train loss 2.3551  acc 33.8% | Test loss 2.3603  acc 33.6%
# Epoch      4 | Train loss 2.3564  acc 33.8% | Test loss 2.3615  acc 33.6%
# Epoch      5 | Train loss 2.3565  acc 33.8% | Test loss 2.3610  acc 33.6%
# Epoch      6 | Train loss 2.3576  acc 33.8% | Test loss 2.3646  acc 33.6%
# Epoch      7 | Train loss 2.3539  acc 33.8% | Test loss 2.3588  acc 33.6%
# Epoch      8 | Train loss 2.3529  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch      9 | Train loss 2.3560  acc 33.8% | Test loss 2.3612  acc 33.6%
# Epoch     10 | Train loss 2.3539  acc 33.8% | Test loss 2.3594  acc 33.6%
# Epoch     11 | Train loss 2.3540  acc 33.8% | Test loss 2.3599  acc 33.6%
# Epoch     12 | Train loss 2.3546  acc 33.8% | Test loss 2.3602  acc 33.6%
# Epoch     13 | Train loss 2.3557  acc 33.8% | Test loss 2.3614  acc 33.6%
# Epoch     14 | Train loss 2.3550  acc 33.8% | Test loss 2.3599  acc 33.6%
# Epoch     15 | Train loss 2.3526  acc 33.8% | Test loss 2.3578  acc 33.6%
# Epoch     16 | Train loss 2.3530  acc 33.8% | Test loss 2.3580  acc 33.6%
# Epoch     17 | Train loss 2.3546  acc 33.8% | Test loss 2.3601  acc 33.6%
# Epoch     18 | Train loss 2.3533  acc 33.8% | Test loss 2.3585  acc 33.6%
# Epoch     19 | Train loss 2.3529  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch     20 | Train loss 2.3529  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch     21 | Train loss 2.3529  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch     22 | Train loss 2.3531  acc 33.8% | Test loss 2.3588  acc 33.6%
# Epoch     23 | Train loss 2.3525  acc 33.8% | Test loss 2.3582  acc 33.6%
# Epoch     24 | Train loss 2.3530  acc 33.8% | Test loss 2.3585  acc 33.6%
# Epoch     25 | Train loss 2.3526  acc 33.8% | Test loss 2.3577  acc 33.6%
# Epoch     26 | Train loss 2.3532  acc 33.8% | Test loss 2.3590  acc 33.6%
# Epoch     27 | Train loss 2.3518  acc 33.8% | Test loss 2.3572  acc 33.6%
# Epoch     28 | Train loss 2.3531  acc 33.8% | Test loss 2.3575  acc 33.6%
# Epoch     29 | Train loss 2.3516  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     30 | Train loss 2.3517  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch     31 | Train loss 2.3521  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     32 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     33 | Train loss 2.3534  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch     34 | Train loss 2.3521  acc 33.8% | Test loss 2.3578  acc 33.6%
# Epoch     35 | Train loss 2.3513  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     36 | Train loss 2.3517  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch     37 | Train loss 2.3519  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch     38 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     39 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     40 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     41 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     42 | Train loss 2.3521  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch     43 | Train loss 2.3514  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     44 | Train loss 2.3517  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     45 | Train loss 2.3515  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     46 | Train loss 2.3517  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     47 | Train loss 2.3515  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     48 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     49 | Train loss 2.3515  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     50 | Train loss 2.3515  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     51 | Train loss 2.3516  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     52 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     53 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     54 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     55 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     56 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     57 | Train loss 2.3515  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     58 | Train loss 2.3515  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     59 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     60 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     61 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     62 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     63 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     64 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     65 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     66 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     67 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     68 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     69 | Train loss 2.3512  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     70 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     71 | Train loss 2.3514  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     72 | Train loss 2.3512  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     73 | Train loss 2.3520  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     74 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     75 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     76 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     77 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     78 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     79 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     80 | Train loss 2.3515  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     81 | Train loss 2.3514  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     82 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     83 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     84 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     85 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     86 | Train loss 2.3513  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     87 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     88 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     89 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     90 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     91 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     92 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     93 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     94 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     95 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     96 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     97 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     98 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     99 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    100 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    101 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    102 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    103 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    104 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    105 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    106 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    107 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    108 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    109 | Train loss 2.3514  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    110 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    111 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    112 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    113 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    114 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    115 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    116 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    117 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    118 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    119 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    120 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    121 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    122 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    123 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    124 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    125 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch    126 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    127 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    128 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    129 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    130 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    131 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    132 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    133 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    134 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    135 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    136 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    137 | Train loss 2.3509  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    138 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    139 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    140 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    141 | Train loss 2.3514  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    142 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    143 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    144 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    145 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    146 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    147 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    148 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    149 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    150 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    151 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    152 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    153 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    154 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    155 | Train loss 2.3510  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    156 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    157 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    158 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    159 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    160 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    161 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    162 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    163 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    164 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    165 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    166 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    167 | Train loss 2.3510  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    168 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    169 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    170 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    171 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    172 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    173 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    174 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    175 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    176 | Train loss 2.3509  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    177 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    178 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    179 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    180 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    181 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    182 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    183 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    184 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    185 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    186 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    187 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    188 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    189 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    190 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    191 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    192 | Train loss 2.3510  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    193 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    194 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    195 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    196 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    197 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    198 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    199 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    200 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 33.6%

# %% [markdown]
# # 5) Pre-norm LayerNorm

# %%
train(run_name="pre-norm LayerNorm", norm_type=nn.LayerNorm)
# Out:
# ============================================================
#   🚀 Run: pre-norm LayerNorm
# ============================================================
# W0328 10:21:10.651000 7212 torch/_dynamo/convert_frame.py:1676] [1/8] torch._dynamo hit config.recompile_limit (8)
# W0328 10:21:10.651000 7212 torch/_dynamo/convert_frame.py:1676] [1/8]    function: 'forward' (/tmp/ipykernel_7212/3363611922.py:22)
# W0328 10:21:10.651000 7212 torch/_dynamo/convert_frame.py:1676] [1/8]    last reason: 1/7: GLOBAL_STATE changed: grad_mode
# W0328 10:21:10.651000 7212 torch/_dynamo/convert_frame.py:1676] [1/8] To log all recompilation reasons, use TORCH_LOGS="recompiles".
# W0328 10:21:10.651000 7212 torch/_dynamo/convert_frame.py:1676] [1/8] To diagnose recompilation issues, see https://pytorch.org/docs/main/compile/programming_model.recompilation.html
# Epoch      1 | Train loss 1.7359  acc 44.0% | Test loss 1.7869  acc 42.8%
# Epoch      2 | Train loss 1.1813  acc 54.6% | Test loss 1.2211  acc 53.4%
# Epoch      3 | Train loss 1.1829  acc 54.6% | Test loss 1.2185  acc 53.7%
# Epoch      4 | Train loss 1.0961  acc 55.3% | Test loss 1.1284  acc 53.7%
# Epoch      5 | Train loss 1.1458  acc 55.0% | Test loss 1.1811  acc 54.2%
# Epoch      6 | Train loss 1.0902  acc 55.4% | Test loss 1.1215  acc 54.2%
# Epoch      7 | Train loss 1.1203  acc 55.9% | Test loss 1.1504  acc 54.9%
# Epoch      8 | Train loss 0.9293  acc 63.3% | Test loss 0.9555  acc 62.4%
# Epoch      9 | Train loss 0.8567  acc 65.3% | Test loss 0.8717  acc 64.6%
# Epoch     10 | Train loss 0.8309  acc 65.7% | Test loss 0.8493  acc 64.7%
# Epoch     11 | Train loss 0.8326  acc 65.8% | Test loss 0.8525  acc 64.9%
# Epoch     12 | Train loss 0.8525  acc 65.6% | Test loss 0.8663  acc 64.9%
# Epoch     13 | Train loss 0.7948  acc 68.3% | Test loss 0.8182  acc 67.1%
# Epoch     14 | Train loss 0.6980  acc 72.9% | Test loss 0.7098  acc 72.5%
# Epoch     15 | Train loss 0.6811  acc 73.5% | Test loss 0.6876  acc 73.1%
# Epoch     16 | Train loss 0.6498  acc 74.5% | Test loss 0.6591  acc 73.8%
# Epoch     17 | Train loss 0.5995  acc 77.4% | Test loss 0.6088  acc 76.9%
# Epoch     18 | Train loss 0.5767  acc 78.3% | Test loss 0.5821  acc 77.8%
# Epoch     19 | Train loss 0.5617  acc 79.1% | Test loss 0.5730  acc 78.7%
# Epoch     20 | Train loss 0.5463  acc 80.2% | Test loss 0.5535  acc 79.9%
# Epoch     21 | Train loss 0.5232  acc 80.9% | Test loss 0.5275  acc 80.7%
# Epoch     22 | Train loss 0.5239  acc 81.1% | Test loss 0.5333  acc 80.6%
# Epoch     23 | Train loss 0.5193  acc 81.6% | Test loss 0.5286  acc 81.3%
# Epoch     24 | Train loss 0.5000  acc 82.3% | Test loss 0.5092  acc 81.8%
# Epoch     59 | Train loss 0.0206  acc 99.5% | Test loss 0.0250  acc 99.4%
# Epoch     60 | Train loss 0.0236  acc 99.2% | Test loss 0.0291  acc 99.1%
# Epoch     61 | Train loss 0.0137  acc 99.5% | Test loss 0.0161  acc 99.5%
# Epoch     62 | Train loss 0.0281  acc 99.3% | Test loss 0.0362  acc 99.2%
# Epoch     63 | Train loss 0.0083  acc 99.7% | Test loss 0.0121  acc 99.6%
# Epoch     64 | Train loss 0.0266  acc 99.4% | Test loss 0.0305  acc 99.3%
# Epoch     65 | Train loss 0.0056  acc 99.8% | Test loss 0.0078  acc 99.7%
# Epoch     66 | Train loss 0.0237  acc 99.2% | Test loss 0.0277  acc 99.1%
# Epoch     67 | Train loss 0.0303  acc 99.0% | Test loss 0.0347  acc 98.8%
# Epoch     68 | Train loss 0.0153  acc 99.5% | Test loss 0.0183  acc 99.4%
# Epoch     69 | Train loss 0.0210  acc 99.4% | Test loss 0.0270  acc 99.2%
# Epoch     70 | Train loss 0.0180  acc 99.5% | Test loss 0.0208  acc 99.3%
# Epoch     71 | Train loss 0.0111  acc 99.7% | Test loss 0.0129  acc 99.7%
# Epoch     72 | Train loss 0.0078  acc 99.7% | Test loss 0.0118  acc 99.6%
# Epoch     73 | Train loss 0.0255  acc 99.3% | Test loss 0.0285  acc 99.2%
# Epoch     74 | Train loss 0.0176  acc 99.6% | Test loss 0.0231  acc 99.5%
# Epoch     75 | Train loss 0.0118  acc 99.7% | Test loss 0.0142  acc 99.6%
# Epoch     76 | Train loss 0.0082  acc 99.7% | Test loss 0.0103  acc 99.6%
# Epoch     77 | Train loss 0.0059  acc 99.8% | Test loss 0.0075  acc 99.8%
# Epoch     78 | Train loss 0.0020  acc 99.9% | Test loss 0.0024  acc 99.9%
# ============================================================
#   ✅ 100% test accuracy reached at epoch 78!
#   📊 Final — Train: 99.93%  Test: 99.93%
# ============================================================

# %% [markdown]
# # 6) Post-norm LayerNorm

# %%
train(run_name="post-norm LayerNorm", norm_type=nn.LayerNorm, is_post_norm=True)
# Out:
# ============================================================
#   🚀 Run: post-norm LayerNorm
# ============================================================
# Epoch      1 | Train loss 2.3596  acc 33.8% | Test loss 2.3659  acc 33.6%
# Epoch      2 | Train loss 2.3611  acc 33.8% | Test loss 2.3669  acc 33.6%
# Epoch      3 | Train loss 2.3549  acc 33.8% | Test loss 2.3601  acc 33.6%
# Epoch      4 | Train loss 2.3561  acc 33.8% | Test loss 2.3612  acc 33.6%
# Epoch      5 | Train loss 2.3562  acc 33.8% | Test loss 2.3608  acc 33.6%
# Epoch      6 | Train loss 2.3572  acc 33.8% | Test loss 2.3642  acc 33.6%
# Epoch      7 | Train loss 2.3537  acc 33.8% | Test loss 2.3587  acc 33.6%
# Epoch      8 | Train loss 2.3528  acc 33.8% | Test loss 2.3578  acc 33.6%
# Epoch      9 | Train loss 2.3556  acc 33.8% | Test loss 2.3609  acc 33.6%
# Epoch     10 | Train loss 2.3538  acc 33.8% | Test loss 2.3593  acc 33.6%
# Epoch     11 | Train loss 2.3533  acc 33.8% | Test loss 2.3591  acc 33.6%
# Epoch     12 | Train loss 2.3543  acc 33.8% | Test loss 2.3599  acc 33.6%
# Epoch     13 | Train loss 2.3559  acc 33.8% | Test loss 2.3615  acc 33.6%
# Epoch     14 | Train loss 2.3546  acc 33.8% | Test loss 2.3595  acc 33.6%
# Epoch     15 | Train loss 2.3523  acc 33.8% | Test loss 2.3575  acc 33.6%
# Epoch     16 | Train loss 2.3530  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch     17 | Train loss 2.3536  acc 33.8% | Test loss 2.3592  acc 33.6%
# Epoch     18 | Train loss 2.3529  acc 33.8% | Test loss 2.3581  acc 33.6%
# Epoch     19 | Train loss 2.3528  acc 33.8% | Test loss 2.3577  acc 33.6%
# Epoch     20 | Train loss 2.3526  acc 33.8% | Test loss 2.3577  acc 33.6%
# Epoch     21 | Train loss 2.3526  acc 33.8% | Test loss 2.3578  acc 33.6%
# Epoch     22 | Train loss 2.3526  acc 33.8% | Test loss 2.3582  acc 33.6%
# Epoch     23 | Train loss 2.3523  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch     24 | Train loss 2.3527  acc 33.8% | Test loss 2.3582  acc 33.6%
# Epoch     25 | Train loss 2.3524  acc 33.8% | Test loss 2.3574  acc 33.6%
# Epoch     26 | Train loss 2.3530  acc 33.8% | Test loss 2.3586  acc 33.6%
# Epoch     27 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     28 | Train loss 2.3529  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch     29 | Train loss 2.3516  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     30 | Train loss 2.3515  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     31 | Train loss 2.3520  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     32 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     33 | Train loss 2.3530  acc 33.8% | Test loss 2.3575  acc 33.6%
# Epoch     34 | Train loss 2.3519  acc 33.8% | Test loss 2.3575  acc 33.6%
# Epoch     35 | Train loss 2.3514  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     36 | Train loss 2.3517  acc 33.8% | Test loss 2.3572  acc 33.6%
# Epoch     37 | Train loss 2.3518  acc 33.8% | Test loss 2.3572  acc 33.6%
# Epoch     38 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     39 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     40 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     41 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     42 | Train loss 2.3522  acc 33.8% | Test loss 2.3575  acc 33.6%
# Epoch     43 | Train loss 2.3513  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     44 | Train loss 2.3517  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     45 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     46 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     47 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     48 | Train loss 2.3514  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     49 | Train loss 2.3517  acc 33.8% | Test loss 2.3571  acc 33.6%
# Epoch     50 | Train loss 2.3514  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     51 | Train loss 2.3515  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     52 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     53 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     54 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     55 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     56 | Train loss 2.3512  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     57 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     58 | Train loss 2.3516  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     59 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     60 | Train loss 2.3513  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch     61 | Train loss 2.3515  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     62 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     63 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     64 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     65 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     66 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     67 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     68 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     69 | Train loss 2.3512  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     70 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     71 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     72 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     73 | Train loss 2.3524  acc 33.8% | Test loss 2.3574  acc 33.6%
# Epoch     74 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     75 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     76 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     77 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     78 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     79 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     80 | Train loss 2.3514  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     81 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     82 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     83 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     84 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     85 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     86 | Train loss 2.3514  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     87 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     88 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     89 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch     90 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     91 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch     92 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     93 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     94 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     95 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     96 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     97 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     98 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     99 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    100 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    101 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    102 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    103 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    104 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    105 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    106 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    107 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    108 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    109 | Train loss 2.3515  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    110 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    111 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    112 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    113 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    114 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    115 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    116 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    117 | Train loss 2.3515  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    118 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    119 | Train loss 2.3510  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    120 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    121 | Train loss 2.3514  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    122 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    123 | Train loss 2.3513  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    124 | Train loss 2.3514  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    125 | Train loss 2.3516  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    126 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    127 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    128 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    129 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    130 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    131 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    132 | Train loss 2.3514  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    133 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    134 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    135 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    136 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    137 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    138 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    139 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    140 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    141 | Train loss 2.3515  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    142 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    143 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    144 | Train loss 2.3509  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    145 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    146 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    147 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    148 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    149 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    150 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    151 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    152 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    153 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    154 | Train loss 2.3515  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    155 | Train loss 2.3512  acc 33.8% | Test loss 2.3561  acc 33.6%
# Epoch    156 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    157 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    158 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    159 | Train loss 2.3513  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    160 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    161 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    162 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    163 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    164 | Train loss 2.3515  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch    165 | Train loss 2.3510  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    166 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    167 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    168 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    169 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    170 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    171 | Train loss 2.3510  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    172 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    173 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    174 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    175 | Train loss 2.3512  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    176 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    177 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    178 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    179 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    180 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    181 | Train loss 2.3515  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    182 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    183 | Train loss 2.3509  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    184 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    185 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    186 | Train loss 2.3511  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    187 | Train loss 2.3511  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    188 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    189 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    190 | Train loss 2.3511  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    191 | Train loss 2.3513  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    192 | Train loss 2.3512  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    193 | Train loss 2.3512  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch    194 | Train loss 2.3509  acc 33.8% | Test loss 2.3562  acc 33.6%
# Epoch    195 | Train loss 2.3511  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch    196 | Train loss 2.3511  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    197 | Train loss 2.3510  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    198 | Train loss 2.3512  acc 33.8% | Test loss 2.3563  acc 33.6%
# Epoch    199 | Train loss 2.3512  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch    200 | Train loss 2.3510  acc 33.8% | Test loss 2.3563  acc 33.6%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 33.6%

# %% [markdown]
# # 7) Pre-norm BatchNorm

# %%
train(run_name="pre-norm BatchNorm", norm_type=nn.BatchNorm1d)
# Out:
# ============================================================
#   🚀 Run: pre-norm BatchNorm
# ============================================================
# Epoch      1 | Train loss 1.8387  acc 39.6% | Test loss 1.9062  acc 38.2%
# Epoch      2 | Train loss 1.2297  acc 53.3% | Test loss 1.2975  acc 51.1%
# Epoch      3 | Train loss 1.0717  acc 56.0% | Test loss 1.1357  acc 53.4%
# Epoch      4 | Train loss 1.1591  acc 54.6% | Test loss 1.2040  acc 52.7%
# Epoch      5 | Train loss 1.1199  acc 55.5% | Test loss 1.1614  acc 53.9%
# Epoch      6 | Train loss 1.0480  acc 57.8% | Test loss 1.0901  acc 56.2%
# Epoch      7 | Train loss 0.9360  acc 61.6% | Test loss 0.9759  acc 59.7%
# Epoch      8 | Train loss 0.9144  acc 62.3% | Test loss 0.9599  acc 59.7%
# Epoch      9 | Train loss 1.0277  acc 60.5% | Test loss 1.0682  acc 59.2%
# Epoch     10 | Train loss 0.9243  acc 62.0% | Test loss 0.9621  acc 59.8%
# Epoch     11 | Train loss 0.9296  acc 61.9% | Test loss 0.9713  acc 59.7%
# Epoch     12 | Train loss 0.9089  acc 62.6% | Test loss 0.9558  acc 59.8%
# Epoch     13 | Train loss 0.8959  acc 63.3% | Test loss 0.9447  acc 60.1%
# Epoch     14 | Train loss 0.9088  acc 63.7% | Test loss 0.9662  acc 60.5%
# Epoch     15 | Train loss 0.8674  acc 66.5% | Test loss 0.9319  acc 63.1%
# Epoch     16 | Train loss 0.6864  acc 73.8% | Test loss 0.7371  acc 70.5%
# Epoch     17 | Train loss 0.6093  acc 77.0% | Test loss 0.6503  acc 75.0%
# Epoch     18 | Train loss 0.5840  acc 78.2% | Test loss 0.6197  acc 76.4%
# Epoch     19 | Train loss 0.5602  acc 79.0% | Test loss 0.5982  acc 77.1%
# Epoch     20 | Train loss 1.0112  acc 68.4% | Test loss 1.0640  acc 67.3%
# Epoch     21 | Train loss 0.5739  acc 79.2% | Test loss 0.6073  acc 77.7%
# Epoch     22 | Train loss 0.5447  acc 80.3% | Test loss 0.5816  acc 78.7%
# Epoch     23 | Train loss 0.4966  acc 82.9% | Test loss 0.5334  acc 81.4%
# Epoch     24 | Train loss 0.4862  acc 83.3% | Test loss 0.5210  acc 82.1%
# Epoch     25 | Train loss 0.4789  acc 83.4% | Test loss 0.5063  acc 82.3%
# Epoch     26 | Train loss 0.5033  acc 82.7% | Test loss 0.5390  acc 81.8%
# Epoch     27 | Train loss 0.4732  acc 83.6% | Test loss 0.5068  acc 82.3%
# Epoch     28 | Train loss 0.4764  acc 83.8% | Test loss 0.5151  acc 82.3%
# Epoch     29 | Train loss 0.4483  acc 84.4% | Test loss 0.4922  acc 82.6%
# Epoch     30 | Train loss 0.4232  acc 84.7% | Test loss 0.4700  acc 82.9%
# Epoch     31 | Train loss 0.4025  acc 85.2% | Test loss 0.4519  acc 83.6%
# Epoch     32 | Train loss 0.3434  acc 86.8% | Test loss 0.3925  acc 84.6%
# Epoch     67 | Train loss 0.0024  acc 99.9% | Test loss 0.0035  acc 99.9%
# ============================================================
#   ✅ 100% test accuracy reached at epoch 67!
#   📊 Final — Train: 99.92%  Test: 99.91%
# ============================================================

# %% [markdown]
# # 8) Post-norm BatchNorm

# %%
train(run_name="post-norm BatchNorm", norm_type=nn.BatchNorm1d, is_post_norm=True)
# Out:
# ============================================================
#   🚀 Run: post-norm BatchNorm
# ============================================================
# Epoch      1 | Train loss 2.3868  acc 33.7% | Test loss 2.3932  acc 33.5%
# Epoch      2 | Train loss 2.3633  acc 33.6% | Test loss 2.3700  acc 33.4%
# Epoch      3 | Train loss 2.3000  acc 33.8% | Test loss 2.3095  acc 33.6%
# Epoch      4 | Train loss 2.2369  acc 33.8% | Test loss 2.2462  acc 33.6%
# Epoch      5 | Train loss 2.1460  acc 33.8% | Test loss 2.1575  acc 33.6%
# Epoch      6 | Train loss 2.1044  acc 33.8% | Test loss 2.1153  acc 33.6%
# Epoch      7 | Train loss 2.2645  acc 33.8% | Test loss 2.2674  acc 33.6%
# Epoch      8 | Train loss 2.2713  acc 33.1% | Test loss 2.2748  acc 32.9%
# Epoch      9 | Train loss 2.3287  acc 33.8% | Test loss 2.3323  acc 33.6%
# Epoch     10 | Train loss 2.3525  acc 33.8% | Test loss 2.3591  acc 33.6%
# Epoch     11 | Train loss 2.3554  acc 33.6% | Test loss 2.3616  acc 33.4%
# Epoch     12 | Train loss 2.3575  acc 33.8% | Test loss 2.3619  acc 33.6%
# Epoch     13 | Train loss 2.3593  acc 33.8% | Test loss 2.3646  acc 33.6%
# Epoch     14 | Train loss 2.3553  acc 33.8% | Test loss 2.3595  acc 33.6%
# Epoch     15 | Train loss 2.3522  acc 33.8% | Test loss 2.3576  acc 33.6%
# Epoch     16 | Train loss 2.3570  acc 33.8% | Test loss 2.3627  acc 33.6%
# Epoch     17 | Train loss 2.5440  acc 33.8% | Test loss 2.5481  acc 33.6%
# Epoch     18 | Train loss 2.3532  acc 33.8% | Test loss 2.3579  acc 33.6%
# Epoch     19 | Train loss 2.3602  acc 33.7% | Test loss 2.3637  acc 33.5%
# Epoch     20 | Train loss 2.3553  acc 33.7% | Test loss 2.3603  acc 33.5%
# Epoch     21 | Train loss 2.3587  acc 33.8% | Test loss 2.3656  acc 33.6%
# Epoch     22 | Train loss 2.3560  acc 33.7% | Test loss 2.3614  acc 33.5%
# Epoch     23 | Train loss 2.3569  acc 33.8% | Test loss 2.3623  acc 33.6%
# Epoch     24 | Train loss 2.3604  acc 33.4% | Test loss 2.3664  acc 33.2%
# Epoch     25 | Train loss 2.3520  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     26 | Train loss 3.7363  acc 3.1% | Test loss 3.7471  acc 3.2%
# Epoch     27 | Train loss 2.3718  acc 33.3% | Test loss 2.3766  acc 33.1%
# Epoch     28 | Train loss 2.3537  acc 33.8% | Test loss 2.3590  acc 33.6%
# Epoch     29 | Train loss 2.3529  acc 33.8% | Test loss 2.3580  acc 33.6%
# Epoch     30 | Train loss 2.3600  acc 33.3% | Test loss 2.3652  acc 33.2%
# Epoch     31 | Train loss 2.3576  acc 33.8% | Test loss 2.3632  acc 33.6%
# Epoch     32 | Train loss 2.3536  acc 33.8% | Test loss 2.3581  acc 33.6%
# Epoch     33 | Train loss 2.3517  acc 33.8% | Test loss 2.3566  acc 33.6%
# Epoch     34 | Train loss 2.3560  acc 33.8% | Test loss 2.3610  acc 33.6%
# Epoch     35 | Train loss 2.3539  acc 33.8% | Test loss 2.3582  acc 33.6%
# Epoch     36 | Train loss 2.3538  acc 33.8% | Test loss 2.3604  acc 33.6%
# Epoch     37 | Train loss 2.3653  acc 33.8% | Test loss 2.3733  acc 33.6%
# Epoch     38 | Train loss 2.3530  acc 33.8% | Test loss 2.3580  acc 33.6%
# Epoch     39 | Train loss 2.7892  acc 9.5% | Test loss 2.7971  acc 9.2%
# Epoch     40 | Train loss 2.4351  acc 33.3% | Test loss 2.4387  acc 33.1%
# Epoch     41 | Train loss 2.4160  acc 33.8% | Test loss 2.4112  acc 33.6%
# Epoch     42 | Train loss 2.3745  acc 33.8% | Test loss 2.3828  acc 33.6%
# Epoch     43 | Train loss 2.3581  acc 33.7% | Test loss 2.3640  acc 33.6%
# Epoch     44 | Train loss 2.4148  acc 33.7% | Test loss 2.4253  acc 33.5%
# Epoch     45 | Train loss 2.3747  acc 33.8% | Test loss 2.3897  acc 33.6%
# Epoch     46 | Train loss 2.3995  acc 33.8% | Test loss 2.4053  acc 33.6%
# Epoch     47 | Train loss 2.3537  acc 33.8% | Test loss 2.3589  acc 33.6%
# Epoch     48 | Train loss 2.3535  acc 33.8% | Test loss 2.3582  acc 33.6%
# Epoch     49 | Train loss 2.3682  acc 33.6% | Test loss 2.3735  acc 33.4%
# Epoch     50 | Train loss 2.3561  acc 33.8% | Test loss 2.3613  acc 33.6%
# Epoch     51 | Train loss 2.3538  acc 33.8% | Test loss 2.3592  acc 33.6%
# Epoch     52 | Train loss 2.3673  acc 33.8% | Test loss 2.3729  acc 33.6%
# Epoch     53 | Train loss 2.3527  acc 33.8% | Test loss 2.3578  acc 33.6%
# Epoch     54 | Train loss 2.3546  acc 33.8% | Test loss 2.3599  acc 33.6%
# Epoch     55 | Train loss 2.3515  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     56 | Train loss 2.3515  acc 33.8% | Test loss 2.3564  acc 33.6%
# Epoch     57 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     58 | Train loss 2.3515  acc 33.8% | Test loss 2.3565  acc 33.6%
# Epoch     59 | Train loss 2.3514  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch     60 | Train loss 2.3516  acc 33.8% | Test loss 2.3570  acc 33.6%
# Epoch     61 | Train loss 2.4211  acc 33.8% | Test loss 2.4242  acc 33.6%
# Epoch     62 | Train loss 2.3591  acc 33.8% | Test loss 2.3646  acc 33.6%
# Epoch     63 | Train loss 2.3539  acc 33.8% | Test loss 2.3587  acc 33.6%
# Epoch     64 | Train loss 2.3513  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch     65 | Train loss 2.3804  acc 33.8% | Test loss 2.3860  acc 33.6%
# Epoch     66 | Train loss 2.3862  acc 33.8% | Test loss 2.3908  acc 33.6%
# Epoch     67 | Train loss 2.3798  acc 33.8% | Test loss 2.3846  acc 33.6%
# Epoch     68 | Train loss 2.3666  acc 33.8% | Test loss 2.3721  acc 33.6%
# Epoch     69 | Train loss 2.3682  acc 33.8% | Test loss 2.3727  acc 33.6%
# Epoch     70 | Train loss 2.3945  acc 33.8% | Test loss 2.3993  acc 33.6%
# Epoch     71 | Train loss 2.3838  acc 33.8% | Test loss 2.3886  acc 33.6%
# Epoch     72 | Train loss 2.3860  acc 33.8% | Test loss 2.3887  acc 33.6%
# Epoch     73 | Train loss 2.3996  acc 33.8% | Test loss 2.4009  acc 33.6%
# Epoch     74 | Train loss 2.3807  acc 33.8% | Test loss 2.3849  acc 33.6%
# Epoch     75 | Train loss 2.3572  acc 33.8% | Test loss 2.3625  acc 33.6%
# Epoch     76 | Train loss 2.3616  acc 33.8% | Test loss 2.3713  acc 33.6%
# Epoch     77 | Train loss 2.3682  acc 33.8% | Test loss 2.3728  acc 33.6%
# Epoch     78 | Train loss 2.3654  acc 33.8% | Test loss 2.3709  acc 33.6%
# Epoch     79 | Train loss 2.4072  acc 33.8% | Test loss 2.4113  acc 33.6%
# Epoch     80 | Train loss 2.4075  acc 33.8% | Test loss 2.4092  acc 33.6%
# Epoch     81 | Train loss 2.4560  acc 33.8% | Test loss 2.4607  acc 33.6%
# Epoch     82 | Train loss 2.3967  acc 33.8% | Test loss 2.4026  acc 33.6%
# Epoch     83 | Train loss 2.3982  acc 33.8% | Test loss 2.4019  acc 33.6%
# Epoch     84 | Train loss 2.3934  acc 33.8% | Test loss 2.3987  acc 33.6%
# Epoch     85 | Train loss 3.2081  acc 7.1% | Test loss 3.2190  acc 7.1%
# Epoch     86 | Train loss 5.3324  acc 3.5% | Test loss 5.3653  acc 3.4%
# Epoch     87 | Train loss 3.2573  acc 8.1% | Test loss 3.2582  acc 8.1%
# Epoch     88 | Train loss 2.4796  acc 33.7% | Test loss 2.4801  acc 33.5%
# Epoch     89 | Train loss 2.3580  acc 33.8% | Test loss 2.3630  acc 33.6%
# Epoch     90 | Train loss 2.7219  acc 33.7% | Test loss 2.7157  acc 33.5%
# Epoch     91 | Train loss 2.3673  acc 33.8% | Test loss 2.3721  acc 33.6%
# Epoch     92 | Train loss 2.3579  acc 33.8% | Test loss 2.3630  acc 33.6%
# Epoch     93 | Train loss 2.3582  acc 33.8% | Test loss 2.3629  acc 33.6%
# Epoch     94 | Train loss 2.3565  acc 33.8% | Test loss 2.3617  acc 33.6%
# Epoch     95 | Train loss 2.4794  acc 33.8% | Test loss 2.4814  acc 33.6%
# Epoch     96 | Train loss 2.3538  acc 33.8% | Test loss 2.3594  acc 33.6%
# Epoch     97 | Train loss 2.3826  acc 33.8% | Test loss 2.3858  acc 33.6%
# Epoch     98 | Train loss 2.3573  acc 33.8% | Test loss 2.3615  acc 33.6%
# Epoch     99 | Train loss 2.3744  acc 33.8% | Test loss 2.3794  acc 33.6%
# Epoch    100 | Train loss 2.3592  acc 33.8% | Test loss 2.3637  acc 33.6%
# Epoch    101 | Train loss 2.3611  acc 33.8% | Test loss 2.3657  acc 33.6%
# Epoch    102 | Train loss 2.3622  acc 33.8% | Test loss 2.3671  acc 33.6%
# Epoch    103 | Train loss 2.3730  acc 33.8% | Test loss 2.3789  acc 33.6%
# Epoch    104 | Train loss 2.3584  acc 33.8% | Test loss 2.3632  acc 33.6%
# Epoch    105 | Train loss 2.3547  acc 33.8% | Test loss 2.3604  acc 33.6%
# Epoch    106 | Train loss 2.5935  acc 33.4% | Test loss 2.5965  acc 33.2%
# Epoch    107 | Train loss 2.3634  acc 33.8% | Test loss 2.3684  acc 33.6%
# Epoch    108 | Train loss 2.3592  acc 33.8% | Test loss 2.3640  acc 33.6%
# Epoch    109 | Train loss 2.3692  acc 33.8% | Test loss 2.3741  acc 33.6%
# Epoch    110 | Train loss 2.3532  acc 33.8% | Test loss 2.3588  acc 33.6%
# Epoch    111 | Train loss 2.3771  acc 33.8% | Test loss 2.3809  acc 33.6%
# Epoch    112 | Train loss 2.4501  acc 33.8% | Test loss 2.4542  acc 33.6%
# Epoch    113 | Train loss 2.3618  acc 33.8% | Test loss 2.3656  acc 33.6%
# Epoch    114 | Train loss 2.3698  acc 33.8% | Test loss 2.3732  acc 33.6%
# Epoch    115 | Train loss 2.3868  acc 33.8% | Test loss 2.3916  acc 33.6%
# Epoch    116 | Train loss 2.3625  acc 33.8% | Test loss 2.3674  acc 33.6%
# Epoch    117 | Train loss 2.3648  acc 33.8% | Test loss 2.3694  acc 33.6%
# Epoch    118 | Train loss 2.3674  acc 33.8% | Test loss 2.3722  acc 33.6%
# Epoch    119 | Train loss 2.3640  acc 33.8% | Test loss 2.3689  acc 33.6%
# Epoch    120 | Train loss 2.3998  acc 33.8% | Test loss 2.4029  acc 33.6%
# Epoch    121 | Train loss 2.3576  acc 33.8% | Test loss 2.3622  acc 33.6%
# Epoch    122 | Train loss 2.3571  acc 33.8% | Test loss 2.3631  acc 33.6%
# Epoch    123 | Train loss 2.3665  acc 33.8% | Test loss 2.3733  acc 33.6%
# Epoch    124 | Train loss 2.3608  acc 33.8% | Test loss 2.3658  acc 33.6%
# Epoch    125 | Train loss 2.3612  acc 33.8% | Test loss 2.3669  acc 33.6%
# Epoch    126 | Train loss 2.3820  acc 33.8% | Test loss 2.3861  acc 33.6%
# Epoch    127 | Train loss 2.3633  acc 33.8% | Test loss 2.3677  acc 33.6%
# Epoch    128 | Train loss 2.3724  acc 33.8% | Test loss 2.3771  acc 33.6%
# Epoch    129 | Train loss 3.4661  acc 7.8% | Test loss 3.4702  acc 7.9%
# Epoch    130 | Train loss 2.3556  acc 33.8% | Test loss 2.3605  acc 33.6%
# Epoch    131 | Train loss 2.3569  acc 33.8% | Test loss 2.3629  acc 33.6%
# Epoch    132 | Train loss 2.3734  acc 33.8% | Test loss 2.3791  acc 33.6%
# Epoch    133 | Train loss 2.3561  acc 33.8% | Test loss 2.3624  acc 33.6%
# Epoch    134 | Train loss 2.3544  acc 33.8% | Test loss 2.3598  acc 33.6%
# Epoch    135 | Train loss 2.3578  acc 33.8% | Test loss 2.3633  acc 33.6%
# Epoch    136 | Train loss 2.3566  acc 33.8% | Test loss 2.3622  acc 33.6%
# Epoch    137 | Train loss 4.3019  acc 4.9% | Test loss 4.2924  acc 5.0%
# Epoch    138 | Train loss 2.3672  acc 33.8% | Test loss 2.3720  acc 33.6%
# Epoch    139 | Train loss 2.3520  acc 33.8% | Test loss 2.3576  acc 33.6%
# Epoch    140 | Train loss 2.3609  acc 33.8% | Test loss 2.3659  acc 33.6%
# Epoch    141 | Train loss 2.3615  acc 33.8% | Test loss 2.3663  acc 33.6%
# Epoch    142 | Train loss 2.3572  acc 33.8% | Test loss 2.3623  acc 33.6%
# Epoch    143 | Train loss 2.3537  acc 33.8% | Test loss 2.3585  acc 33.6%
# Epoch    144 | Train loss 2.3536  acc 33.8% | Test loss 2.3584  acc 33.6%
# Epoch    145 | Train loss 2.3567  acc 33.8% | Test loss 2.3613  acc 33.6%
# Epoch    146 | Train loss 2.3620  acc 33.8% | Test loss 2.3664  acc 33.6%
# Epoch    147 | Train loss 2.3563  acc 33.8% | Test loss 2.3623  acc 33.6%
# Epoch    148 | Train loss 2.3559  acc 33.8% | Test loss 2.3606  acc 33.6%
# Epoch    149 | Train loss 2.3533  acc 33.8% | Test loss 2.3582  acc 33.6%
# Epoch    150 | Train loss 2.3537  acc 33.8% | Test loss 2.3590  acc 33.6%
# Epoch    151 | Train loss 2.3538  acc 33.8% | Test loss 2.3584  acc 33.6%
# Epoch    152 | Train loss 2.8067  acc 33.7% | Test loss 2.8147  acc 33.6%
# Epoch    153 | Train loss 2.3709  acc 33.7% | Test loss 2.3724  acc 33.6%
# Epoch    154 | Train loss 2.3616  acc 33.8% | Test loss 2.3669  acc 33.6%
# Epoch    155 | Train loss 2.3651  acc 33.8% | Test loss 2.3688  acc 33.6%
# Epoch    156 | Train loss 2.3524  acc 33.8% | Test loss 2.3576  acc 33.6%
# Epoch    157 | Train loss 2.3518  acc 33.8% | Test loss 2.3568  acc 33.6%
# Epoch    158 | Train loss 2.3548  acc 33.8% | Test loss 2.3599  acc 33.6%
# Epoch    159 | Train loss 2.3537  acc 33.8% | Test loss 2.3588  acc 33.6%
# Epoch    160 | Train loss 2.3771  acc 33.8% | Test loss 2.3826  acc 33.6%
# Epoch    161 | Train loss 2.3580  acc 33.7% | Test loss 2.3633  acc 33.5%
# Epoch    162 | Train loss 7.0889  acc 33.8% | Test loss 7.1362  acc 33.6%
# Epoch    163 | Train loss 18.0520  acc 0.2% | Test loss 18.0292  acc 0.2%
# Epoch    164 | Train loss 2.3550  acc 33.8% | Test loss 2.3595  acc 33.6%
# Epoch    165 | Train loss 2.3529  acc 33.8% | Test loss 2.3581  acc 33.6%
# Epoch    166 | Train loss 2.3564  acc 33.7% | Test loss 2.3603  acc 33.6%
# Epoch    167 | Train loss 2.3554  acc 33.8% | Test loss 2.3605  acc 33.6%
# Epoch    168 | Train loss 2.3568  acc 33.8% | Test loss 2.3621  acc 33.6%
# Epoch    169 | Train loss 2.3826  acc 33.7% | Test loss 2.3872  acc 33.5%
# Epoch    170 | Train loss 2.3625  acc 33.8% | Test loss 2.3687  acc 33.6%
# Epoch    171 | Train loss 2.3667  acc 33.8% | Test loss 2.3732  acc 33.6%
# Epoch    172 | Train loss 2.3543  acc 33.8% | Test loss 2.3595  acc 33.6%
# Epoch    173 | Train loss 2.3536  acc 33.8% | Test loss 2.3586  acc 33.6%
# Epoch    174 | Train loss 2.3555  acc 33.8% | Test loss 2.3606  acc 33.6%
# Epoch    175 | Train loss 2.4388  acc 33.8% | Test loss 2.4474  acc 33.6%
# Epoch    176 | Train loss 2.3558  acc 33.8% | Test loss 2.3608  acc 33.6%
# Epoch    177 | Train loss 2.3897  acc 33.8% | Test loss 2.3885  acc 33.6%
# Epoch    178 | Train loss 2.3517  acc 33.8% | Test loss 2.3567  acc 33.6%
# Epoch    179 | Train loss 2.3518  acc 33.8% | Test loss 2.3574  acc 33.6%
# Epoch    180 | Train loss 2.3558  acc 33.8% | Test loss 2.3599  acc 33.6%
# Epoch    181 | Train loss 2.4628  acc 33.7% | Test loss 2.4634  acc 33.6%
# Epoch    182 | Train loss 2.4006  acc 33.8% | Test loss 2.4038  acc 33.6%
# Epoch    183 | Train loss 2.3804  acc 33.8% | Test loss 2.3842  acc 33.6%
# Epoch    184 | Train loss 2.7953  acc 33.8% | Test loss 2.8049  acc 33.6%
# Epoch    185 | Train loss 2.3518  acc 33.8% | Test loss 2.3569  acc 33.6%
# Epoch    186 | Train loss 2.3646  acc 33.8% | Test loss 2.3687  acc 33.6%
# Epoch    187 | Train loss 2.3676  acc 33.8% | Test loss 2.3710  acc 33.6%
# Epoch    188 | Train loss 2.3790  acc 33.8% | Test loss 2.3785  acc 33.6%
# Epoch    189 | Train loss 2.4612  acc 33.6% | Test loss 2.4701  acc 33.4%
# Epoch    190 | Train loss 2.3526  acc 33.8% | Test loss 2.3573  acc 33.6%
# Epoch    191 | Train loss 2.3622  acc 33.8% | Test loss 2.3691  acc 33.6%
# Epoch    192 | Train loss 2.3603  acc 33.8% | Test loss 2.3656  acc 33.6%
# Epoch    193 | Train loss 2.3620  acc 33.8% | Test loss 2.3667  acc 33.6%
# Epoch    194 | Train loss 2.3580  acc 33.8% | Test loss 2.3627  acc 33.6%
# Epoch    195 | Train loss 2.3545  acc 33.8% | Test loss 2.3595  acc 33.6%
# Epoch    196 | Train loss 2.3674  acc 33.8% | Test loss 2.3734  acc 33.6%
# Epoch    197 | Train loss 2.3594  acc 33.8% | Test loss 2.3642  acc 33.6%
# Epoch    198 | Train loss 2.3542  acc 33.8% | Test loss 2.3584  acc 33.6%
# Epoch    199 | Train loss 2.3528  acc 33.8% | Test loss 2.3584  acc 33.6%
# Epoch    200 | Train loss 2.3527  acc 33.8% | Test loss 2.3584  acc 33.6%
# ⚠️  Did not reach 100% in 200 epochs.
#     Final test acc: 33.6%

# %% [markdown]
# # 9) Loss + Accuracy across runs

# %%
#@title Visualize
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
import logging
import matplotlib.ticker as ticker

# Suppress missing font warnings
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# Prefer the deployment font when available, otherwise fall back to common sans-serif fonts
font_candidates = ['Inter', 'DejaVu Sans', 'Arial', 'Helvetica', 'sans-serif']
plt.rcParams['font.family'] = font_candidates
font_path = 'fonts/Inter-Regular.ttf'
try:
    prop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = prop.get_name()
except Exception:
    pass

# Set styling for all text and lines
plt.rcParams['text.color'] = '#F1F5F9'
plt.rcParams['axes.labelcolor'] = '#F1F5F9'
plt.rcParams['xtick.color'] = '#F1F5F9'
plt.rcParams['ytick.color'] = '#F1F5F9'
plt.rcParams['axes.edgecolor'] = '#F1F5F9'

# Grid styling
plt.rcParams['grid.color'] = '#5B7268'
plt.rcParams['grid.alpha'] = 0.7

def _coplot_luminance_from_rgba(rgba):
    r, g, b = mcolors.to_rgb(rgba)
    def _linear(c):
        return c / 12.92 if c <= 0.03928 else ((c + 0.055) / 1.055) ** 2.4
    return 0.2126 * _linear(r) + 0.7152 * _linear(g) + 0.0722 * _linear(b)

def _coplot_text_color_for_rgba(rgba, preferred='#F1F5F9'):
    try:
        preferred_l = _coplot_luminance_from_rgba(mcolors.to_rgba(preferred))
        bg_l = _coplot_luminance_from_rgba(rgba)
        lighter = max(preferred_l, bg_l)
        darker = min(preferred_l, bg_l)
        ratio = (lighter + 0.05) / (darker + 0.05)
        if ratio >= 4.5:
            return preferred
    except Exception:
        pass
    bg_l = _coplot_luminance_from_rgba(rgba)
    return '#111111' if bg_l > 0.5 else '#FFFFFF'

# Create figure and axis with publication-quality settings
fig, axes = plt.subplots(1, 2, figsize=(14, 5.5), dpi=300)
fig.patch.set_facecolor('#1A3A2A')

# Distinct bright colors for dark background (modified to keep runs distinguishable)
colors = ["#38BDF8", "#34D399", "#FBBF24", "#F87171", "#A78BFA", "#FB923C", "#E879F9"]
line_styles = ["-","--",":","-."]
marker_styles = ["o","s","^","D"]

for idx, run in enumerate(all_runs):
    h = run["history"]

    line_style = line_styles[idx % len(line_styles)] if False else '-'
    marker_style = marker_styles[idx % len(marker_styles)] if False else ''

    # Plot accuracy
    axes[0].plot(h["epoch"], h["test_acc"], label=run["name"],
                 color=colors[idx % len(colors)], linewidth=2,
                 linestyle=line_style, marker=marker_style, alpha=0.9)

    # Plot loss
    axes[1].plot(h["epoch"], h["test_loss"], label=run["name"],
                 color=colors[idx % len(colors)], linewidth=2,
                 linestyle=line_style, marker=marker_style, alpha=0.9)

# Apply custom styling to both axes
for ax in axes:
    ax.set_facecolor('#1A3A2A')
    ax.set_xlabel('Epoch', fontsize=12, labelpad=10, color='#F1F5F9')

    # Force integer epochs
    ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # Add grid
    ax.grid(axis='both', alpha=0.7, color='#5B7268', linestyle='--', linewidth=0.5, zorder=0)
    ax.set_axisbelow(True)

    # Remove top and right spines for cleaner look
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['left'].set_linewidth(1)
    ax.spines['bottom'].set_color('#F1F5F9')
    ax.spines['left'].set_color('#F1F5F9')

    # Adjust spine positions
    ax.spines['left'].set_position(('outward', 2))
    ax.spines['bottom'].set_position(('outward', 2))

    # Add legend
    ax.legend(frameon=False, fontsize=10)

# Specific titles and labels
axes[0].set_ylabel('Test Accuracy', fontsize=12, color='#F1F5F9', labelpad=10)
axes[0].set_title('Test Accuracy by Normalization', color='#F1F5F9', pad=15)
axes[0].yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

axes[1].set_ylabel('Test Loss', fontsize=12, color='#F1F5F9', labelpad=10)
axes[1].set_title('Test Loss by Normalization', color='#F1F5F9', pad=15)
axes[1].set_yscale('linear')
axes[1].set_ylim(top=3.0)
axes[1].set_ylim(bottom=0.0)
axes[1].yaxis.set_major_formatter(ticker.ScalarFormatter())

# Global title
plt.suptitle("Normalization Method Comparison", fontsize=14, y=1.02, color='#F1F5F9')

# Tight layout
plt.tight_layout()
plt.show()

# Summary table
print(f"\n{'Run':<20s} {'Converged Epoch':<20s}")
print("-" * 40)
for run in sorted(all_runs, key=lambda x: (x['converged_epoch'] is None, x['converged_epoch'])):
    ep = run["converged_epoch"]
    print(f"{run['name']:<20s} {str(ep) if ep else 'Did not converge':<20s}")
# Out:
# Run                  Converged Epoch
# ----------------------------------------
# pre-norm BatchNorm   67
# pre-norm RMSNorm     71
# pre-norm LayerNorm   78
# no normalization     Did not converge
# post-norm RMSNorm    Did not converge
# post-norm LayerNorm  Did not converge
# post-norm BatchNorm  Did not converge

# %%
#@title Visualize 2x2 Accuracy & Loss
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
import logging
import matplotlib.ticker as ticker

# Suppress missing font warnings
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# Prefer the deployment font when available, otherwise fall back to common sans-serif fonts
font_candidates = ['Inter', 'DejaVu Sans', 'Arial', 'Helvetica', 'sans-serif']
plt.rcParams['font.family'] = font_candidates
font_path = 'fonts/Inter-Regular.ttf'
try:
    prop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = prop.get_name()
except Exception:
    pass

# Set styling for all text and lines
plt.rcParams['text.color'] = '#F1F5F9'
plt.rcParams['axes.labelcolor'] = '#F1F5F9'
plt.rcParams['xtick.color'] = '#F1F5F9'
plt.rcParams['ytick.color'] = '#F1F5F9'
plt.rcParams['axes.edgecolor'] = '#F1F5F9'

# Grid styling
plt.rcParams['grid.color'] = '#5B7268'
plt.rcParams['grid.alpha'] = 0.7

# Create figure and axis with publication-quality settings
fig, axes = plt.subplots(2, 2, figsize=(16, 10), dpi=300)
fig.patch.set_facecolor('#1A3A2A')

run_color_map = {
    "pre-norm BatchNorm": "#F87171", # Red hue
    "pre-norm LayerNorm": "#FB923C", # Orange hue
    "pre-norm RMSNorm": "#22C55E",   # Green hue
    "post-norm BatchNorm": "#A78BFA",# Purple hue
    "post-norm LayerNorm": "#38BDF8",# Blue hue
    "post-norm RMSNorm": "#E879F9",  # Pink hue
    "no normalization": "#FBBF24"    # Yellow hue
}
fallback_colors = ["#38BDF8", "#34D399", "#FBBF24", "#F87171", "#A78BFA", "#FB923C", "#E879F9"]

for idx, run in enumerate(all_runs):
    h = run["history"]

    is_pre = "pre-norm" in run["name"]
    row_idx = 0 if is_pre else 1

    run_color = run_color_map.get(run["name"], fallback_colors[idx % len(fallback_colors)])

    # Plot accuracy
    axes[row_idx, 0].plot(h["epoch"], h["test_acc"], label=run["name"],
                 color=run_color, linewidth=2, alpha=0.9)

    # Plot loss
    axes[row_idx, 1].plot(h["epoch"], h["test_loss"], label=run["name"],
                 color=run_color, linewidth=2, alpha=0.9)

# Apply custom styling to all axes
for r in range(2):
    for c in range(2):
        ax = axes[r, c]
        ax.set_facecolor('#1A3A2A')
        ax.set_xlabel('Epoch', fontsize=12, labelpad=10, color='#F1F5F9')

        # Force integer epochs
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

        # Add grid
        ax.grid(axis='both', alpha=0.7, color='#5B7268', linestyle='--', linewidth=0.5, zorder=0)
        ax.set_axisbelow(True)

        # Remove top and right spines for cleaner look
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_linewidth(1)
        ax.spines['left'].set_linewidth(1)
        ax.spines['bottom'].set_color('#F1F5F9')
        ax.spines['left'].set_color('#F1F5F9')

        # Adjust spine positions
        ax.spines['left'].set_position(('outward', 2))
        ax.spines['bottom'].set_position(('outward', 2))

        # Add legend
        ax.legend(frameon=False, fontsize=10)

# Specific titles and labels
axes[0, 0].set_ylabel('Test Accuracy', fontsize=12, color='#F1F5F9', labelpad=10)
axes[0, 0].set_title('Pre-norm: Test Accuracy', color='#F1F5F9', pad=15)
axes[0, 0].yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

axes[0, 1].set_ylabel('Test Loss', fontsize=12, color='#F1F5F9', labelpad=10)
axes[0, 1].set_title('Pre-norm: Test Loss', color='#F1F5F9', pad=15)
axes[0, 1].set_yscale('linear')
axes[0, 1].set_ylim(bottom=0.0, top=3.0)

axes[1, 0].set_ylabel('Test Accuracy', fontsize=12, color='#F1F5F9', labelpad=10)
axes[1, 0].set_title('Post-norm & No-norm: Test Accuracy', color='#F1F5F9', pad=15)
axes[1, 0].yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1.0))

axes[1, 1].set_ylabel('Test Loss', fontsize=12, color='#F1F5F9', labelpad=10)
axes[1, 1].set_title('Post-norm & No-norm: Test Loss', color='#F1F5F9', pad=15)
axes[1, 1].set_yscale('linear')
axes[1, 1].set_ylim(bottom=0.0, top=3.0)

# Global title
plt.suptitle("Normalization Method Comparison", fontsize=16, y=1.02, color='#F1F5F9')

# Tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10) Activation values visualized

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
import torch

# Prefer the deployment font when available, otherwise fall back to common sans-serif fonts
font_candidates = ['Inter', 'DejaVu Sans', 'Arial', 'Helvetica', 'sans-serif']
plt.rcParams['font.family'] = font_candidates
font_path = 'fonts/Inter-Regular.ttf'
try:
    prop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = prop.get_name()
except Exception:
    pass

# Set styling for all text and lines
plt.rcParams['text.color'] = '#F1F5F9'
plt.rcParams['axes.labelcolor'] = '#F1F5F9'
plt.rcParams['xtick.color'] = '#F1F5F9'
plt.rcParams['ytick.color'] = '#F1F5F9'
plt.rcParams['axes.edgecolor'] = '#F1F5F9'

# Grid styling
plt.rcParams['grid.color'] = '#5D6674'
plt.rcParams['grid.alpha'] = 0.7

def _coplot_luminance_from_rgba(rgba):
    r, g, b = mcolors.to_rgb(rgba)
    def _linear(c):
        return c / 12.92 if c <= 0.03928 else ((c + 0.055) / 1.055) ** 2.4
    return 0.2126 * _linear(r) + 0.7152 * _linear(g) + 0.0722 * _linear(b)

def _coplot_text_color_for_rgba(rgba, preferred='#F1F5F9'):
    try:
        preferred_l = _coplot_luminance_from_rgba(mcolors.to_rgba(preferred))
        bg_l = _coplot_luminance_from_rgba(rgba)
        lighter = max(preferred_l, bg_l)
        darker = min(preferred_l, bg_l)
        ratio = (lighter + 0.05) / (darker + 0.05)
        if ratio >= 4.5:
            return preferred
    except Exception:
        pass
    bg_l = _coplot_luminance_from_rgba(rgba)
    return '#111111' if bg_l > 0.5 else '#FFFFFF'

# ── Signal survival per layer (post-hoc) ──
xb, yb = next(iter(test_loader))

# Create figure and axis with publication-quality settings
fig, ax = plt.subplots(figsize=(10, 5.5), dpi=300)
fig.patch.set_facecolor('#1E293B')
ax.set_facecolor('#1E293B')

# Define distinct bright colors instead of the same blue, so lines are distinguishable
colors = ["#38BDF8", "#34D399", "#FBBF24", "#F87171", "#A78BFA", "#FB923C", "#E879F9"]
line_styles = ["-","--",":","-."]
marker_styles = ["o","s","^","D"]

for idx, run in enumerate(all_runs):
    model = run["model"].eval()
    if hasattr(model, "_orig_mod"):
        model = model._orig_mod

    magnitudes = []

    handles = []
    def make_hook(store):
        def hook(module, input, output):
            store.append(output.detach().abs().mean().item())
        return hook

    for block in model.layers:
        m = []
        magnitudes.append(m)
        handles.append(block.register_forward_hook(make_hook(m)))

    with torch.no_grad():
        model(xb)

    for h in handles:
        h.remove()

    layer_means = [m[0] for m in magnitudes]

    line_style = line_styles[idx % len(line_styles)] if False else '-'
    marker_style = marker_styles[idx % len(marker_styles)] if False else 'o'

    ax.plot(range(len(layer_means)), layer_means,
           color=colors[idx % len(colors)],
           linewidth=2,
           linestyle=line_style,
           marker=marker_style, markersize=5,
           label=run["name"],
           alpha=0.9)

ax.set_yscale("log")
ax.axhline(y=1.0, color="#F1F5F9", linestyle="--", alpha=0.3, linewidth=1)

# Customize axis labels
ax.set_xlabel('Layer index', fontsize=15, labelpad=10, color='#F1F5F9')
ax.set_ylabel('Activation value', fontsize=15, color='#F1F5F9', labelpad=10)
ax.set_title("Activation values in each layer", fontsize=16, color='#F1F5F9', pad=25)

# Add grid
ax.grid(axis='both', alpha=0.7, color='#5D6674', linestyle='--', linewidth=0.5, zorder=0)
ax.set_axisbelow(True)

# Add legend
ax.legend(loc='upper center',
         bbox_to_anchor=(0.5, 1.05),
         frameon=False, fontsize=12, ncol=3)

# Remove top and right spines for cleaner look
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1)
ax.spines['left'].set_linewidth(1)
ax.spines['bottom'].set_color('#F1F5F9')
ax.spines['left'].set_color('#F1F5F9')

# Adjust spine positions
ax.spines['left'].set_position(('outward', 2))
ax.spines['bottom'].set_position(('outward', 2))

# Tight layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
import torch

# Prefer the deployment font when available, otherwise fall back to common sans-serif fonts
font_candidates = ['Inter', 'DejaVu Sans', 'Arial', 'Helvetica', 'sans-serif']
plt.rcParams['font.family'] = font_candidates
font_path = 'fonts/Inter-Regular.ttf'
try:
    prop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = prop.get_name()
except Exception:
    pass

# Set styling for all text and lines
plt.rcParams['text.color'] = '#F1F5F9'
plt.rcParams['axes.labelcolor'] = '#F1F5F9'
plt.rcParams['xtick.color'] = '#F1F5F9'
plt.rcParams['ytick.color'] = '#F1F5F9'
plt.rcParams['axes.edgecolor'] = '#F1F5F9'

# Grid styling
plt.rcParams['grid.color'] = '#5D6674'
plt.rcParams['grid.alpha'] = 0.7

# ── Signal survival per layer (post-hoc) ──
xb, yb = next(iter(test_loader))

# Create figure and axis with publication-quality settings
fig, axes = plt.subplots(1, 2, figsize=(20, 5.5), dpi=300)
fig.patch.set_facecolor('#1E293B')

# Define color mappings for specific runs
run_color_map = {
    "pre-norm BatchNorm": "#F87171", # Red hue
    "pre-norm LayerNorm": "#FB923C", # Orange hue
    "pre-norm RMSNorm": "#38BDF8",   # Blue hue
    "post-norm BatchNorm": "#A78BFA",# Purple hue
    "post-norm LayerNorm": "#34D399",# Green hue
    "post-norm RMSNorm": "#E879F9",  # Pink hue
    "no normalization": "#FBBF24"    # Yellow hue
}
fallback_colors = ["#38BDF8", "#34D399", "#FBBF24", "#F87171", "#A78BFA", "#FB923C", "#E879F9"]
line_styles = ["-","--",":","-."]

for idx, run in enumerate(all_runs):
    is_pre = "pre-norm" in run["name"]
    is_post = "post-norm" in run["name"]
    is_no = "no normalization" in run["name"]

    ax_idx = 0 if is_pre else 1
    ax = axes[ax_idx]

    model = run["model"].eval()
    if hasattr(model, "_orig_mod"):
        model = model._orig_mod

    magnitudes = []

    handles = []
    def make_hook(store):
        def hook(module, input, output):
            store.append(output.detach().abs().mean().item())
        return hook

    for block in model.layers:
        m = []
        magnitudes.append(m)
        handles.append(block.register_forward_hook(make_hook(m)))

    with torch.no_grad():
        model(xb)

    for h in handles:
        h.remove()

    layer_means = [m[0] for m in magnitudes]

    line_style = line_styles[idx % len(line_styles)] if False else '-'
    run_color = run_color_map.get(run["name"], fallback_colors[idx % len(fallback_colors)])

    ax.plot(range(len(layer_means)), layer_means,
           color=run_color,
           linewidth=2.5,
           linestyle=line_style,
           label=run["name"],
           alpha=0.9)

titles = ["Pre-norm Activation Values", "Post-norm & No Normalization Activation Values"]
for i, ax in enumerate(axes):
    ax.set_facecolor('#1E293B')
    ax.set_yscale("log")
    ax.axhline(y=1.0, color="#F1F5F9", linestyle="--", alpha=0.3, linewidth=1)

    # Customize axis labels
    ax.set_xlabel('Layer index', fontsize=15, labelpad=10, color='#F1F5F9')
    ax.set_ylabel('Activation value', fontsize=15, color='#F1F5F9', labelpad=10)
    ax.set_title(titles[i], fontsize=16, color='#F1F5F9', pad=25)

    # Add grid
    ax.grid(axis='both', alpha=0.7, color='#5D6674', linestyle='--', linewidth=0.5, zorder=0)
    ax.set_axisbelow(True)

    # Add legend
    ax.legend(loc='upper center',
             bbox_to_anchor=(0.5, 1.05),
             frameon=False, fontsize=12, ncol=3)

    # Remove top and right spines for cleaner look
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_linewidth(1)
    ax.spines['left'].set_linewidth(1)
    ax.spines['bottom'].set_color('#F1F5F9')
    ax.spines['left'].set_color('#F1F5F9')

    # Adjust spine positions
    ax.spines['left'].set_position(('outward', 2))
    ax.spines['bottom'].set_position(('outward', 2))

# Tight layout
plt.tight_layout()

# Display the plot
plt.show()
